# %%
import os
import re
import json
import pickle
import random
from template_config import *
from collections import defaultdict
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/taoyu/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
ps = PorterStemmer()
lmtzr = WordNetLemmatizer()

# %%
def read_in_all_data(data_path=DATA_PATH):
    training_data = json.load(open(os.path.join(data_path, "train_spider.json")))
    tables_org = json.load(open(os.path.join(data_path, "tables.json")))
    tables = {tab['db_id']: tab for tab in tables_org}

    return training_data, tables

# %%
def get_all_question_query_pairs(data):
    question_query_pairs = []
    for item in data:
        question_query_pairs.append((item['question_toks'], item['query'], item['db_id']))
    return question_query_pairs

# %%
training_data, tables = read_in_all_data("data")

train_qq_pairs = get_all_question_query_pairs(training_data)

# %%
print("Training question-query pair count: {}".format(len(train_qq_pairs)))
# Out:
# Training question-query pair count: 7000

# %%
def is_value(token):
    """
    as values can either be a numerical digit or a string literal, then we can
    detect if a token is a value by matching with regex
    """
    is_number = True
    try:
        float(token)
    except ValueError:
        is_number = False
    is_string = token.startswith("\"") or token.startswith("\'") or token.endswith("\"") or token.endswith("\'")

    return is_number or is_string


def remove_all_from_clauses(query_keywords):
    """
    remove all keywords from from clauses, until there is no more from clauses
    e.g. select {} from {} as {} where {} = {} --> select {} where {} = {}
    """
    # remove from clause by deleting the range from "FROM" to "WHERE" or "GROUP"
    start_location = 0
    count = 0
    while "FROM" in query_keywords:
        count += 1
        if count > 5:
            break
            print("error query_keywords: ", query_keywords)
        from_location = query_keywords.index("FROM")
        end_token_locations = [len(query_keywords)]  # defaulting to the end of the list
        for end_token in ["WHERE", "GROUP", "ORDER"]:
            try:
                end_token_locations.append(query_keywords.index(end_token, start_location))
            except ValueError:
                pass

        query_keywords = query_keywords[:from_location] + [FROM_SYMBOL] + query_keywords[min(end_token_locations):]
        start_location = min(end_token_locations)
        
    return query_keywords


def strip_query(query, table):
    """
    returns (stripped query, non keywords)
    """
    #get table column names info
    column_types = table['column_types']
    table_names_original = [cn.lower() for cn in table['table_names_original']]
    table_names = [cn.lower() for cn in table['table_names']]
    column_names = [cn.lower() for i, cn in table['column_names']]
    column_names_original = [cn.lower() for i, cn in table['column_names_original']]

    #clean query: replace values, numbers, column names with SYMBOL
    query_keywords = []
    columns = table_names_original + table_names

    query = query.replace(";","")
    query = query.replace("\t","")
    query = query.replace("(", " ( ").replace(")", " ) ")
    # then replace all stuff enclosed by "" with a numerical value to get it marked as {VALUE}
    str_1 = re.findall("\"[^\"]*\"", query)
    str_2 = re.findall("\'[^\']*\'", query)
    values = str_1 + str_2
    for val in values:
        query = query.replace(val.strip(), VALUE_STR_SYMBOL)

    query_tokenized = query.split(' ')
    float_nums = re.findall("[-+]?\d*\.\d+", query)
    query_tokenized = [VALUE_NUM_SYMBOL if qt in float_nums else qt for qt in query_tokenized]
    query = " ".join(query_tokenized)
    int_nums = [i.strip() for i in re.findall("[^tT]\d+", query)]
    query_tokenized = [VALUE_NUM_SYMBOL if qt in int_nums else qt for qt in query_tokenized]
    nums = float_nums + int_nums
        
    #query_tokenized = query.split(' ')
    cols_dict = {}
    for token in query_tokenized:
        if len(token.strip()) == 0:  # in case there are more than one space used
            continue
        if IGNORE_COMMAS_AND_ROUND_BRACKETS:
            keywords_dict = SQL_KEYWORDS_AND_OPERATORS_WITHOUT_COMMAS_AND_BRACES
        else:
            keywords_dict = SQL_KEYWORDS_AND_OPERATORS

        if token.upper() not in keywords_dict and token != VALUE_STR_SYMBOL and token != VALUE_NUM_SYMBOL:
            token = token.upper()
            if USE_COLUMN_AND_VALUE_REPLACEMENT_TOKEN:
                token = re.sub("[T]\d+\.", '', token)
                token = re.sub(r"\"|\'", '', token)
                token = re.sub("[T]\d+", '', token).lower()
#                 if token in table_names_original:
#                     query_keywords.append(TABLE_SYMBOL)
#                     continue
                if token != '' and token in column_names_original:
                    try:
                        tok_ind = column_names_original.index(token)
                    except:
                        print("\ntable: {}".format(table['db_id']))
                        print("\ntoken: {}".format(token))
                        print("column_names_original: {}".format(column_names_original))
                        print("query: {}".format(query))
                        print("query_tokenized: {}".format(query_tokenized))
                        exit(1)
                    col_type = column_types[tok_ind]
                    col_name = column_names[tok_ind]
                    columns.append(col_name)
                    columns.append(token)
                    if token not in cols_dict:
                        cols_dict[token] = COLUMN_SYMBOL.replace("}", str(len(cols_dict)))
                    query_keywords.append(cols_dict[token])
                elif token in table_names_original:
                    query_keywords.append(TABLE_SYMBOL)
                    continue
                    
        else:
            query_keywords.append(token.upper())

    if "FROM" in query_keywords:
        query_keywords = remove_all_from_clauses(query_keywords)

    if USE_LIMITED_KEYWORD_SET:
        query_keywords = [kw for kw in query_keywords if kw in LIMITED_KEYWORD_SET]

    columns_lemed = [lmtzr.lemmatize(w) for w in " ".join(columns).split(" ") if w not in LOW_CHAR]
    columns_lemed_stemed = [ps.stem(w) for w in columns_lemed]

    return " ".join(query_keywords), values, nums, columns_lemed_stemed


def filter_string(cs):
    return "".join([c.upper() for c in cs if c.isalpha() or c == ' '])


def process_question(question, values, nums, columns):

    question = " ".join(question).lower()
    values = [re.sub(r"\"|\'", '', val) for val in values]
    for val in values:
        val = val.lower()
        try:
            question = re.sub(r'\b'+val+r'\b', VALUE_STR_SYMBOL, question)
        except:
            continue

    for num in nums:
        num = num.strip()
        question = re.sub(r'\b'+num+r'\b', VALUE_NUM_SYMBOL, question)

    question_toks = question.split(" ")
    question_lemed = [lmtzr.lemmatize(w) for w in question_toks]
    question_lemed_stemed = [ps.stem(w) for w in question_lemed]
    replace_inds = [i for i, qt in enumerate(question_lemed_stemed) if qt in columns]
    #print("question_stemed: {}".format(question_stemed))
    #print("replace_inds: {}".format(replace_inds))
    for ind in replace_inds:
        question_toks[ind] = COLUMN_SYMBOL

    question_template = ' '.join(question_toks)

    return question_template

# %%
KEY_KEYWORD_SET = {"SELECT", "WHERE", "GROUP", "HAVING", "ORDER", "BY", "LIMIT", "EXCEPT", "UNION", "INTERSECT"}
ALL_KEYWORD_SET = {"SELECT", "WHERE", "GROUP", "HAVING", "DESC", "ORDER", "BY", "LIMIT", "EXCEPT", "UNION", 
                   "INTERSECT", "NOT", "IN", "OR", "LIKE", "(", ">", ")", "COUNT"}

WHERE_OPS = ['=', '>', '<', '>=', '<=', '!=', 'LIKE', 'IS', 'EXISTS']
AGG_OPS = ['MAX', 'MIN', 'SUM', 'AVG']
DASC = ['ASC', 'DESC']
def general_pattern(pattern):
    general_pattern_list = []
    for x in pattern.split(" "):
        if x in KEY_KEYWORD_SET:
            general_pattern_list.append(x)
    
    return " ".join(general_pattern_list)

def sub_pattern(pattern):
    general_pattern_list = []
    for x in pattern.split(" "):
        if x in ALL_KEYWORD_SET:
            general_pattern_list.append(x)
    
    return " ".join(general_pattern_list)

def tune_pattern(pattern):
    general_pattern_list = []
    cols_dict = {}
    for x in pattern.split(" "):
        if "{COLUMN" in x:
            if x not in cols_dict:
                cols_dict[x] = COLUMN_SYMBOL.replace("}", str(len(cols_dict))+"}")
            general_pattern_list.append(cols_dict[x])
            continue
            
        if "{VALUE" in x:
            general_pattern_list.append("{VALUE}")
            continue
            
        if x == 'DISTINCT':
            continue
        elif x in DASC:
            general_pattern_list.append("{DASC}")
        elif x in WHERE_OPS:
            general_pattern_list.append("{OP}")
        elif x in AGG_OPS:
            general_pattern_list.append("{AGG}")
        else:
            general_pattern_list.append(x)
    
    return " ".join(general_pattern_list)

# %%
training_question_pattern_pairs = []
training_patterns = set()

pattern_question_dict = defaultdict(list)

# train_qq_pairs
for eid, (question, query, bd_id) in enumerate(train_qq_pairs):
    table = tables[bd_id]
    if eid % 500 == 0:
        print("processing eid: ", eid)
    
    pattern, values, nums, columns = strip_query(query, table)
    question_template = process_question(question, values, nums, columns)
    
    gen_pattern = general_pattern(pattern)
    more_pattern = sub_pattern(pattern)
    tu_pattern = tune_pattern(pattern)
    
    pattern_question_dict[tu_pattern].append(' '.join(question) + " ||| " + 
                                              question_template + " ||| " + more_pattern
                                              + " ||| " + query)
#     print("\n--------------------------------------")
#     print("original question: {}".format(' '.join(question).encode('utf-8')))
#     print("question: {}".format(question_template.encode('utf-8')))
#     print("query: {}".format(query))
#     print("pattern: {}".format(pattern))
#     print("values: {}".format(values))
#     print("nums: {}".format(nums))
#     print("columns: {}".format(columns))
# Out:
# processing eid:  0
# processing eid:  500
# processing eid:  1000
# processing eid:  1500
# processing eid:  2000
# processing eid:  2500
# processing eid:  3000
# processing eid:  3500
# processing eid:  4000
# processing eid:  4500
# processing eid:  5000
# processing eid:  5500
# processing eid:  6000
# processing eid:  6500

# %%
print("total pattern number: {}".format(len(pattern_question_dict)))
pattern_question_dict = sorted(pattern_question_dict.items(), key=lambda kv: len(kv[1]), reverse=True)
# Out:
# total pattern number: 517

# %%
# filter_nums = [762, 275, 241, 204, 202, 164, 98, 59, 55, 48]

# %%
for sql, qts in pattern_question_dict:
#     if len(qts) not in filter_nums:
#         continue
    print("\n--------------------------------------------")
    print("SQL Pattern: {}".format(sql))
    print("count: {}".format(len(qts)))
    for qt in qts:
        q, q_template, sql, sql_more = qt.split("|||")
        print("question: ", q.replace("""'""", "").replace("""``""", ''))
#         print("question: ", q_template.replace("""'""", "").replace("""``""", ''))
        print("SQL: {} \n".format(sql_more))
#     for qt in qts:
#         q, q_template, sql_temp, sql_more = qt.split("|||")
#     #     print("question: ", q_template)
#     #     print("sql_temp: ", sql_temp)
#     #     print("sql_more: ", sql_more)
#         if sql == 'SELECT {COLUMN0} {FROM} WHERE {COLUMN4} {OP} {VALUE_STR} AND {COLUMN5} {OP} {VALUE_STR}':
#             print(sql_more)
# Out:
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count: 794
# question:  What are the distinct creation years of the departments managed by a secretary born in state Alabama  ?
# SQL:  SELECT DISTINCT T1.creation FROM department AS T1 JOIN management AS T2 ON T1.department_id  =  T2.department_id JOIN head AS T3 ON T2.head_id  =  T3.head_id WHERE T3.born_state  =  'Alabama'
#
# question:  What are the distinct ages of the heads who are acting ?
# SQL:  SELECT DISTINCT T1.age FROM management AS T2 JOIN head AS T1 ON T1.head_id  =  T2.head_id WHERE T2.temporary_acting  =  'Yes'
#
# question:  Please show the themes of competitions with host cities having populations larger than 1000 .
# SQL:  SELECT T2.Theme FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID WHERE T1.Population  >  1000
#
# question:  What are the themes of competitions that have corresponding host cities with more than 1000 residents ?
# SQL:  SELECT T2.Theme FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID WHERE T1.Population  >  1000
#
# question:  Find id of the candidate whose email is stanley.monahan @ example.org ?
# SQL:  SELECT T2.candidate_id FROM people AS T1 JOIN candidates AS T2 ON T1.person_id = T2.candidate_id WHERE T1.email_address = "stanley.monahan@example.org"
#
# question:  What is the id of the candidate whose email is stanley.monahan @ example.org ?
# SQL:  SELECT T2.candidate_id FROM people AS T1 JOIN candidates AS T2 ON T1.person_id = T2.candidate_id WHERE T1.email_address = "stanley.monahan@example.org"
#
# question:  Find id of candidates whose assessment code is  Pass  ?
# SQL:  SELECT candidate_id FROM candidate_assessments WHERE asessment_outcome_code = "Pass"
#
# question:  What are the ids of the candidates that have an outcome code of Pass ?
# SQL:  SELECT candidate_id FROM candidate_assessments WHERE asessment_outcome_code = "Pass"
#
# question:  Find the cell mobile number of the candidates whose assessment code is  Fail  ?
# SQL:  SELECT T3.cell_mobile_number FROM candidates AS T1 JOIN candidate_assessments AS T2 ON T1.candidate_id = T2.candidate_id JOIN people AS T3 ON T1.candidate_id = T3.person_id WHERE T2.asessment_outcome_code = "Fail"
#
# question:  What are the cell phone numbers of the candidates that received an assessment code of  Fail  ?
# SQL:  SELECT T3.cell_mobile_number FROM candidates AS T1 JOIN candidate_assessments AS T2 ON T1.candidate_id = T2.candidate_id JOIN people AS T3 ON T1.candidate_id = T3.person_id WHERE T2.asessment_outcome_code = "Fail"
#
# question:  What are the id of students who registered course 301 ?
# SQL:  SELECT student_id FROM student_course_attendance WHERE course_id  =  301
#
# question:  What are the ids of the students who registered for course 301 ?
# SQL:  SELECT student_id FROM student_course_attendance WHERE course_id  =  301
#
# question:  Give me the dates when the max temperature was higher than 85 .
# SQL:  SELECT date FROM weather WHERE max_temperature_f  >  85
#
# question:  What are the dates with a maximum temperature higher than 85 ?
# SQL:  SELECT date FROM weather WHERE max_temperature_f  >  85
#
# question:  What are the names of stations that have latitude lower than 37.5 ?
# SQL:  SELECT name FROM station WHERE lat  <  37.5
#
# question:  What are the names of all stations with a latitude smaller than 37.5 ?
# SQL:  SELECT name FROM station WHERE lat  <  37.5
#
# question:  Return the unique name for stations that have ever had 7 bikes available .
# SQL:  SELECT DISTINCT T1.name FROM station AS T1 JOIN status AS T2 ON T1.id  =  T2.station_id WHERE T2.bikes_available  =  7
#
# question:  What are the different names for each station that has ever had 7 bikes available ?
# SQL:  SELECT DISTINCT T1.name FROM station AS T1 JOIN status AS T2 ON T1.id  =  T2.station_id WHERE T2.bikes_available  =  7
#
# question:  List all the distinct stations from which a trip of duration below 100 started .
# SQL:  SELECT DISTINCT start_station_name FROM trip WHERE duration  <  100
#
# question:  What are all the different start station names for a trip that lasted less than 100 ?
# SQL:  SELECT DISTINCT start_station_name FROM trip WHERE duration  <  100
#
# question:  Find all the zip codes in which the max dew point have never reached 70 .
# SQL:  SELECT DISTINCT zip_code FROM weather EXCEPT SELECT DISTINCT zip_code FROM weather WHERE max_dew_point_f  >=  70
#
# question:  What are all the different zip codes that have a maximum dew point that was always below 70 ?
# SQL:  SELECT DISTINCT zip_code FROM weather EXCEPT SELECT DISTINCT zip_code FROM weather WHERE max_dew_point_f  >=  70
#
# question:  What are the distinct publishers of publications with price higher than 5000000 ?
# SQL:  SELECT DISTINCT Publisher FROM publication WHERE Price  >  5000000
#
# question:  Show writers who have published a book with price more than 4000000 .
# SQL:  SELECT T1.Writer FROM book AS T1 JOIN publication AS T2 ON T1.Book_ID  =  T2.Book_ID WHERE T2.Price  >  4000000
#
# question:  What are the names of musicals with nominee  Bob Fosse  ?
# SQL:  SELECT Name FROM musical WHERE Nominee  =  "Bob Fosse"
#
# question:  Return the names of musicals who have the nominee Bob Fosse .
# SQL:  SELECT Name FROM musical WHERE Nominee  =  "Bob Fosse"
#
# question:  Find the emails of the user named  Mary  .
# SQL:  SELECT email FROM user_profiles WHERE name  =  'Mary'
#
# question:  What is the partition id of the user named  Iron Man  .
# SQL:  SELECT partitionid FROM user_profiles WHERE name  =  'Iron Man'
#
# question:  What is the attribute data type of the attribute with name  Green  ?
# SQL:  SELECT attribute_data_type FROM Attribute_Definitions WHERE attribute_name  =  "Green"
#
# question:  Find the attribute data type for the attribute named  Green  .
# SQL:  SELECT attribute_data_type FROM Attribute_Definitions WHERE attribute_name  =  "Green"
#
# question:  Find the names of all the products whose stock number starts with  2  .
# SQL:  SELECT catalog_entry_name FROM catalog_contents WHERE product_stock_number LIKE "2%"
#
# question:  Which catalog contents have a product stock number that starts from  2  ? Show the catalog entry names .
# SQL:  SELECT catalog_entry_name FROM catalog_contents WHERE product_stock_number LIKE "2%"
#
# question:  Find the names of catalog entries with level number 8 .
# SQL:  SELECT t1.catalog_entry_name FROM Catalog_Contents AS t1 JOIN Catalog_Contents_Additional_Attributes AS t2 ON t1.catalog_entry_id  =  t2.catalog_entry_id WHERE t2.catalog_level_number  =  "8"
#
# question:  What are the names of catalog entries with level number 8 ?
# SQL:  SELECT t1.catalog_entry_name FROM Catalog_Contents AS t1 JOIN Catalog_Contents_Additional_Attributes AS t2 ON t1.catalog_entry_id  =  t2.catalog_entry_id WHERE t2.catalog_level_number  =  "8"
#
# question:  Name all the products with next entry ID greater than 8 .
# SQL:  SELECT catalog_entry_name FROM catalog_contents WHERE next_entry_id  >  8
#
# question:  What are the catalog entry names of the products with next entry ID above 8 ?
# SQL:  SELECT catalog_entry_name FROM catalog_contents WHERE next_entry_id  >  8
#
# question:  Show ids for all aircrafts with more than 1000 distance .
# SQL:  SELECT aid FROM Aircraft WHERE distance  >  1000
#
# question:  What are the ids of all aircrafts that can cover a distance of more than 1000 ?
# SQL:  SELECT aid FROM Aircraft WHERE distance  >  1000
#
# question:  Show ids for all employees with at least 100000 salary .
# SQL:  SELECT eid FROM Employee WHERE salary  >  100000
#
# question:  What is the id of every employee who has at least a salary of 100000 ?
# SQL:  SELECT eid FROM Employee WHERE salary  >  100000
#
# question:  Show all flight number from Los Angeles .
# SQL:  SELECT flno FROM Flight WHERE origin  =  "Los Angeles"
#
# question:  What are the numbers of all flights coming from Los Angeles ?
# SQL:  SELECT flno FROM Flight WHERE origin  =  "Los Angeles"
#
# question:  Show origins of all flights with destination Honolulu .
# SQL:  SELECT origin FROM Flight WHERE destination  =  "Honolulu"
#
# question:  What are the origins of all flights that are headed to Honolulu ?
# SQL:  SELECT origin FROM Flight WHERE destination  =  "Honolulu"
#
# question:  Show flight number for all flights with more than 2000 distance .
# SQL:  SELECT flno FROM Flight WHERE distance  >  2000
#
# question:  What are the numbers of all flights that can cover a distance of more than 2000 ?
# SQL:  SELECT flno FROM Flight WHERE distance  >  2000
#
# question:  What is the aircraft name for the flight with number 99
# SQL:  SELECT T2.name FROM Flight AS T1 JOIN Aircraft AS T2 ON T1.aid  =  T2.aid WHERE T1.flno  =  99
#
# question:  What is the name of the aircraft that was on flight number 99 ?
# SQL:  SELECT T2.name FROM Flight AS T1 JOIN Aircraft AS T2 ON T1.aid  =  T2.aid WHERE T1.flno  =  99
#
# question:  Show all flight numbers with aircraft Airbus A340-300 .
# SQL:  SELECT T1.flno FROM Flight AS T1 JOIN Aircraft AS T2 ON T1.aid  =  T2.aid WHERE T2.name  =  "Airbus A340-300"
#
# question:  What are the flight numbers for the aircraft Airbus A340-300 ?
# SQL:  SELECT T1.flno FROM Flight AS T1 JOIN Aircraft AS T2 ON T1.aid  =  T2.aid WHERE T2.name  =  "Airbus A340-300"
#
# question:  Show all allergies with type food .
# SQL:  SELECT DISTINCT allergy FROM Allergy_type WHERE allergytype  =  "food"
#
# question:  What are all the different food allergies ?
# SQL:  SELECT DISTINCT allergy FROM Allergy_type WHERE allergytype  =  "food"
#
# question:  What is the type of allergy Cat ?
# SQL:  SELECT allergytype FROM Allergy_type WHERE allergy  =  "Cat"
#
# question:  What is allergy type of a cat allergy ?
# SQL:  SELECT allergytype FROM Allergy_type WHERE allergy  =  "Cat"
#
# question:  Show student ids for all male students .
# SQL:  SELECT StuID FROM Student WHERE Sex  =  'M'
#
# question:  What are the student ids for all male students ?
# SQL:  SELECT StuID FROM Student WHERE Sex  =  'M'
#
# question:  Show all student ids who are older than 20 .
# SQL:  SELECT StuID FROM Student WHERE age  >  20
#
# question:  What are the student ids for students over 20 years old ?
# SQL:  SELECT StuID FROM Student WHERE age  >  20
#
# question:  Which city does the student whose last name is  Kim  live in ?
# SQL:  SELECT city_code FROM Student WHERE LName  =  "Kim"
#
# question:  Give the city that the student whose family name is Kim lives in .
# SQL:  SELECT city_code FROM Student WHERE LName  =  "Kim"
#
# question:  Who is the advisor of student with ID 1004 ?
# SQL:  SELECT Advisor FROM Student WHERE StuID  =  1004
#
# question:  Who advises student 1004 ?
# SQL:  SELECT Advisor FROM Student WHERE StuID  =  1004
#
# question:  List Aerosmith s albums .
# SQL:  SELECT T1.title FROM albums AS T1 JOIN artists AS T2 ON  T1.artist_id = T2.id WHERE T2.name = "Aerosmith";
#
# question:  What are the titles of all the Aerosmith albums ?
# SQL:  SELECT T1.title FROM albums AS T1 JOIN artists AS T2 ON  T1.artist_id = T2.id WHERE T2.name = "Aerosmith";
#
# question:  List the name of albums that are released by aritist whose name has Led
# SQL:  SELECT T2.title FROM artists AS T1 JOIN albums AS T2 ON T1.id  =  T2.artist_id WHERE T1.name LIKE '%Led%'
#
# question:  What is the title of the album that was released by the artist whose name has the phrase Led  ?
# SQL:  SELECT T2.title FROM artists AS T1 JOIN albums AS T2 ON T1.id  =  T2.artist_id WHERE T1.name LIKE '%Led%'
#
# question:  Who is the composer of track Fast As a Shark ?
# SQL:  SELECT composer FROM tracks WHERE name = "Fast As a Shark";
#
# question:  What is the composer who created the track  Fast As a Shark  ?
# SQL:  SELECT composer FROM tracks WHERE name = "Fast As a Shark";
#
# question:  How long does track Fast As a Shark has ?
# SQL:  SELECT milliseconds FROM tracks WHERE name = "Fast As a Shark";
#
# question:  How many milliseconds long is Fast As a Shark ?
# SQL:  SELECT milliseconds FROM tracks WHERE name = "Fast As a Shark";
#
# question:  What is title of album which track Balls to the Wall belongs to ?
# SQL:  SELECT T1.title FROM albums AS T1 JOIN tracks AS T2 ON T1.id = T2.genre_id WHERE T2.name = "Balls to the Wall";
#
# question:  What is the name of the album that has the track Ball to the Wall ?
# SQL:  SELECT T1.title FROM albums AS T1 JOIN tracks AS T2 ON T1.id = T2.genre_id WHERE T2.name = "Balls to the Wall";
#
# question:  List name of all tracks in Balls to the Wall .
# SQL:  SELECT T2.name FROM albums AS T1 JOIN tracks AS T2 ON T1.id = T2.genre_id WHERE T1.title = "Balls to the Wall";
#
# question:  What is the name of all tracks in the album named Balls to the Wall ?
# SQL:  SELECT T2.name FROM albums AS T1 JOIN tracks AS T2 ON T1.id = T2.genre_id WHERE T1.title = "Balls to the Wall";
#
# question:  How much is the track Fast As a Shark ?
# SQL:  SELECT unit_price FROM tracks WHERE name = "Fast As a Shark";
#
# question:  What is the unit price of the tune  Fast As a Shark  ?
# SQL:  SELECT unit_price FROM tracks WHERE name = "Fast As a Shark";
#
# question:  List the names of editors who are older than 25 .
# SQL:  SELECT Name FROM editor WHERE Age  >  25
#
# question:  Show the names of editors that are on the committee of journals with sales bigger than 3000 .
# SQL:  SELECT T2.Name FROM journal_committee AS T1 JOIN editor AS T2 ON T1.Editor_ID  =  T2.Editor_ID JOIN journal AS T3 ON T1.Journal_ID  =  T3.Journal_ID WHERE T3.Sales  >  3000
#
# question:  Show other account details for account with name 338 .
# SQL:  SELECT other_account_details FROM Accounts WHERE account_name  =  "338"
#
# question:  What are the other account details for the account with the name 338 ?
# SQL:  SELECT other_account_details FROM Accounts WHERE account_name  =  "338"
#
# question:  What are the names for tracks without a race in class GT  .
# SQL:  SELECT name FROM track EXCEPT SELECT T2.name FROM race AS T1 JOIN track AS T2 ON T1.track_id  =  T2.track_id WHERE T1.class  =  'GT'
#
# question:  Give the names of tracks that do not have a race in the class GT  .
# SQL:  SELECT name FROM track EXCEPT SELECT T2.name FROM race AS T1 JOIN track AS T2 ON T1.track_id  =  T2.track_id WHERE T1.class  =  'GT'
#
# question:  Which address do not have any member with the black membership card ?
# SQL:  SELECT address FROM member EXCEPT SELECT address FROM member WHERE Membership_card  =  'Black'
#
# question:  Find the title of all the albums of the artist  AC/DC  .
# SQL:  SELECT Title FROM ALBUM AS T1 JOIN ARTIST AS T2 ON T1.ArtistId  =  T2.ArtistId WHERE T2.Name  =  "AC/DC"
#
# question:  What are the titles of albums by the artist  AC/DC  ?
# SQL:  SELECT Title FROM ALBUM AS T1 JOIN ARTIST AS T2 ON T1.ArtistId  =  T2.ArtistId WHERE T2.Name  =  "AC/DC"
#
# question:  Which artist does the album  Balls to the Wall  belong to ?
# SQL:  SELECT T2.Name FROM ALBUM AS T1 JOIN ARTIST AS T2 ON T1.ArtistId  =  T2.ArtistId WHERE T1.Title  =  "Balls to the Wall"
#
# question:  Find the name of the artist who made the album  Balls to the Wall  .
# SQL:  SELECT T2.Name FROM ALBUM AS T1 JOIN ARTIST AS T2 ON T1.ArtistId  =  T2.ArtistId WHERE T1.Title  =  "Balls to the Wall"
#
# question:  What city does the employee who helps the customer with postal code 70174 live in ?
# SQL:  SELECT T2.City FROM CUSTOMER AS T1 JOIN EMPLOYEE AS T2 ON T1.SupportRepId  =  T2.EmployeeId WHERE T1.PostalCode  =  "70174"
#
# question:  Find the cities corresponding to employees who help customers with the postal code 70174 .
# SQL:  SELECT T2.City FROM CUSTOMER AS T1 JOIN EMPLOYEE AS T2 ON T1.SupportRepId  =  T2.EmployeeId WHERE T1.PostalCode  =  "70174"
#
# question:  Find all the customer last names that do not have invoice totals larger than 20 .
# SQL:  SELECT LastName FROM CUSTOMER EXCEPT SELECT T1.LastName FROM CUSTOMER AS T1 JOIN Invoice AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T2.total  >  20
#
# question:  What are the last names of customers without invoice totals exceeding 20 ?
# SQL:  SELECT LastName FROM CUSTOMER EXCEPT SELECT T1.LastName FROM CUSTOMER AS T1 JOIN Invoice AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T2.total  >  20
#
# question:  Find the first names of all customers that live in Brazil and have an invoice .
# SQL:  SELECT DISTINCT T1.FirstName FROM CUSTOMER AS T1 JOIN INVOICE AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T1.country  =  "Brazil"
#
# question:  What are the different first names for customers from Brazil who have also had an invoice ?
# SQL:  SELECT DISTINCT T1.FirstName FROM CUSTOMER AS T1 JOIN INVOICE AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T1.country  =  "Brazil"
#
# question:  Find the address of all customers that live in Germany and have invoice .
# SQL:  SELECT DISTINCT T1.Address FROM CUSTOMER AS T1 JOIN INVOICE AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T1.country  =  "Germany"
#
# question:  What are the addresses of customers living in Germany who have had an invoice ?
# SQL:  SELECT DISTINCT T1.Address FROM CUSTOMER AS T1 JOIN INVOICE AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T1.country  =  "Germany"
#
# question:  What are the birth dates of employees living in Edmonton ?
# SQL:  SELECT BirthDate FROM EMPLOYEE WHERE City  =  "Edmonton"
#
# question:  Find the birth dates corresponding to employees who live in the city of Edmonton .
# SQL:  SELECT BirthDate FROM EMPLOYEE WHERE City  =  "Edmonton"
#
# question:  What are the customer phone numbers under the policy  Life Insurance  ?
# SQL:  SELECT customer_phone FROM available_policies WHERE policy_type_code  =  "Life Insurance"
#
# question:  What are the phone numbers of customers using the policy with the code  Life Insurance  ?
# SQL:  SELECT customer_phone FROM available_policies WHERE policy_type_code  =  "Life Insurance"
#
# question:  What are all the policy types of the customer named  Dayana Robel  ?
# SQL:  SELECT DISTINCT t3.policy_type_code FROM customers AS t1 JOIN customers_policies AS t2 ON t1.customer_id  =  t2.customer_id JOIN available_policies AS t3 ON t2.policy_id  =  t3.policy_id WHERE t1.customer_name  =  "Dayana Robel"
#
# question:  Tell me the types of the policy used by the customer named  Dayana Robel  .
# SQL:  SELECT DISTINCT t3.policy_type_code FROM customers AS t1 JOIN customers_policies AS t2 ON t1.customer_id  =  t2.customer_id JOIN available_policies AS t3 ON t2.policy_id  =  t3.policy_id WHERE t1.customer_name  =  "Dayana Robel"
#
# question:  Find the IDs of customers whose name contains  Diana  .
# SQL:  SELECT customer_id FROM customers WHERE customer_name LIKE "%Diana%"
#
# question:  What are the IDs of customers who have  Diana  in part of their names ?
# SQL:  SELECT customer_id FROM customers WHERE customer_name LIKE "%Diana%"
#
# question:  Find the names of the chip models that are not used by any phone with full accreditation type .
# SQL:  SELECT model_name FROM chip_model EXCEPT SELECT chip_model FROM phone WHERE Accreditation_type  =  'Full'
#
# question:  Show the players from college UCLA .
# SQL:  SELECT Player FROM match_season WHERE College  =  "UCLA"
#
# question:  Who are the players from UCLA ?
# SQL:  SELECT Player FROM match_season WHERE College  =  "UCLA"
#
# question:  Which players are from Indonesia ?
# SQL:  SELECT T2.Player FROM country AS T1 JOIN match_season AS T2 ON T1.Country_id  =  T2.Country WHERE T1.Country_name  =  "Indonesia"
#
# question:  Who are the players from Indonesia ?
# SQL:  SELECT T2.Player FROM country AS T1 JOIN match_season AS T2 ON T1.Country_id  =  T2.Country WHERE T1.Country_name  =  "Indonesia"
#
# question:  What are the distinct positions of the players from a country whose capital is Dublin ?
# SQL:  SELECT DISTINCT T2.Position FROM country AS T1 JOIN match_season AS T2 ON T1.Country_id  =  T2.Country WHERE T1.Capital  =  "Dublin"
#
# question:  Give the different positions of players who play for the country with the capital Dublin .
# SQL:  SELECT DISTINCT T2.Position FROM country AS T1 JOIN match_season AS T2 ON T1.Country_id  =  T2.Country WHERE T1.Capital  =  "Dublin"
#
# question:  Show the positions of the players from the team with name  Ryley Goldner  .
# SQL:  SELECT T1.Position FROM match_season AS T1 JOIN team AS T2 ON T1.Team  =  T2.Team_id WHERE T2.Name  =  "Ryley Goldner"
#
# question:  Return the positions of players on the team Ryley Goldner .
# SQL:  SELECT T1.Position FROM match_season AS T1 JOIN team AS T2 ON T1.Team  =  T2.Team_id WHERE T2.Name  =  "Ryley Goldner"
#
# question:  What are the countries of mountains with height bigger than 5000 ?
# SQL:  SELECT Country FROM mountain WHERE Height  >  5000
#
# question:  Return the countries of the mountains that have a height larger than 5000 .
# SQL:  SELECT Country FROM mountain WHERE Height  >  5000
#
# question:  Show the distinct names of mountains climbed by climbers from country  West Germany  .
# SQL:  SELECT DISTINCT T2.Name FROM climber AS T1 JOIN mountain AS T2 ON T1.Mountain_ID  =  T2.Mountain_ID WHERE T1.Country  =  "West Germany"
#
# question:  What are the different names of mountains ascended by climbers from the country of West Germany ?
# SQL:  SELECT DISTINCT T2.Name FROM climber AS T1 JOIN mountain AS T2 ON T1.Mountain_ID  =  T2.Mountain_ID WHERE T1.Country  =  "West Germany"
#
# question:  Show the times used by climbers to climb mountains in Country Uganda .
# SQL:  SELECT T1.Time FROM climber AS T1 JOIN mountain AS T2 ON T1.Mountain_ID  =  T2.Mountain_ID WHERE T2.Country  =  "Uganda"
#
# question:  What are the times used by climbers who climbed mountains in the country of Uganda ?
# SQL:  SELECT T1.Time FROM climber AS T1 JOIN mountain AS T2 ON T1.Mountain_ID  =  T2.Mountain_ID WHERE T2.Country  =  "Uganda"
#
# question:  What are the names of body builders whose total score is higher than 300 ?
# SQL:  SELECT T2.Name FROM body_builder AS T1 JOIN people AS T2 ON T1.People_ID  =  T2.People_ID WHERE T1.Total  >  300
#
# question:  What are the heights of body builders with total score smaller than 315 ?
# SQL:  SELECT T2.Height FROM body_builder AS T1 JOIN people AS T2 ON T1.People_ID  =  T2.People_ID WHERE T1.Total  <  315
#
# question:  What are the total scores of the body builders whose birthday contains the string  January  ?
# SQL:  SELECT T1.total FROM body_builder AS T1 JOIN people AS T2 ON T1.people_id  =  T2.people_id WHERE T2.Birth_Date LIKE "%January%";
#
# question:  What are the names of representatives with more than 10000 votes in election ?
# SQL:  SELECT T2.Name FROM election AS T1 JOIN representative AS T2 ON T1.Representative_ID  =  T2.Representative_ID WHERE Votes  >  10000
#
# question:  Show the short names of the buildings managed by  Emma  .
# SQL:  SELECT building_short_name FROM Apartment_Buildings WHERE building_manager	 =  "Emma"
#
# question:  Which buildings does  Emma  manage ? Give me the short names of the buildings .
# SQL:  SELECT building_short_name FROM Apartment_Buildings WHERE building_manager	 =  "Emma"
#
# question:  Return the apartment numbers of the apartments with type code  Flat  .
# SQL:  SELECT apt_number FROM Apartments WHERE apt_type_code  =  "Flat"
#
# question:  Which apartments have type code  Flat  ? Give me their apartment numbers .
# SQL:  SELECT apt_number FROM Apartments WHERE apt_type_code  =  "Flat"
#
# question:  Return the date of birth for all the guests with gender code  Male  .
# SQL:  SELECT date_of_birth FROM Guests WHERE gender_code  =  "Male"
#
# question:  What are dates of birth of all the guests whose gender is  Male  ?
# SQL:  SELECT date_of_birth FROM Guests WHERE gender_code  =  "Male"
#
# question:  What is the booking status code of the apartment with apartment number  Suite 634  ?
# SQL:  SELECT T1.booking_status_code FROM Apartment_Bookings AS T1 JOIN Apartments AS T2 ON T1.apt_id  =  T2.apt_id WHERE T2.apt_number  =  "Suite 634"
#
# question:  Tell me the booking status code for the apartment with number  Suite 634  .
# SQL:  SELECT T1.booking_status_code FROM Apartment_Bookings AS T1 JOIN Apartments AS T2 ON T1.apt_id  =  T2.apt_id WHERE T2.apt_number  =  "Suite 634"
#
# question:  Show the distinct apartment numbers of the apartments that have bookings with status code  Confirmed  .
# SQL:  SELECT DISTINCT T2.apt_number FROM Apartment_Bookings AS T1 JOIN Apartments AS T2 ON T1.apt_id  =  T2.apt_id WHERE T1.booking_status_code  =  "Confirmed"
#
# question:  Which apartments have bookings with status code  Confirmed  ? Return their apartment numbers .
# SQL:  SELECT DISTINCT T2.apt_number FROM Apartment_Bookings AS T1 JOIN Apartments AS T2 ON T1.apt_id  =  T2.apt_id WHERE T1.booking_status_code  =  "Confirmed"
#
# question:  Show the facility codes of apartments with more than 4 bedrooms .
# SQL:  SELECT T1.facility_code FROM Apartment_Facilities AS T1 JOIN Apartments AS T2 ON T1.apt_id  =  T2.apt_id WHERE T2.bedroom_count  >  4
#
# question:  What are the facility codes of the apartments with more than four bedrooms ?
# SQL:  SELECT T1.facility_code FROM Apartment_Facilities AS T1 JOIN Apartments AS T2 ON T1.apt_id  =  T2.apt_id WHERE T2.bedroom_count  >  4
#
# question:  Show the addresses of the buildings that have apartments with more than 2 bathrooms .
# SQL:  SELECT T1.building_address FROM Apartment_Buildings AS T1 JOIN Apartments AS T2 ON T1.building_id  =  T2.building_id WHERE T2.bathroom_count  >  2
#
# question:  Which buildings have apartments that have more than two bathrooms ? Give me the addresses of the buildings .
# SQL:  SELECT T1.building_address FROM Apartment_Buildings AS T1 JOIN Apartments AS T2 ON T1.building_id  =  T2.building_id WHERE T2.bathroom_count  >  2
#
# question:  What is the average attendance of stadiums with capacity percentage higher than 100 % ?
# SQL:  SELECT average_attendance FROM stadium WHERE capacity_percentage  >  100
#
# question:  What is the season of the game which causes the player Walter Samuel  to get injured ?
# SQL:  SELECT T1.season FROM game AS T1 JOIN injury_accident AS T2 ON T1.id  =  T2.game_id WHERE T2.player  =  'Walter Samuel'
#
# question:  Show the dates of performances with attending members whose roles are  Violin  .
# SQL:  SELECT T3.Date FROM member_attendance AS T1 JOIN member AS T2 ON T1.Member_ID  =  T2.Member_ID JOIN performance AS T3 ON T1.Performance_ID  =  T3.Performance_ID WHERE T2.Role  =  "Violin"
#
# question:  Find the buildings which have rooms with capacity more than 50 .
# SQL:  SELECT DISTINCT building FROM classroom WHERE capacity  >  50
#
# question:  What are the distinct buildings with capacities of greater than 50 ?
# SQL:  SELECT DISTINCT building FROM classroom WHERE capacity  >  50
#
# question:  Find the department name of the instructor whose name contains Soisalon  .
# SQL:  SELECT dept_name FROM instructor WHERE name LIKE '%Soisalon%'
#
# question:  What is the name of the department with an instructure who has a name like Soisalon  ?
# SQL:  SELECT dept_name FROM instructor WHERE name LIKE '%Soisalon%'
#
# question:  What is the id of the instructor who advises of all students from History department ?
# SQL:  SELECT i_id FROM advisor AS T1 JOIN student AS T2 ON T1.s_id  =  T2.id WHERE T2.dept_name  =  'History'
#
# question:  Give id of the instructor who advises students in the History department .
# SQL:  SELECT i_id FROM advisor AS T1 JOIN student AS T2 ON T1.s_id  =  T2.id WHERE T2.dept_name  =  'History'
#
# question:  Find the name of the instructors who taught C Programming course before .
# SQL:  SELECT T1.name FROM instructor AS T1 JOIN teaches AS T2 ON T1.id  =  T2.id JOIN course AS T3 ON T2.course_id  =  T3.course_id WHERE T3.title  =  'C Programming'
#
# question:  What are the names of instructors who have taught C Programming courses ?
# SQL:  SELECT T1.name FROM instructor AS T1 JOIN teaches AS T2 ON T1.id  =  T2.id JOIN course AS T3 ON T2.course_id  =  T3.course_id WHERE T3.title  =  'C Programming'
#
# question:  Find the name of students who took some course offered by Statistics department .
# SQL:  SELECT T3.name FROM course AS T1 JOIN takes AS T2 ON T1.course_id  =  T2.course_id JOIN student AS T3 ON T2.id  =  T3.id WHERE T1.dept_name  =  'Statistics'
#
# question:  What are the names of students who have taken Statistics courses ?
# SQL:  SELECT T3.name FROM course AS T1 JOIN takes AS T2 ON T1.course_id  =  T2.course_id JOIN student AS T3 ON T2.id  =  T3.id WHERE T1.dept_name  =  'Statistics'
#
# question:  Find the names of all instructors in computer science department
# SQL:  SELECT name FROM instructor WHERE dept_name  =  'Comp. Sci.'
#
# question:  What are the names of all instructors in the Comp . Sci . department ?
# SQL:  SELECT name FROM instructor WHERE dept_name  =  'Comp. Sci.'
#
# question:  List the dates of debates with number of audience bigger than 150
# SQL:  SELECT Date FROM debate WHERE Num_of_Audience  >  150
#
# question:  Show the names of people that are on affirmative side of debates with number of audience bigger than 200 .
# SQL:  SELECT T3.Name FROM debate_people AS T1 JOIN debate AS T2 ON T1.Debate_ID  =  T2.Debate_ID JOIN people AS T3 ON T1.Affirmative  =  T3.People_ID WHERE T2.Num_of_Audience  >  200
#
# question:  Find all the policy type codes associated with the customer  Dayana Robel
# SQL:  SELECT policy_type_code FROM policies AS t1 JOIN customers AS t2 ON t1.customer_id  =  t2.customer_id WHERE t2.customer_details  =  "Dayana Robel"
#
# question:  What are the type codes of the policies used by the customer  Dayana Robel  ?
# SQL:  SELECT policy_type_code FROM policies AS t1 JOIN customers AS t2 ON t1.customer_id  =  t2.customer_id WHERE t2.customer_details  =  "Dayana Robel"
#
# question:  Find the names of the customers who have an deputy policy .
# SQL:  SELECT DISTINCT t2.customer_details FROM policies AS t1 JOIN customers AS t2 ON t1.customer_id  =  t2.customer_id WHERE t1.policy_type_code  =  "Deputy"
#
# question:  Which customers have an insurance policy with the type code  Deputy  ? Give me the customer details .
# SQL:  SELECT DISTINCT t2.customer_details FROM policies AS t1 JOIN customers AS t2 ON t1.customer_id  =  t2.customer_id WHERE t1.policy_type_code  =  "Deputy"
#
# question:  What is the description of the claim status  Open  ?
# SQL:  SELECT claim_status_description FROM claims_processing_stages WHERE claim_status_name  =  "Open"
#
# question:  Find the description of the claim status  Open  .
# SQL:  SELECT claim_status_description FROM claims_processing_stages WHERE claim_status_name  =  "Open"
#
# question:  Show all church names except for those that had a wedding in year 2015 .
# SQL:  SELECT name FROM church EXCEPT SELECT T1.name FROM church AS T1 JOIN wedding AS T2 ON T1.church_id  =  T2.church_id WHERE T2.year  =  2015
#
# question:  Show all artist names who did nt have an exhibition in 2004 .
# SQL:  SELECT name FROM artist EXCEPT SELECT T2.name FROM exhibition AS T1 JOIN artist AS T2 ON T1.artist_id  =  T2.artist_id WHERE T1.year  =  2004
#
# question:  What are the names of artists who did not have an exhibition in 2004 ?
# SQL:  SELECT name FROM artist EXCEPT SELECT T2.name FROM exhibition AS T1 JOIN artist AS T2 ON T1.artist_id  =  T2.artist_id WHERE T1.year  =  2004
#
# question:  Find the id of the item whose title is  orange  .
# SQL:  SELECT i_id FROM item WHERE title  =  "orange"
#
# question:  Find the names of goods that receive a rating of 10 .
# SQL:  SELECT T1.title FROM item AS T1 JOIN review AS T2 ON T1.i_id  =  T2.i_id WHERE T2.rating  =  10
#
# question:  Find the titles of items that received any rating below 5 .
# SQL:  SELECT T1.title FROM item AS T1 JOIN review AS T2 ON T1.i_id  =  T2.i_id WHERE T2.rating  <  5
#
# question:  Show the names of players coached by the rank 1 coach .
# SQL:  SELECT T3.Player_name FROM player_coach AS T1 JOIN coach AS T2 ON T1.Coach_ID  =  T2.Coach_ID JOIN player AS T3 ON T1.Player_ID  =  T3.Player_ID WHERE T2.Rank  =  1
#
# question:  What are the distinct hometowns of gymnasts with total points more than 57.5 ?
# SQL:  SELECT DISTINCT T2.Hometown FROM gymnast AS T1 JOIN people AS T2 ON T1.Gymnast_ID  =  T2.People_ID WHERE T1.Total_Points  >  57.5
#
# question:  Give the different hometowns of gymnasts that have a total point score of above 57.5 .
# SQL:  SELECT DISTINCT T2.Hometown FROM gymnast AS T1 JOIN people AS T2 ON T1.Gymnast_ID  =  T2.People_ID WHERE T1.Total_Points  >  57.5
#
# question:  What is the checking balance of the account whose owner’s name contains the substring ‘ee’ ?
# SQL:  SELECT T2.balance FROM accounts AS T1 JOIN checking AS T2 ON T1.custid  =  T2.custid WHERE T1.name LIKE '%ee%'
#
# question:  Find the balance of the checking account belonging to an owner whose name contains ee  .
# SQL:  SELECT T2.balance FROM accounts AS T1 JOIN checking AS T2 ON T1.custid  =  T2.custid WHERE T1.name LIKE '%ee%'
#
# question:  What distinct accelerator names are compatible with the browswers that have market share higher than 15 ?
# SQL:  SELECT DISTINCT T1.name FROM web_client_accelerator AS T1 JOIN accelerator_compatible_browser AS T2 ON T2.accelerator_id  =  T1.id JOIN browser AS T3 ON T2.browser_id  =  T3.id WHERE T3.market_share  >  15;
#
# question:  What are the elimination moves of wrestlers whose team is  Team Orton  ?
# SQL:  SELECT Elimination_Move FROM Elimination WHERE Team  =  "Team Orton"
#
# question:  Return the elimination movies of wrestlers on Team Orton .
# SQL:  SELECT Elimination_Move FROM Elimination WHERE Team  =  "Team Orton"
#
# question:  Show times of elimination of wrestlers with days held more than 50 .
# SQL:  SELECT T1.Time FROM elimination AS T1 JOIN wrestler AS T2 ON T1.Wrestler_ID  =  T2.Wrestler_ID WHERE T2.Days_held  >  50
#
# question:  What are the times of elimination for wrestlers with over 50 days held ?
# SQL:  SELECT T1.Time FROM elimination AS T1 JOIN wrestler AS T2 ON T1.Wrestler_ID  =  T2.Wrestler_ID WHERE T2.Days_held  >  50
#
# question:  What are the names of wrestlers days held less than 100 ?
# SQL:  SELECT Name FROM wrestler WHERE Days_held  <  100
#
# question:  Return the names of wrestlers with fewer than 100 days held .
# SQL:  SELECT Name FROM wrestler WHERE Days_held  <  100
#
# question:  Show the names of all the donors except those whose donation amount less than 9 .
# SQL:  SELECT donator_name FROM endowment EXCEPT SELECT donator_name FROM endowment WHERE amount  <  9
#
# question:  Show the names of buildings except for those having an institution founded in 2003 .
# SQL:  SELECT name FROM building EXCEPT SELECT T1.name FROM building AS T1 JOIN institution AS T2 ON T1.building_id  =  T2.building_id WHERE T2.founded  =  2003
#
# question:  Show all the locations where no cinema has capacity over 800 .
# SQL:  SELECT LOCATION FROM cinema EXCEPT SELECT LOCATION FROM cinema WHERE capacity  >  800
#
# question:  Are the customers holding coupons with amount 500 bad or good ?
# SQL:  SELECT T1.good_or_bad_customer FROM customers AS T1 JOIN discount_coupons AS T2 ON T1.coupon_id  =  T2.coupon_id WHERE T2.coupon_amount  =  500
#
# question:  What is the product description of the product booked with an amount of 102.76 ?
# SQL:  SELECT T2.product_description FROM products_booked AS T1 JOIN products_for_hire AS T2 ON T1.product_id  =  T2.product_id WHERE T1.booked_amount  =  102.76
#
# question:  What are the names of products whose availability equals to 1 ?
# SQL:  SELECT T2.product_name FROM view_product_availability AS T1 JOIN products_for_hire AS T2 ON T1.product_id  =  T2.product_id WHERE T1.available_yn  =  1
#
# question:  What are the daily hire costs for the products with substring Book  in its name ?
# SQL:  SELECT daily_hire_cost FROM Products_for_hire WHERE product_name LIKE '%Book%'
#
# question:  List the distinct carriers of phones with memories bigger than 32 .
# SQL:  SELECT DISTINCT Carrier FROM phone WHERE Memory_in_G  >  32
#
# question:  Show the names of phones that are on market with number of shops greater than 50 .
# SQL:  SELECT T3.Name FROM phone_market AS T1 JOIN market AS T2 ON T1.Market_ID  =  T2.Market_ID JOIN phone AS T3 ON T1.Phone_ID  =  T3.Phone_ID WHERE T2.Num_of_shops  >  50
#
# question:  Show all headquarters without a company in banking industry .
# SQL:  SELECT headquarters FROM company EXCEPT SELECT headquarters FROM company WHERE main_industry  =  'Banking'
#
# question:  What are the headquarters without companies that are in the banking industry ?
# SQL:  SELECT headquarters FROM company EXCEPT SELECT headquarters FROM company WHERE main_industry  =  'Banking'
#
# question:  Show the manager name for gas stations belonging to the ExxonMobil company .
# SQL:  SELECT T3.manager_name FROM station_company AS T1 JOIN company AS T2 ON T1.company_id  =  T2.company_id JOIN gas_station AS T3 ON T1.station_id  =  T3.station_id WHERE T2.company  =  'ExxonMobil'
#
# question:  What are the names of the managers for gas stations that are operated by the ExxonMobil company ?
# SQL:  SELECT T3.manager_name FROM station_company AS T1 JOIN company AS T2 ON T1.company_id  =  T2.company_id JOIN gas_station AS T3 ON T1.station_id  =  T3.station_id WHERE T2.company  =  'ExxonMobil'
#
# question:  Show all locations where a gas station for company with market value greater than 100 is located .
# SQL:  SELECT T3.location FROM station_company AS T1 JOIN company AS T2 ON T1.company_id  =  T2.company_id JOIN gas_station AS T3 ON T1.station_id  =  T3.station_id WHERE T2.market_value  >  100
#
# question:  What are the locations that have gas stations owned by a company with a market value greater than 100 ?
# SQL:  SELECT T3.location FROM station_company AS T1 JOIN company AS T2 ON T1.company_id  =  T2.company_id JOIN gas_station AS T3 ON T1.station_id  =  T3.station_id WHERE T2.market_value  >  100
#
# question:  List the distinct positions of pilots older than 30 .
# SQL:  SELECT DISTINCT POSITION FROM pilot WHERE Age  >  30
#
# question:  Show the fleet series of the aircrafts flied by pilots younger than 34
# SQL:  SELECT T2.Fleet_Series FROM pilot_record AS T1 JOIN aircraft AS T2 ON T1.Aircraft_ID  =  T2.Aircraft_ID JOIN pilot AS T3 ON T1.Pilot_ID  =  T3.Pilot_ID WHERE T3.Age  <  34
#
# question:  What is the description of document status code working  ?
# SQL:  SELECT document_status_description FROM Ref_Document_Status WHERE document_status_code = "working";
#
# question:  What is the description of document type Paper  ?
# SQL:  SELECT document_type_description FROM Ref_Document_Types WHERE document_type_code = "Paper";
#
# question:  What is the shipping agent code of shipping agent UPS ?
# SQL:  SELECT shipping_agent_code FROM Ref_Shipping_Agents WHERE shipping_agent_name = "UPS";
#
# question:  What is the description of role code ED ?
# SQL:  SELECT role_description FROM ROLES WHERE role_code = "ED";
#
# question:  What is the role of the employee named Koby ?
# SQL:  SELECT T1.role_description FROM ROLES AS T1 JOIN Employees AS T2 ON T1.role_code = T2.role_code WHERE T2.employee_name = "Koby";
#
# question:  List the document type code for the document with the id 2 .
# SQL:  SELECT document_type_code FROM Documents WHERE document_id = 2;
#
# question:  What is the receipt date of the document with id 3 ?
# SQL:  SELECT receipt_date FROM Documents WHERE document_id = 3;
#
# question:  What is the mail date of the document with id 7 ?
# SQL:  SELECT mailing_date FROM Documents_Mailed WHERE document_id = 7;
#
# question:  What is draft detail of the document with id 7 ?
# SQL:  SELECT draft_details FROM Document_Drafts WHERE document_id = 7;
#
# question:  find all dependent names who have a spouse relation with some employee .
# SQL:  SELECT Dependent_name FROM dependent WHERE relationship  =  'Spouse'
#
# question:  Find the names of departments that are located in Houston .
# SQL:  SELECT t1.dname FROM department AS t1 JOIN dept_locations AS t2 ON t1.dnumber  =  t2.dnumber WHERE t2.dlocation  =  'Houston'
#
# question:  what are the event details of the services that have the type code Marriage  ?
# SQL:  SELECT T1.event_details FROM EVENTS AS T1 JOIN Services AS T2 ON T1.Service_ID  =  T2.Service_ID WHERE T2.Service_Type_Code  =  'Marriage'
#
# question:  Which events id does not have any participant with detail Kenyatta Kuhn  ?
# SQL:  SELECT event_id FROM EVENTS EXCEPT SELECT T1.event_id FROM Participants_in_Events AS T1 JOIN Participants AS T2 ON T1.Participant_ID  =  T2.Participant_ID WHERE Participant_Details  =  'Kenyatta Kuhn'
#
# question:  Find the names of all races held in 2017 .
# SQL:  SELECT name FROM races WHERE YEAR = 2017
#
# question:  What are the names of all the races that occurred in the year 2017 ?
# SQL:  SELECT name FROM races WHERE YEAR = 2017
#
# question:  Show names of technicians who are assigned to repair machines with value point more than 70 .
# SQL:  SELECT T3.Name FROM repair_assignment AS T1 JOIN machine AS T2 ON T1.machine_id  =  T2.machine_id JOIN technician AS T3 ON T1.technician_ID  =  T3.technician_ID WHERE T2.value_points  >  70
#
# question:  What are the names of the technicians that are assigned to repair machines with more point values than 70 ?
# SQL:  SELECT T3.Name FROM repair_assignment AS T1 JOIN machine AS T2 ON T1.machine_id  =  T2.machine_id JOIN technician AS T3 ON T1.technician_ID  =  T3.technician_ID WHERE T2.value_points  >  70
#
# question:  Report the name of all campuses in Los Angeles county .
# SQL:  SELECT campus FROM campuses WHERE county  =  "Los Angeles"
#
# question:  What campuses are located in the county of Los Angeles ?
# SQL:  SELECT campus FROM campuses WHERE county  =  "Los Angeles"
#
# question:  What are the names of all campuses located at Chico ?
# SQL:  SELECT campus FROM campuses WHERE LOCATION  =  "Chico"
#
# question:  What campuses are located in Chico ?
# SQL:  SELECT campus FROM campuses WHERE LOCATION  =  "Chico"
#
# question:  Find all the campuses opened in 1958 .
# SQL:  SELECT campus FROM campuses WHERE YEAR  =  1958
#
# question:  What are the campuses that opened in 1958 ?
# SQL:  SELECT campus FROM campuses WHERE YEAR  =  1958
#
# question:  Find the name of the campuses opened before 1800 .
# SQL:  SELECT campus FROM campuses WHERE YEAR  <  1800
#
# question:  What campuses opened before 1800 ?
# SQL:  SELECT campus FROM campuses WHERE YEAR  <  1800
#
# question:  List the campuses in Los Angeles county .
# SQL:  SELECT campus FROM campuses WHERE county  =  "Los Angeles"
#
# question:  What campuses are in Los Angeles county ?
# SQL:  SELECT campus FROM campuses WHERE county  =  "Los Angeles"
#
# question:  Find the titles of all movies directed by steven spielberg .
# SQL:  SELECT title FROM Movie WHERE director = 'Steven Spielberg'
#
# question:  What are the names of all movies directed by Steven Spielberg ?
# SQL:  SELECT title FROM Movie WHERE director = 'Steven Spielberg'
#
# question:  Who is the director of movie Avatar ?
# SQL:  SELECT director FROM Movie WHERE title  = 'Avatar'
#
# question:  Who directed Avatar ?
# SQL:  SELECT director FROM Movie WHERE title  = 'Avatar'
#
# question:  What is the id of the reviewer whose name has substring “Mike” ?
# SQL:  SELECT rID FROM Reviewer WHERE name LIKE "%Mike%"
#
# question:  What is the id of the reviewer whose name includes the word  Mike  ?
# SQL:  SELECT rID FROM Reviewer WHERE name LIKE "%Mike%"
#
# question:  What is the reviewer id of Daniel Lewis ?
# SQL:  SELECT rID FROM Reviewer WHERE name  =  "Daniel Lewis"
#
# question:  What is the id of the reviewer named Daniel Lewis ?
# SQL:  SELECT rID FROM Reviewer WHERE name  =  "Daniel Lewis"
#
# question:  Find the names of all reviewers who have ratings with a NULL value for the date .
# SQL:  SELECT DISTINCT name FROM Reviewer AS T1 JOIN Rating AS T2 ON T1.rID  =  T2.rID WHERE ratingDate  =  "null"
#
# question:  What are the different names of all reviewers whose ratings do not have a date field ?
# SQL:  SELECT DISTINCT name FROM Reviewer AS T1 JOIN Rating AS T2 ON T1.rID  =  T2.rID WHERE ratingDate  =  "null"
#
# question:  Find the names of all reviewers who rated Gone with the Wind .
# SQL:  SELECT DISTINCT T3.name FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID JOIN Reviewer AS T3 ON T1.rID  =  T3.rID WHERE T2.title  =  'Gone with the Wind'
#
# question:  What are the names of all the different reviewers who rates Gone with the Wind ?
# SQL:  SELECT DISTINCT T3.name FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID JOIN Reviewer AS T3 ON T1.rID  =  T3.rID WHERE T2.title  =  'Gone with the Wind'
#
# question:  Find the names of all directors whose movies are rated by Sarah Martinez .
# SQL:  SELECT DISTINCT T2.director FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID JOIN Reviewer AS T3 ON T1.rID  =  T3.rID WHERE T3.name  =  'Sarah Martinez'
#
# question:  What are the names of all directors whose movies have been reviewed by Sarah Martinez ?
# SQL:  SELECT DISTINCT T2.director FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID JOIN Reviewer AS T3 ON T1.rID  =  T3.rID WHERE T3.name  =  'Sarah Martinez'
#
# question:  Find the titles of all movies not reviewed by Chris Jackson .
# SQL:  SELECT DISTINCT title FROM Movie EXCEPT SELECT T2.title FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID JOIN Reviewer AS T3 ON T1.rID  =  T3.rID WHERE T3.name  =  'Chris Jackson'
#
# question:  What are the titles of all movies that were not reviewed by Chris Jackson ?
# SQL:  SELECT DISTINCT title FROM Movie EXCEPT SELECT T2.title FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID JOIN Reviewer AS T3 ON T1.rID  =  T3.rID WHERE T3.name  =  'Chris Jackson'
#
# question:  Find the names of reviewers who had given higher than 3 star ratings .
# SQL:  SELECT T2.name FROM Rating AS T1 JOIN Reviewer AS T2 ON T1.rID  =  T2.rID WHERE T1.stars  >  3
#
# question:  What are the names of the reviewers who have rated a movie more than 3 stars before ?
# SQL:  SELECT T2.name FROM Rating AS T1 JOIN Reviewer AS T2 ON T1.rID  =  T2.rID WHERE T1.stars  >  3
#
# question:  What are the ids of the movies that are not reviewed by Brittany Harris .
# SQL:  SELECT mID FROM Rating EXCEPT SELECT T1.mID FROM Rating AS T1 JOIN Reviewer AS T2 ON T1.rID  =  T2.rID WHERE T2.name  =  "Brittany Harris"
#
# question:  What are the ids of all moviest hat have not been reviewed by Britanny Harris ?
# SQL:  SELECT mID FROM Rating EXCEPT SELECT T1.mID FROM Rating AS T1 JOIN Reviewer AS T2 ON T1.rID  =  T2.rID WHERE T2.name  =  "Brittany Harris"
#
# question:  find the ids of reviewers who did not give 4 star .
# SQL:  SELECT rID FROM Rating EXCEPT SELECT rID FROM Rating WHERE stars  =  4
#
# question:  What are the ids of all reviewers who did not give 4 stars ?
# SQL:  SELECT rID FROM Rating EXCEPT SELECT rID FROM Rating WHERE stars  =  4
#
# question:  What are the percentage of hispanics in cities with the black percentage higher than 10 ?
# SQL:  SELECT Hispanic FROM city WHERE Black  >  10
#
# question:  Return the hispanic percentage for cities in which the black percentage is greater than 10 .
# SQL:  SELECT Hispanic FROM city WHERE Black  >  10
#
# question:  Show the crime rate of counties with a city having white percentage more than 90 .
# SQL:  SELECT T2.Crime_rate FROM city AS T1 JOIN county_public_safety AS T2 ON T1.County_ID  =  T2.County_ID WHERE T1.White  >  90
#
# question:  What are the crime rates of counties that contain cities that have white percentages of over 90 ?
# SQL:  SELECT T2.Crime_rate FROM city AS T1 JOIN county_public_safety AS T2 ON T1.County_ID  =  T2.County_ID WHERE T1.White  >  90
#
# question:  What is the decor of room Recluse and defiance ?
# SQL:  SELECT decor FROM Rooms WHERE roomName  =  "Recluse and defiance";
#
# question:  Return the decor of the room named  Recluse and defiance  .
# SQL:  SELECT decor FROM Rooms WHERE roomName  =  "Recluse and defiance";
#
# question:  Find the name of rooms booked by some customers whose first name contains ROY .
# SQL:  SELECT T2.roomName FROM Reservations AS T1 JOIN Rooms AS T2 ON T1.Room  =  T2.RoomId WHERE firstname LIKE '%ROY%'
#
# question:  What are the name of rooms booked by customers whose first name has  ROY  in part ?
# SQL:  SELECT T2.roomName FROM Reservations AS T1 JOIN Rooms AS T2 ON T1.Room  =  T2.RoomId WHERE firstname LIKE '%ROY%'
#
# question:  what are the details of the cmi masters that have the cross reference code Tax  ?
# ...
#
#
# --------------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {OP} {VALUE}
# count: 1
# question:  How many documents were shipped by USPS ?
# SQL:  SELECT count(*) FROM Ref_Shipping_Agents JOIN Documents ON Documents.shipping_agent_code = Ref_Shipping_Agents.shipping_agent_code WHERE Ref_Shipping_Agents.shipping_agent_name = "USPS";
#
#
# --------------------------------------------
# SQL Pattern: SELECT , COUNT ( ) {FROM} GROUP BY ORDER BY COUNT ( ) {DASC} LIMIT {VALUE}
# count: 1
# question:  Which shipping agent shipped the most documents ? List the shipping agent name and the number of documents .
# SQL:  SELECT Ref_Shipping_Agents.shipping_agent_name , count(Documents.document_id) FROM Ref_Shipping_Agents JOIN Documents ON Documents.shipping_agent_code = Ref_Shipping_Agents.shipping_agent_code GROUP BY Ref_Shipping_Agents.shipping_agent_code ORDER BY count(Documents.document_id) DESC LIMIT 1;
#
#
# --------------------------------------------
# SQL Pattern: SELECT {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count: 1
# question:  What address was the document with id 4 mailed to ?
# SQL:  SELECT Addresses.address_details FROM Addresses JOIN Documents_Mailed ON Documents_Mailed.mailed_to_address_id = Addresses.address_id WHERE document_id = 4;
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {OP} {VALUE}
# count: 1
# question:  List the document ids of documents with the status done and type Paper , which not shipped by the shipping agent named USPS .
# SQL:  SELECT document_id FROM Documents WHERE document_status_code  =  "done" AND document_type_code = "Paper" EXCEPT SELECT document_id FROM Documents JOIN Ref_Shipping_Agents ON Documents.shipping_agent_code = Ref_Shipping_Agents.shipping_agent_code WHERE Ref_Shipping_Agents.shipping_agent_name = "USPS";
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {OP} {VALUE}
# count: 1
# question:  List document id of documents status is done and document type is Paper and the document is shipped by shipping agent named USPS .
# SQL:  SELECT document_id FROM Documents WHERE document_status_code  =  "done" AND document_type_code = "Paper" INTERSECT SELECT document_id FROM Documents JOIN Ref_Shipping_Agents ON Documents.shipping_agent_code = Ref_Shipping_Agents.shipping_agent_code WHERE Ref_Shipping_Agents.shipping_agent_name = "USPS";
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( {COLUMN1} ) {DASC} LIMIT {VALUE}
# count: 1
# question:  Which document has the most draft copies ? List its document id and number of draft copies .
# SQL:  SELECT document_id , count(copy_number) FROM Draft_Copies GROUP BY document_id ORDER BY count(copy_number) DESC LIMIT 1;
#
#
# --------------------------------------------
# SQL Pattern: SELECT , COUNT ( * ) {FROM} GROUP BY , , ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count: 1
# question:  Which employee has showed up in most circulation history documents . List the employee s name and the number of drafts and copies .
# SQL:  SELECT Employees.employee_name , count(*) FROM Employees JOIN Circulation_History ON Circulation_History.employee_id = Employees.employee_id GROUP BY Circulation_History.document_id , Circulation_History.draft_number , Circulation_History.copy_number ORDER BY count(*) DESC LIMIT 1;
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} HAVING COUNT ( {COLUMN0} ) BETWEEN {VALUE} AND {VALUE}
# count: 1
# question:  Which major has between 2 and 30 number of students ? List major and the number of students .
# SQL:  SELECT Major ,  count(*) FROM Student GROUP BY Major HAVING count(Major) BETWEEN 2 AND 30;
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {VALUE} AND {COLUMN4} {OP} {VALUE}
# count: 1
# question:  List all female students age is older than 18 who is not majoring in 600 . List students  first name and last name .
# SQL:  SELECT Fname , Lname FROM Student WHERE Age  >  18 AND Major != 600 AND Sex = 'F';
#
#
# --------------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} GROUP BY HAVING {OP} {VALUE}
# count: 1
# question:  How many restaurant is the Sandwich type restaurant ?
# SQL:  SELECT count(*) FROM Restaurant JOIN Type_Of_Restaurant ON Restaurant.ResID =  Type_Of_Restaurant.ResID JOIN Restaurant_Type ON Type_Of_Restaurant.ResTypeID = Restaurant_Type.ResTypeID GROUP BY Type_Of_Restaurant.ResTypeID HAVING Restaurant_Type.ResTypeName = 'Sandwich'
#
#
# --------------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {OP} {VALUE} AND {OP} {VALUE}
# count: 1
# question:  How long does student Linda Smith spend on the restaurant in total ?
# SQL:  SELECT sum(Spent) FROM Student JOIN Visits_Restaurant ON Student.StuID = Visits_Restaurant.StuID WHERE Student.Fname = "Linda" AND Student.Lname = "Smith";
#
#
# --------------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {OP} {VALUE} AND {OP} {VALUE} AND {OP} {VALUE}
# count: 1
# question:  How many times has the student Linda Smith visited Subway ?
# SQL:  SELECT count(*) FROM Student JOIN Visits_Restaurant ON Student.StuID = Visits_Restaurant.StuID JOIN Restaurant ON Visits_Restaurant.ResID = Restaurant.ResID WHERE Student.Fname = "Linda" AND Student.Lname = "Smith" AND Restaurant.ResName = "Subway";
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {OP} {VALUE} AND {OP} {VALUE} AND {OP} {VALUE}
# count: 1
# question:  When did Linda Smith visit Subway ?
# SQL:  SELECT TIME FROM Student JOIN Visits_Restaurant ON Student.StuID = Visits_Restaurant.StuID JOIN Restaurant ON Visits_Restaurant.ResID = Restaurant.ResID WHERE Student.Fname = "Linda" AND Student.Lname = "Smith" AND Restaurant.ResName = "Subway";
#
#
# --------------------------------------------
# SQL Pattern: SELECT , {AGG} ( ) {FROM} GROUP BY ORDER BY {AGG} ( ) {DASC} LIMIT {VALUE}
# count: 1
# question:  At which restaurant did the students spend the least amount of time ? List restaurant and the time students spent on in total .
# SQL:  SELECT Restaurant.ResName ,  sum(Visits_Restaurant.Spent) FROM Visits_Restaurant JOIN Restaurant ON Visits_Restaurant.ResID = Restaurant.ResID GROUP BY Restaurant.ResID ORDER BY sum(Visits_Restaurant.Spent) ASC LIMIT 1;
#
#
# --------------------------------------------
# SQL Pattern: SELECT , {FROM} GROUP BY ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count: 1
# question:  Which student visited restaurant most often ? List student s first name and last name .
# SQL:  SELECT Student.Fname , Student.Lname FROM Student JOIN Visits_Restaurant ON Student.StuID = Visits_Restaurant.StuID GROUP BY Student.StuID ORDER BY count(*) DESC LIMIT 1;
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count: 1
# question:  Which assets have 2 parts and have less than 2 fault logs ? List the asset id and detail .
# SQL:  SELECT T1.asset_id ,  T1.asset_details FROM Assets AS T1 JOIN Asset_Parts AS T2 ON T1.asset_id  =  T2.asset_id GROUP BY T1.asset_id HAVING count(*)  =  2 INTERSECT SELECT T1.asset_id ,  T1.asset_details FROM Assets AS T1 JOIN Fault_Log AS T2 ON T1.asset_id  =  T2.asset_id GROUP BY T1.asset_id HAVING count(*)  <  2
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} UNION SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count: 1
# question:  Which third party companies have at least 2 maintenance engineers or have at least 2 maintenance contracts ? List the company id and name .
# SQL:  SELECT T1.company_id ,  T1.company_name FROM Third_Party_Companies AS T1 JOIN Maintenance_Engineers AS T2 ON T1.company_id  =  T2.company_id GROUP BY T1.company_id HAVING count(*)  >=  2 UNION SELECT T3.company_id ,  T3.company_name FROM Third_Party_Companies AS T3 JOIN Maintenance_Contracts AS T4 ON T3.company_id  =  T4.maintenance_contract_company_id GROUP BY T3.company_id HAVING count(*)  >=  2
#
#
# --------------------------------------------
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2}
# count: 1
# question:  Find the number of trains for each station , as well as the station network name and services .
# SQL:  SELECT count(*) ,  t1.network_name ,  t1.services FROM station AS t1 JOIN route AS t2 ON t1.id  =  t2.station_id GROUP BY t2.station_id
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2} HAVING {AGG} ( {COLUMN3} ) {OP} {VALUE}
# count: 1
# question:  Find the id and local authority of the station whose maximum precipitation is higher than 50 .
# SQL:  SELECT t2.id ,  t2.local_authority FROM weekly_weather AS t1 JOIN station AS t2 ON t1.station_id  =  t2.id GROUP BY t1.station_id HAVING max(t1.precipitation)  >  50
#
#
# --------------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} ORDER BY {COLUMN0} {DASC} LIMIT {VALUE}
# count: 1
# question:  find the total market rate of the furnitures that have the top 2 market shares .
# SQL:  SELECT sum(market_rate) FROM furniture ORDER BY market_rate DESC LIMIT 2
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * )
# count: 1
# question:  What is the name of each camera lens and the number of photos taken by it ? Order the result by the count of photos .
# SQL:  SELECT T1.name ,  count(*) FROM camera_lens AS T1 JOIN photos AS T2 ON T1.id  =  T2.camera_lens_id GROUP BY T1.id ORDER BY count(*)
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN1} , {COLUMN2} {DASC}
# count: 1
# question:  list the names of the companies with more than 200 sales in the descending order of sales and profits .
# SQL:  SELECT name FROM company WHERE Sales_in_Billion  >  200 ORDER BY Sales_in_Billion ,  Profits_in_Billion DESC
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} ORDER BY {COLUMN0}
# count: 1
# question:  Show the names of products that are in at least two events in ascending alphabetical order of product name .
# SQL:  SELECT T1.Product_Name FROM Products AS T1 JOIN Products_in_Events AS T2 ON T1.Product_ID  =  T2.Product_ID GROUP BY T1.Product_Name HAVING COUNT(*)  >=  2 ORDER BY T1.Product_Name
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {VALUE}
# count: 1
# question:  In which year are there festivals both inside the United States  and outside the United States  ?
# SQL:  SELECT YEAR FROM festival_detail WHERE LOCATION  =  'United States' INTERSECT SELECT YEAR FROM festival_detail WHERE LOCATION != 'United States'
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) BETWEEN {VALUE} AND {VALUE}
# count: 1
# question:  Which events have the number of notes between one and three ? List the event id and the property id .
# SQL:  SELECT T1.Customer_Event_ID  ,  T1.property_id FROM Customer_Events AS T1 JOIN Customer_Event_Notes AS T2 ON T1.Customer_Event_ID  =  T2.Customer_Event_ID GROUP BY T1.customer_event_id HAVING count(*) BETWEEN 1 AND 3
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE}
# count: 1
# question:  What are the country names , area and population which has both roller coasters with speed higher
# SQL:  SELECT T1.name ,  T1.area ,  T1.population FROM country AS T1 JOIN roller_coaster AS T2 ON T1.Country_ID  =  T2.Country_ID WHERE T2.speed  >  60 INTERSECT SELECT T1.name ,  T1.area ,  T1.population FROM country AS T1 JOIN roller_coaster AS T2 ON T1.Country_ID  =  T2.Country_ID WHERE T2.speed  <  55
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM} ORDER BY {COLUMN3}
# count: 1
# question:  List the id , country , city and name of the airports ordered alphabetically by the name .
# SQL:  SELECT id ,  country ,  city ,  name FROM airport ORDER BY name
#
#
# --------------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count: 1
# question:  What is the average and maximum number of total passengers for train stations in London or Glasgow ?
# SQL:  SELECT avg(total_passengers) ,  max(total_passengers) FROM station WHERE LOCATION  =  'London' OR LOCATION  =  'Glasgow'
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) , {AGG} ( {COLUMN2} ) {FROM} GROUP BY {COLUMN0}
# count: 1
# question:  Show all locations and the total number of platforms and passengers for all train stations in each location .
# SQL:  SELECT LOCATION ,  sum(number_of_platforms) ,  sum(total_passengers) FROM station GROUP BY LOCATION
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ORDER BY {COLUMN1} {DASC}
# count: 1
# question:  Show all train names and times in stations in London in descending order by train time .
# SQL:  SELECT T3.name ,  T3.time FROM train_station AS T1 JOIN station AS T2 ON T1.station_id  =  T2.station_id JOIN train AS T3 ON T3.train_id  =  T1.train_id WHERE T2.location  =  'London' ORDER BY T3.time DESC
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2} , {COLUMN3}
# count: 1
# question:  List the names and locations of all stations ordered by their yearly entry exit and interchange amounts .
# SQL:  SELECT name ,  LOCATION FROM station ORDER BY Annual_entry_exit ,  Annual_interchanges
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ORDER BY {COLUMN0}
# count: 1
# question:  List the name , nationality and id of all male architects ordered by their names lexicographically .
# SQL:  SELECT name ,  nationality ,  id FROM architect WHERE gender  =  'male' ORDER BY name
#
#
# --------------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM}
# count: 1
# question:  What is the maximum length in meters for the bridges and what are the architects  names ?
# SQL:  SELECT max(T1.length_meters) ,  T2.name FROM bridge AS T1 JOIN architect AS T2 ON T1.architect_id  =  T2.id
#
#
# --------------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} UNION SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count: 1
# question:  What are the ids , names and genders of the architects who built two bridges or one mill ?
# SQL:  SELECT T1.id ,  T1.name ,  T1.gender FROM architect AS T1 JOIN bridge AS T2 ON T1.id  =  T2.architect_id GROUP BY T1.id HAVING count(*)  =  2 UNION SELECT T1.id ,  T1.name ,  T1.gender FROM architect AS T1 JOIN mill AS T2 ON T1.id  =  T2.architect_id GROUP BY T1.id HAVING count(*)  =  1

# %%
for sql, qts in pattern_question_dict:
    print("\n")
    print("SQL Pattern: {}".format(sql))
    print("count: ", len(qts))
# Out:
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  794
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM}
# count:  275
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  260
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM}
# count:  241
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  239
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM}
# count:  210
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0}
# count:  208
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  206
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN1} {DASC} LIMIT {VALUE}
# count:  184
#
#
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) {FROM}
# count:  166
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  151
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  149
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  134
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  112
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN1} {DASC}
# count:  108
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM}
# count:  98
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN1} {FROM}
# count:  84
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count:  83
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE}
# count:  79
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  75
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  70
#
#
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} GROUP BY {COLUMN0}
# count:  64
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM}
# count:  63
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  61
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE}
# count:  60
#
#
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  58
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {VALUE}
# count:  55
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1}
# count:  53
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN0}
# count:  51
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2} {DASC} LIMIT {VALUE}
# count:  50
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM}
# count:  48
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0}
# count:  47
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN0} {DASC}
# count:  41
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  39
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  39
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE}
# count:  38
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN1} LIMIT {VALUE}
# count:  37
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN1}
# count:  35
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  34
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN0} {FROM}
# count:  33
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN1}
# count:  31
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN2} {OP} {VALUE}
# count:  30
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE}
# count:  30
#
#
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0}
# count:  29
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} BETWEEN {VALUE} AND {VALUE}
# count:  27
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM}
# count:  27
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  26
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  25
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} OR {COLUMN2} {OP} {VALUE}
# count:  25
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  25
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  25
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN1} {DASC} LIMIT {VALUE}
# count:  24
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN1} ) {DASC} LIMIT {VALUE}
# count:  23
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2} LIMIT {VALUE}
# count:  22
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2} {DASC}
# count:  22
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  22
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE}
# count:  21
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0}
# count:  20
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN2} {DASC} LIMIT {VALUE}
# count:  19
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  19
#
#
# SQL Pattern: SELECT * {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  18
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE}
# count:  17
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM}
# count:  17
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN0} {DASC} LIMIT {VALUE}
# count:  17
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN2} {FROM}
# count:  16
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  16
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN0}
# count:  16
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} {FROM}
# count:  15
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} NOT IN ( SELECT {COLUMN2} {FROM}
# count:  15
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2}
# count:  15
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC}
# count:  15
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  15
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN0}
# count:  15
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  14
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE}
# count:  14
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM}
# count:  14
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN2}
# count:  13
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  13
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  13
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) LIMIT {VALUE}
# count:  12
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN3} {DASC} LIMIT {VALUE}
# count:  12
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN1} ) {OP} {VALUE}
# count:  12
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  12
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2} HAVING COUNT ( * ) {OP} {VALUE}
# count:  12
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  12
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} OR {COLUMN0} {OP} {VALUE}
# count:  12
#
#
# SQL Pattern: SELECT * {FROM}
# count:  12
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN3}
# count:  12
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  11
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0}
# count:  11
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN1}
# count:  11
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} ORDER BY {AGG} ( {COLUMN2} ) {DASC} LIMIT {VALUE}
# count:  11
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  11
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  10
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN1}
# count:  10
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} NOT IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  10
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count:  10
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN0} {DASC}
# count:  10
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  10
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} UNION SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  10
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} ( SELECT {AGG} ( {COLUMN0} ) {FROM}
# count:  10
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) LIMIT {VALUE}
# count:  10
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} )
# count:  10
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING {AGG} ( {COLUMN2} ) {OP} {VALUE}
# count:  9
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE}
# count:  9
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN1} {FROM}
# count:  9
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  9
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} UNION SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  8
#
#
# SQL Pattern: SELECT ( {COLUMN0} ) {FROM}
# count:  8
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE} OR {COLUMN0} {OP} {VALUE}
# count:  8
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN1}
# count:  8
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} BETWEEN {VALUE} AND {VALUE}
# count:  8
#
#
# SQL Pattern: SELECT * {FROM} ORDER BY {COLUMN0}
# count:  8
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1}
# count:  8
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count:  8
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {AGG} ( {COLUMN2} ) {FROM} GROUP BY {COLUMN1}
# count:  8
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( {COLUMN1} ) {OP} {VALUE}
# count:  8
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  8
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  7
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN1} ) {DASC} LIMIT {VALUE}
# count:  7
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN0}
# count:  7
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0}
# count:  7
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {VALUE}
# count:  7
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN2}
# count:  7
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN2}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} )
# count:  6
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {VALUE}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN1} {DASC}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN1} BETWEEN {VALUE} AND {VALUE}
# count:  6
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} BETWEEN {VALUE} AND {VALUE}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} INTERSECT SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( {COLUMN2} ) {OP} {VALUE}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} OR {COLUMN3} {OP} {VALUE}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} )
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} , {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN1} LIMIT {VALUE}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} EXCEPT SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN3} {DASC}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} UNION SELECT {COLUMN0} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  6
#
#
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN2} {DASC}
# count:  6
#
#
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC}
# count:  6
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  5
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ORDER BY {COLUMN0}
# count:  5
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  5
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  5
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN2} HAVING COUNT ( * ) {OP} {VALUE}
# count:  5
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) , {COLUMN2} {FROM} GROUP BY {COLUMN2}
# count:  5
#
#
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} GROUP BY {COLUMN1}
# count:  5
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN0} {FROM}
# count:  4
#
#
# SQL Pattern: SELECT * {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN0} {FROM}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN3} LIMIT {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {AGG} ( {COLUMN2} ) {FROM} GROUP BY {COLUMN3}
# count:  4
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) {FROM}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {COLUMN1} {FROM} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} )
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} AND {COLUMN4} {OP} {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN1} {FROM}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN2} LIMIT {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN0} {OP} {VALUE} )
# count:  4
#
#
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY {AGG} ( {COLUMN2} ) {DASC} LIMIT {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  4
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN1} ORDER BY {COLUMN2}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN2} ORDER BY {AGG} ( {COLUMN1} ) {DASC} LIMIT {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ORDER BY {COLUMN3}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN2} ) {OP} {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} , {COLUMN1} HAVING COUNT ( {COLUMN2} ) {OP} {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) , {COLUMN2} {FROM} GROUP BY {COLUMN2} ORDER BY {COLUMN2}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ORDER BY {COLUMN4}
# count:  4
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} BETWEEN {VALUE} AND {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) BETWEEN {VALUE} AND {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN0} {DASC}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} )
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN0} {FROM}
# count:  4
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} UNION SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {COLUMN1} {FROM}
# count:  4
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  4
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  4
#
#
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE} )
# count:  4
#
#
# SQL Pattern: SELECT COUNT ( * ) , {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1}
# count:  4
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ORDER BY {COLUMN2}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} , {COLUMN1}
# count:  4
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  3
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE}
# count:  3
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN1} {FROM}
# count:  3
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN1} {FROM}
# count:  3
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN2} {DASC}
# count:  3
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE}
# count:  3
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {VALUE}
# count:  3
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN0} {DASC}
# count:  3
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} ORDER BY {AGG} ( {COLUMN2} ) LIMIT {VALUE}
# count:  3
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {VALUE}
# count:  3
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN0} {DASC} LIMIT {VALUE}
# count:  3
#
#
# SQL Pattern: SELECT {FROM} WHERE {OP} {VALUE}
# count:  3
#
#
# SQL Pattern: SELECT * {FROM} ORDER BY {COLUMN0} {DASC}
# count:  3
#
#
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  3
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  3
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC}
# count:  3
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  3
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} {FROM} ORDER BY {COLUMN1}
# count:  3
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN2} {FROM} GROUP BY {COLUMN2} HAVING {AGG} ( {COLUMN3} ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2} HAVING {AGG} ( {COLUMN3} ) {OP} {VALUE} UNION SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN4} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN1} ) LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN2} {FROM} GROUP BY {COLUMN2} HAVING {AGG} ( {COLUMN3} ) {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {VALUE} AND {COLUMN2} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} EXCEPT SELECT {COLUMN2} {FROM} GROUP BY {COLUMN2} HAVING {AGG} ( {COLUMN3} ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING {AGG} ( {COLUMN2} ) {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {COLUMN3} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN1} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN1} ) {DASC}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} - {COLUMN2} {FROM} ORDER BY {COLUMN1} - {COLUMN2} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN1} ) {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} EXCEPT SELECT {COLUMN2} {FROM} GROUP BY {COLUMN2} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN0} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT ( {COLUMN0} ) {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} EXCEPT SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} INTERSECT SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN1} IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN1} NOT IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} OR {COLUMN2} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {AGG} ( {COLUMN2} ) {FROM} GROUP BY {COLUMN3} ORDER BY {AGG} ( {COLUMN2} ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE} ORDER BY {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( {COLUMN2} ) {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( {COLUMN2} ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( {COLUMN1} ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN0} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ORDER BY {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} ( SELECT {AGG} ( {COLUMN3} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN0} {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE} ORDER BY {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {VALUE} ORDER BY {COLUMN0} {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} ORDER BY {COLUMN0} {DASC}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN3} ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN3} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN0} , {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1} HAVING {AGG} ( {COLUMN0} ) {OP} ( SELECT {AGG} ( {COLUMN0} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} , {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} , {COLUMN1} ORDER BY COUNT ( * ) LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN0} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , COUNT ( * ) {FROM} ORDER BY {COLUMN1} {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) , COUNT ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM} WHERE {COLUMN4} {OP} {VALUE} ORDER BY {COLUMN5}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} ( SELECT {AGG} ( {COLUMN0} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN1} ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} ( SELECT {COLUMN1} {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM} WHERE {COLUMN4} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , COUNT ( * ) {FROM} GROUP BY {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN0} {OP} ( SELECT {AGG} ( {COLUMN0} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN1} + {COLUMN1} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} + {COLUMN1} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} + {COLUMN0} {FROM} ORDER BY {COLUMN0} + {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN0} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} , {COLUMN1} {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN0} + {COLUMN0} {DASC}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} + {COLUMN1} {FROM} WHERE {COLUMN1} {OP} {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} {FROM} ORDER BY {COLUMN1} {DASC}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN3} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN1} ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ORDER BY {COLUMN4} , {COLUMN5}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN2} HAVING COUNT ( * ) {OP} {VALUE} UNION SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN2} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE} GROUP BY {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {COLUMN2}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) , {AGG} ( {COLUMN2} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM} ORDER BY {COLUMN0} , {COLUMN1} , {COLUMN2}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN0} {COLUMN0} ORDER BY {COLUMN1} , {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN0} {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {VALUE} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN2} ORDER BY {AGG} ( {COLUMN1} ) LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {VALUE} GROUP BY {COLUMN2}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {AGG} ( {COLUMN2} ) {FROM} GROUP BY {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN2}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN0} {FROM} WHERE {COLUMN2} {OP} {VALUE} ) GROUP BY {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {COLUMN1} {FROM} ORDER BY {COLUMN2} {DASC} LIMIT {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} IN ( SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM} GROUP BY {COLUMN4} ORDER BY {COLUMN1} {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( {COLUMN0} ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {COLUMN1} + {COLUMN2}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} - {COLUMN3} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) , {COLUMN1} {FROM} GROUP BY {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING {AGG} ( {COLUMN2} ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN0} {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( {COLUMN0} ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} , {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) , {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN2} ORDER BY {AGG} ( {COLUMN3} ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN2} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {COLUMN3} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN1} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN2} ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN2} ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2} ORDER BY {AGG} ( {COLUMN3} ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( {COLUMN0} ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN2} {OP} {VALUE} ORDER BY {COLUMN3} {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN0} {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} NOT {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} , {COLUMN4} {FROM} WHERE {COLUMN0} NOT {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} , {COLUMN4} {FROM} WHERE {COLUMN0} NOT {OP} {VALUE} ORDER BY {COLUMN4}
# count:  2
#
#
# SQL Pattern: SELECT * {FROM} WHERE {COLUMN0} BETWEEN {VALUE} AND {VALUE} AND {COLUMN1} {VALUE} OR {COLUMN2} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN1} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT * {FROM} WHERE {COLUMN0} {OP} {VALUE} OR {COLUMN0} {OP} {VALUE} ORDER BY {COLUMN1} {DASC}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} - {COLUMN2} {FROM} WHERE {COLUMN1} BETWEEN {VALUE} AND {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} BETWEEN {VALUE} AND {VALUE} AND {COLUMN3} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {VALUE} GROUP BY {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} - {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} IN ( SELECT {AGG} ( {COLUMN3} ) {FROM} GROUP BY {COLUMN2} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} ( SELECT {COLUMN0} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT * {FROM} WHERE {COLUMN0} {OP} {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT * {FROM} WHERE {COLUMN0} BETWEEN ( SELECT {AGG} ( {COLUMN0} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT * {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN0} {FROM} WHERE {COLUMN1} BETWEEN {VALUE} AND {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} ( SELECT {COLUMN3} {FROM} WHERE {COLUMN0} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} ( SELECT {COLUMN3} {FROM} WHERE {COLUMN0} {OP} {VALUE} ) AND {COLUMN0} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} IN ( SELECT {COLUMN3} {FROM} WHERE {COLUMN1} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM} WHERE {COLUMN3} {OP} ( SELECT {AGG} ( {COLUMN3} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM} WHERE {COLUMN4} {OP} ( SELECT {AGG} ( {COLUMN4} ) {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} , {AGG} ( {COLUMN2} ) {FROM} GROUP BY {COLUMN3}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} , {COLUMN4} {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , COUNT ( * ) {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN3} ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} UNION SELECT * {FROM} WHERE {COLUMN0} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN0} {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} AND {COLUMN3} BETWEEN {VALUE} AND {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE} UNION SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE} EXCEPT SELECT {COLUMN0} , {COLUMN1} {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN1} {DASC}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY {COLUMN1} {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( {COLUMN1} ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( {COLUMN1} ) LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( {COLUMN2} ) LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} UNION SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN0} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} EXCEPT SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {VALUE} AND {COLUMN0} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( {COLUMN1} ) , COUNT ( * ) {FROM} GROUP BY {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} IN ( SELECT {COLUMN2} {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} ) UNION SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} ) UNION SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} ) UNION SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} ) UNION SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} ) UNION SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} ) UNION SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} ) UNION SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} ) UNION SELECT {COLUMN0} , {COLUMN1} FROM {TABLE} WHERE {COLUMN3} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} UNION SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN2} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE} ) ORDER BY {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} ( SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} AND {COLUMN4} {OP} ( SELECT {AGG} ( {COLUMN4} ) {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN0} {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  2
#
#
# ...
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN3} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN1} ) {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2} - {COLUMN3} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} UNION SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN1} ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN1} ) {OP} {VALUE} OR {AGG} ( {COLUMN1} ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} ( SELECT {COLUMN2} {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT * {FROM} ORDER BY {COLUMN0} {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} ORDER BY {COLUMN1} {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} ( SELECT {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} WHERE {COLUMN0} {OP} {VALUE} GROUP BY {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} INTERSECT SELECT {COLUMN1} {FROM} WHERE {COLUMN0} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} EXCEPT SELECT {COLUMN1} {FROM} WHERE {COLUMN0} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN0} {OP} ( SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) , {COLUMN2} {FROM} GROUP BY {COLUMN2}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT * {FROM} WHERE {COLUMN0} BETWEEN {VALUE} AND {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN1} {DASC} , {COLUMN0} {DASC}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1} HAVING {AGG} ( {COLUMN0} ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) , {COLUMN0} {FROM} GROUP BY {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN2} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN2}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN3} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} BETWEEN {VALUE} AND {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) , COUNT ( {COLUMN1} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} UNION SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {VALUE} ORDER BY {COLUMN3}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) , {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} ( SELECT {COLUMN2} {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN0} , {COLUMN1}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN1} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) , {AGG} ( {COLUMN1} ) , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} - {COLUMN1} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} - {COLUMN3} {OP} ( SELECT {COLUMN2} - {COLUMN3} {FROM} ORDER BY ( {COLUMN2} - {COLUMN3} ) {DASC} LIMIT {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY {AGG} ( {COLUMN2} ) LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN1} , {COLUMN2}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {COLUMN2} OR {COLUMN1} {OP} {COLUMN3}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {COLUMN2} INTERSECT SELECT {COLUMN0} {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {COLUMN2} EXCEPT SELECT {COLUMN0} {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {COLUMN2} UNION SELECT {COLUMN0} {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN0} , {COLUMN0}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING {COLUMN2} {OP} {VALUE} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} OR {COLUMN4} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) , {COLUMN2} {FROM} GROUP BY {COLUMN2}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {COLUMN2} {OP} {VALUE} OR {COLUMN2} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC}
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} ORDER BY COUNT ( * )
# count:  2
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ) AND {COLUMN3} IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ) AND {COLUMN4} IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN3} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ORDER BY {COLUMN3} {DASC} LIMIT {VALUE}
# count:  2
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} BETWEEN {VALUE} AND {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} GROUP BY {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} ( SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} )
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN0}
# count:  1
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN2} {FROM}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} NOT IN ( SELECT {COLUMN4} {FROM}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} GROUP BY {COLUMN2} HAVING {AGG} ( {COLUMN3} ) {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN1} ) {DASC}
# count:  1
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {COLUMN1}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN1} ) {OP} {VALUE} OR {AGG} ( {COLUMN2} ) {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE} )
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} OR {COLUMN4} {OP} {VALUE} ORDER BY {COLUMN5} , {COLUMN6}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ORDER BY {COLUMN1}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN1} ) {OP} {VALUE} ORDER BY {AGG} ( {COLUMN1} ) {DASC}
# count:  1
#
#
# SQL Pattern: SELECT , COUNT ( ) {FROM} GROUP BY HAVING COUNT ( ) {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT , COUNT ( ) {FROM} GROUP BY ORDER BY COUNT ( ) {DASC} LIMIT {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( {COLUMN1} ) {DASC} LIMIT {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT , COUNT ( * ) {FROM} GROUP BY , , ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} HAVING COUNT ( {COLUMN0} ) BETWEEN {VALUE} AND {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {VALUE} AND {COLUMN4} {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} GROUP BY HAVING {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {OP} {VALUE} AND {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {OP} {VALUE} AND {OP} {VALUE} AND {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {OP} {VALUE} AND {OP} {VALUE} AND {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT , {AGG} ( ) {FROM} GROUP BY ORDER BY {AGG} ( ) {DASC} LIMIT {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT , {FROM} GROUP BY ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} UNION SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2} HAVING {AGG} ( {COLUMN3} ) {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} ORDER BY {COLUMN0} {DASC} LIMIT {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * )
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN1} , {COLUMN2} {DASC}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} ORDER BY {COLUMN0}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) BETWEEN {VALUE} AND {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM} ORDER BY {COLUMN3}
# count:  1
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) , {AGG} ( {COLUMN2} ) {FROM} GROUP BY {COLUMN0}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ORDER BY {COLUMN1} {DASC}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2} , {COLUMN3}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ORDER BY {COLUMN0}
# count:  1
#
#
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM}
# count:  1
#
#
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} UNION SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  1

# %%
for sql_template, qts in pattern_question_dict:
    print("\n--------------------------------------")
    print("SQL Pattern: {}".format(sql_template))
    print("count: ", len(qts))
    sql_dict = defaultdict(int)
    for qt in qts:
        q, q_template, sql, sql_more = qt.split("|||")
        sql_dict[sql] += 1
        
    sql_count = sorted(sql_dict.items(), key=lambda kv: kv[1])
    for sql, count in sql_count:
        print("SQL: {}, count: {}".format(sql, count))
# Out:
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  794
# SQL:  SELECT WHERE LIKE , count: 47
# SQL:  SELECT WHERE > , count: 103
# SQL:  SELECT WHERE , count: 644
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM}
# count:  275
# SQL:  SELECT , count: 275
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  260
# SQL:  SELECT WHERE LIKE , count: 15
# SQL:  SELECT WHERE > , count: 22
# SQL:  SELECT WHERE , count: 223
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM}
# count:  241
# SQL:  SELECT COUNT ( ) , count: 241
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  239
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) LIMIT , count: 22
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 217
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM}
# count:  210
# SQL:  SELECT , count: 210
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0}
# count:  208
# SQL:  SELECT COUNT ( ) GROUP BY , count: 208
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  206
# SQL:  SELECT COUNT ( ) WHERE > , count: 14
# SQL:  SELECT COUNT ( ) WHERE LIKE , count: 16
# SQL:  SELECT COUNT ( ) WHERE , count: 176
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN1} {DASC} LIMIT {VALUE}
# count:  184
# SQL:  SELECT ORDER BY LIMIT , count: 25
# SQL:  SELECT ORDER BY DESC LIMIT , count: 159
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) {FROM}
# count:  166
# SQL:  SELECT COUNT ( ) , count: 166
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  151
# SQL:  SELECT WHERE INTERSECT SELECT WHERE > , count: 9
# SQL:  SELECT WHERE > INTERSECT SELECT WHERE , count: 30
# SQL:  SELECT WHERE INTERSECT SELECT WHERE , count: 112
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  149
# SQL:  SELECT WHERE LIKE , count: 2
# SQL:  SELECT WHERE > , count: 29
# SQL:  SELECT WHERE , count: 118
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  134
# SQL:  SELECT GROUP BY HAVING COUNT ( ) > , count: 62
# SQL:  SELECT GROUP BY HAVING COUNT ( ) , count: 72
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  112
# SQL:  SELECT ( ) WHERE LIKE , count: 2
# SQL:  SELECT ( ) WHERE > , count: 9
# SQL:  SELECT ( ) WHERE , count: 101
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN1} {DASC}
# count:  108
# SQL:  SELECT ORDER BY , count: 48
# SQL:  SELECT ORDER BY DESC , count: 60
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM}
# count:  98
# SQL:  SELECT ( ) , count: 98
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN1} {FROM}
# count:  84
# SQL:  SELECT WHERE NOT IN ( SELECT , count: 84
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count:  83
# SQL:  SELECT WHERE LIKE OR LIKE , count: 1
# SQL:  SELECT WHERE > OR > , count: 1
# SQL:  SELECT WHERE OR > , count: 6
# SQL:  SELECT WHERE > OR , count: 9
# SQL:  SELECT WHERE OR , count: 66
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE}
# count:  79
# SQL:  SELECT COUNT ( ) WHERE > > , count: 4
# SQL:  SELECT COUNT ( ) WHERE > , count: 9
# SQL:  SELECT COUNT ( ) WHERE , count: 66
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  75
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) LIMIT , count: 4
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 71
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  70
# SQL:  SELECT WHERE , count: 26
# SQL:  SELECT WHERE LIKE , count: 44
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} GROUP BY {COLUMN0}
# count:  64
# SQL:  SELECT COUNT ( ) GROUP BY , count: 64
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM}
# count:  63
# SQL:  SELECT , count: 63
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  61
# SQL:  SELECT WHERE > ( SELECT ( ) , count: 21
# SQL:  SELECT WHERE ( SELECT ( ) , count: 40
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE}
# count:  60
# SQL:  SELECT GROUP BY HAVING COUNT ( ) > , count: 27
# SQL:  SELECT GROUP BY HAVING COUNT ( ) , count: 33
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  58
# SQL:  SELECT COUNT ( ) WHERE > , count: 3
# SQL:  SELECT COUNT ( ) WHERE , count: 55
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {VALUE}
# count:  55
# SQL:  SELECT WHERE , count: 55
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1}
# count:  53
# SQL:  SELECT ( ) GROUP BY , count: 53
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN0}
# count:  51
# SQL:  SELECT ORDER BY , count: 51
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2} {DASC} LIMIT {VALUE}
# count:  50
# SQL:  SELECT ORDER BY LIMIT , count: 6
# SQL:  SELECT ORDER BY DESC LIMIT , count: 44
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM}
# count:  48
# SQL:  SELECT ( ) ( ) , count: 48
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0}
# count:  47
# SQL:  SELECT ( ) GROUP BY , count: 47
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN0} {DASC}
# count:  41
# SQL:  SELECT ORDER BY DESC , count: 11
# SQL:  SELECT ORDER BY , count: 30
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  39
# SQL:  SELECT WHERE > GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 6
# SQL:  SELECT WHERE GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 33
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  39
# SQL:  SELECT ( ) WHERE > , count: 1
# SQL:  SELECT ( ) WHERE , count: 38
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE}
# count:  38
# SQL:  SELECT WHERE > , count: 2
# SQL:  SELECT WHERE > > , count: 2
# SQL:  SELECT WHERE , count: 34
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN1} LIMIT {VALUE}
# count:  37
# SQL:  SELECT ORDER BY LIMIT , count: 37
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN1}
# count:  35
# SQL:  SELECT COUNT ( ) GROUP BY , count: 35
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  34
# SQL:  SELECT WHERE ( SELECT ( ) WHERE ) , count: 12
# SQL:  SELECT WHERE > ( SELECT ( ) WHERE ) , count: 22
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN0} {FROM}
# count:  33
# SQL:  SELECT COUNT ( ) WHERE NOT IN ( SELECT , count: 33
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN1}
# count:  31
# SQL:  SELECT ORDER BY , count: 31
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN2} {OP} {VALUE}
# count:  30
# SQL:  SELECT WHERE > OR , count: 3
# SQL:  SELECT WHERE OR > , count: 7
# SQL:  SELECT WHERE > OR > , count: 7
# SQL:  SELECT WHERE OR , count: 13
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE}
# count:  30
# SQL:  SELECT WHERE , count: 30
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0}
# count:  29
# SQL:  SELECT COUNT ( ) WHERE > GROUP BY , count: 14
# SQL:  SELECT COUNT ( ) WHERE GROUP BY , count: 15
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} BETWEEN {VALUE} AND {VALUE}
# count:  27
# SQL:  SELECT WHERE , count: 27
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM}
# count:  27
# SQL:  SELECT ( ) ( ) ( ) , count: 27
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  26
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) LIMIT , count: 1
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 25
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  25
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 25
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} OR {COLUMN2} {OP} {VALUE}
# count:  25
# SQL:  SELECT WHERE OR > , count: 2
# SQL:  SELECT WHERE > OR , count: 3
# SQL:  SELECT WHERE OR , count: 20
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  25
# SQL:  SELECT GROUP BY HAVING COUNT ( ) > , count: 7
# SQL:  SELECT GROUP BY HAVING COUNT ( ) , count: 18
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  25
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) LIMIT , count: 2
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 23
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN1} {DASC} LIMIT {VALUE}
# count:  24
# SQL:  SELECT ORDER BY LIMIT , count: 6
# SQL:  SELECT ORDER BY DESC LIMIT , count: 18
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN1} ) {DASC} LIMIT {VALUE}
# count:  23
# SQL:  SELECT GROUP BY ORDER BY ( ) DESC LIMIT , count: 23
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2} LIMIT {VALUE}
# count:  22
# SQL:  SELECT ORDER BY LIMIT , count: 22
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2} {DASC}
# count:  22
# SQL:  SELECT ORDER BY , count: 2
# SQL:  SELECT ORDER BY DESC , count: 20
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  22
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) LIMIT , count: 2
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 20
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE}
# count:  21
# SQL:  SELECT WHERE > , count: 2
# SQL:  SELECT WHERE > > , count: 2
# SQL:  SELECT WHERE LIKE , count: 2
# SQL:  SELECT WHERE , count: 15
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0}
# count:  20
# SQL:  SELECT COUNT ( ) WHERE > GROUP BY , count: 3
# SQL:  SELECT COUNT ( ) WHERE GROUP BY , count: 17
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN2} {DASC} LIMIT {VALUE}
# count:  19
# SQL:  SELECT WHERE ORDER BY LIMIT , count: 2
# SQL:  SELECT WHERE ORDER BY DESC LIMIT , count: 17
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  19
# SQL:  SELECT ( ) ( ) WHERE > , count: 2
# SQL:  SELECT ( ) ( ) WHERE LIKE , count: 2
# SQL:  SELECT ( ) ( ) WHERE , count: 15
#
# --------------------------------------
# SQL Pattern: SELECT * {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  18
# SQL:  SELECT WHERE > , count: 2
# SQL:  SELECT WHERE , count: 16
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE}
# count:  17
# SQL:  SELECT GROUP BY HAVING COUNT ( ) > , count: 5
# SQL:  SELECT GROUP BY HAVING COUNT ( ) , count: 12
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM}
# count:  17
# SQL:  SELECT WHERE > ( SELECT ( ) , count: 7
# SQL:  SELECT WHERE ( SELECT ( ) , count: 10
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN0} {DASC} LIMIT {VALUE}
# count:  17
# SQL:  SELECT ORDER BY LIMIT , count: 7
# SQL:  SELECT ORDER BY DESC LIMIT , count: 10
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN2} {FROM}
# count:  16
# SQL:  SELECT WHERE NOT IN ( SELECT , count: 16
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  16
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) LIMIT , count: 4
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 12
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN0}
# count:  16
# SQL:  SELECT WHERE > ORDER BY , count: 2
# SQL:  SELECT WHERE ORDER BY , count: 14
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} {FROM}
# count:  15
# SQL:  SELECT , count: 15
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} NOT IN ( SELECT {COLUMN2} {FROM}
# count:  15
# SQL:  SELECT WHERE NOT IN ( SELECT , count: 15
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2}
# count:  15
# SQL:  SELECT ORDER BY , count: 15
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC}
# count:  15
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) , count: 4
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) DESC , count: 11
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  15
# SQL:  SELECT WHERE INTERSECT SELECT WHERE > , count: 3
# SQL:  SELECT WHERE INTERSECT SELECT WHERE , count: 12
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN0}
# count:  15
# SQL:  SELECT ORDER BY , count: 15
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  14
# SQL:  SELECT ( ) ( ) WHERE , count: 14
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE}
# count:  14
# SQL:  SELECT WHERE , count: 14
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM}
# count:  14
# SQL:  SELECT , count: 14
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN2}
# count:  13
# SQL:  SELECT WHERE ORDER BY , count: 13
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  13
# SQL:  SELECT WHERE INTERSECT SELECT WHERE , count: 13
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  13
# SQL:  SELECT WHERE > GROUP BY HAVING COUNT ( ) > , count: 2
# SQL:  SELECT WHERE GROUP BY HAVING COUNT ( ) > , count: 2
# SQL:  SELECT WHERE GROUP BY HAVING COUNT ( ) , count: 4
# SQL:  SELECT WHERE > GROUP BY HAVING COUNT ( ) , count: 5
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) LIMIT {VALUE}
# count:  12
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) LIMIT , count: 12
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN3} {DASC} LIMIT {VALUE}
# count:  12
# SQL:  SELECT ORDER BY DESC LIMIT , count: 12
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN1} ) {OP} {VALUE}
# count:  12
# SQL:  SELECT GROUP BY HAVING ( ) , count: 6
# SQL:  SELECT GROUP BY HAVING ( ) > , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  12
# SQL:  SELECT WHERE > , count: 1
# SQL:  SELECT WHERE LIKE , count: 3
# SQL:  SELECT WHERE , count: 8
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2} HAVING COUNT ( * ) {OP} {VALUE}
# count:  12
# SQL:  SELECT GROUP BY HAVING COUNT ( ) , count: 3
# SQL:  SELECT GROUP BY HAVING COUNT ( ) > , count: 9
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  12
# SQL:  SELECT WHERE INTERSECT SELECT WHERE , count: 12
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} OR {COLUMN0} {OP} {VALUE}
# count:  12
# SQL:  SELECT COUNT ( ) WHERE OR , count: 12
#
# --------------------------------------
# SQL Pattern: SELECT * {FROM}
# count:  12
# SQL:  SELECT , count: 12
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN3}
# count:  12
# SQL:  SELECT ORDER BY , count: 12
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  11
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) LIMIT , count: 3
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 8
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0}
# count:  11
# SQL:  SELECT COUNT ( ) GROUP BY , count: 11
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN1}
# count:  11
# SQL:  SELECT COUNT ( ) GROUP BY , count: 11
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} ORDER BY {AGG} ( {COLUMN2} ) {DASC} LIMIT {VALUE}
# count:  11
# SQL:  SELECT GROUP BY ORDER BY ( ) DESC LIMIT , count: 11
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  11
# SQL:  SELECT WHERE > , count: 3
# SQL:  SELECT WHERE , count: 8
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  10
# SQL:  SELECT COUNT ( ) GROUP BY HAVING COUNT ( ) , count: 5
# SQL:  SELECT COUNT ( ) GROUP BY HAVING COUNT ( ) > , count: 5
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN1}
# count:  10
# SQL:  SELECT ORDER BY , count: 10
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} NOT IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  10
# SQL:  SELECT WHERE NOT IN ( SELECT WHERE ) , count: 10
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count:  10
# SQL:  SELECT ( ) WHERE OR , count: 10
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN0} {DASC}
# count:  10
# SQL:  SELECT ORDER BY DESC , count: 1
# SQL:  SELECT ORDER BY , count: 9
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  10
# SQL:  SELECT WHERE EXCEPT SELECT WHERE , count: 10
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} UNION SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  10
# SQL:  SELECT WHERE UNION SELECT WHERE > , count: 2
# SQL:  SELECT WHERE UNION SELECT WHERE , count: 8
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} ( SELECT {AGG} ( {COLUMN0} ) {FROM}
# count:  10
# SQL:  SELECT COUNT ( ) WHERE > ( SELECT ( ) , count: 10
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) LIMIT {VALUE}
# count:  10
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) LIMIT , count: 10
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} )
# count:  10
# SQL:  SELECT WHERE ( SELECT ( ) WHERE ) , count: 10
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING {AGG} ( {COLUMN2} ) {OP} {VALUE}
# count:  9
# SQL:  SELECT GROUP BY HAVING ( ) > , count: 4
# SQL:  SELECT GROUP BY HAVING ( ) , count: 5
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE}
# count:  9
# SQL:  SELECT WHERE , count: 9
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN1} {FROM}
# count:  9
# SQL:  SELECT COUNT ( ) WHERE NOT IN ( SELECT , count: 9
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  9
# SQL:  SELECT WHERE NOT IN ( SELECT WHERE > ) , count: 2
# SQL:  SELECT WHERE NOT IN ( SELECT WHERE ) , count: 7
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} UNION SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  8
# SQL:  SELECT WHERE > UNION SELECT WHERE , count: 2
# SQL:  SELECT WHERE UNION SELECT WHERE , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT ( {COLUMN0} ) {FROM}
# count:  8
# SQL:  SELECT ( ) , count: 8
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE} OR {COLUMN0} {OP} {VALUE}
# count:  8
# SQL:  SELECT WHERE LIKE OR LIKE , count: 2
# SQL:  SELECT WHERE OR , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN1}
# count:  8
# SQL:  SELECT ( ) WHERE > GROUP BY , count: 4
# SQL:  SELECT ( ) WHERE GROUP BY , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} BETWEEN {VALUE} AND {VALUE}
# count:  8
# SQL:  SELECT WHERE , count: 8
#
# --------------------------------------
# SQL Pattern: SELECT * {FROM} ORDER BY {COLUMN0}
# count:  8
# SQL:  SELECT ORDER BY , count: 8
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1}
# count:  8
# SQL:  SELECT ( ) ( ) GROUP BY , count: 8
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count:  8
# SQL:  SELECT COUNT ( ) WHERE > OR , count: 3
# SQL:  SELECT COUNT ( ) WHERE OR , count: 5
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {AGG} ( {COLUMN2} ) {FROM} GROUP BY {COLUMN1}
# count:  8
# SQL:  SELECT ( ) GROUP BY , count: 8
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( {COLUMN1} ) {OP} {VALUE}
# count:  8
# SQL:  SELECT GROUP BY HAVING COUNT ( ) , count: 2
# SQL:  SELECT GROUP BY HAVING COUNT ( ) > , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  8
# SQL:  SELECT WHERE EXCEPT SELECT WHERE , count: 2
# SQL:  SELECT WHERE > EXCEPT SELECT WHERE , count: 2
# SQL:  SELECT WHERE EXCEPT SELECT WHERE > , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  7
# SQL:  SELECT WHERE LIKE GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 2
# SQL:  SELECT WHERE > GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 2
# SQL:  SELECT WHERE GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN1} ) {DASC} LIMIT {VALUE}
# count:  7
# SQL:  SELECT ( ) GROUP BY ORDER BY ( ) DESC LIMIT , count: 7
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN0}
# count:  7
# SQL:  SELECT COUNT ( ) GROUP BY , count: 7
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0}
# count:  7
# SQL:  SELECT ( ) ( ) GROUP BY , count: 7
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {VALUE}
# count:  7
# SQL:  SELECT WHERE , count: 7
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN2}
# count:  7
# SQL:  SELECT ( ) GROUP BY , count: 7
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN2}
# count:  6
# SQL:  SELECT ORDER BY , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC}
# count:  6
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) , count: 2
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) DESC , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} )
# count:  6
# SQL:  SELECT WHERE > ( SELECT ( ) WHERE ) , count: 2
# SQL:  SELECT WHERE ( SELECT ( ) WHERE ) , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {VALUE}
# count:  6
# SQL:  SELECT COUNT ( ) WHERE , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN1} {DASC}
# count:  6
# SQL:  SELECT ORDER BY DESC , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN1} BETWEEN {VALUE} AND {VALUE}
# count:  6
# SQL:  SELECT WHERE , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} BETWEEN {VALUE} AND {VALUE}
# count:  6
# SQL:  SELECT COUNT ( ) WHERE , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} INTERSECT SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  6
# SQL:  SELECT WHERE IN ( SELECT WHERE INTERSECT SELECT WHERE ) , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( {COLUMN2} ) {OP} {VALUE}
# count:  6
# SQL:  SELECT GROUP BY HAVING COUNT ( ) > , count: 2
# SQL:  SELECT GROUP BY HAVING COUNT ( ) , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} OR {COLUMN3} {OP} {VALUE}
# count:  6
# SQL:  SELECT WHERE OR > , count: 1
# SQL:  SELECT WHERE OR , count: 2
# SQL:  SELECT WHERE > OR , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} )
# count:  6
# SQL:  SELECT WHERE ( SELECT GROUP BY ORDER BY COUNT ( ) DESC LIMIT ) , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} , {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  6
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  6
# SQL:  SELECT WHERE INTERSECT SELECT WHERE , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN1} LIMIT {VALUE}
# count:  6
# SQL:  SELECT ORDER BY LIMIT , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} EXCEPT SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  6
# SQL:  SELECT WHERE EXCEPT SELECT WHERE , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN3} {DASC}
# count:  6
# SQL:  SELECT ORDER BY , count: 2
# SQL:  SELECT ORDER BY DESC , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} UNION SELECT {COLUMN0} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  6
# SQL:  SELECT WHERE > UNION SELECT WHERE , count: 2
# SQL:  SELECT WHERE UNION SELECT WHERE > , count: 2
# SQL:  SELECT WHERE LIKE UNION SELECT WHERE , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1}
# count:  6
# SQL:  SELECT COUNT ( ) GROUP BY , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM}
# count:  6
# SQL:  SELECT WHERE EXCEPT SELECT , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  6
# SQL:  SELECT WHERE , count: 2
# SQL:  SELECT WHERE LIKE , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN2} {DASC}
# count:  6
# SQL:  SELECT WHERE ORDER BY , count: 2
# SQL:  SELECT WHERE ORDER BY DESC , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC}
# count:  6
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) DESC , count: 6
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  5
# SQL:  SELECT WHERE , count: 2
# SQL:  SELECT WHERE LIKE , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ORDER BY {COLUMN0}
# count:  5
# SQL:  SELECT WHERE ORDER BY , count: 5
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  5
# SQL:  SELECT GROUP BY HAVING COUNT ( ) , count: 5
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  5
# SQL:  SELECT ( ) ( ) ( ) WHERE , count: 5
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN2} HAVING COUNT ( * ) {OP} {VALUE}
# count:  5
# SQL:  SELECT WHERE > GROUP BY HAVING COUNT ( ) > , count: 1
# SQL:  SELECT WHERE GROUP BY HAVING COUNT ( ) > , count: 1
# SQL:  SELECT WHERE GROUP BY HAVING COUNT ( ) , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) , {COLUMN2} {FROM} GROUP BY {COLUMN2}
# count:  5
# SQL:  SELECT ( ) ( ) GROUP BY , count: 5
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} GROUP BY {COLUMN1}
# count:  5
# SQL:  SELECT COUNT ( ) GROUP BY , count: 5
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN0} {FROM}
# count:  4
# SQL:  SELECT WHERE NOT IN ( SELECT , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT * {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN0} {FROM}
# count:  4
# SQL:  SELECT WHERE NOT IN ( SELECT , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN3} LIMIT {VALUE}
# count:  4
# SQL:  SELECT ORDER BY LIMIT , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {AGG} ( {COLUMN2} ) {FROM} GROUP BY {COLUMN3}
# count:  4
# SQL:  SELECT ( ) GROUP BY , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) {FROM}
# count:  4
# SQL:  SELECT ( ) ( ) , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {COLUMN1} {FROM} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} )
# count:  4
# SQL:  SELECT WHERE ( SELECT ORDER BY COUNT ( ) DESC LIMIT ) , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  4
# SQL:  SELECT WHERE > GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN2} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  4
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} AND {COLUMN4} {OP} {VALUE}
# count:  4
# SQL:  SELECT WHERE , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  4
# SQL:  SELECT COUNT ( ) WHERE , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN1} {FROM}
# count:  4
# SQL:  SELECT , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  4
# SQL:  SELECT WHERE > ( SELECT ( ) , count: 2
# SQL:  SELECT WHERE ( SELECT ( ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN2} LIMIT {VALUE}
# count:  4
# SQL:  SELECT WHERE ORDER BY LIMIT , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  4
# SQL:  SELECT WHERE EXCEPT SELECT WHERE , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN0} {OP} {VALUE} )
# count:  4
# SQL:  SELECT WHERE IN ( SELECT WHERE ) , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  4
# SQL:  SELECT COUNT ( ) WHERE , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  4
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY {AGG} ( {COLUMN2} ) {DASC} LIMIT {VALUE}
# count:  4
# SQL:  SELECT GROUP BY ORDER BY ( ) DESC LIMIT , count: 2
# SQL:  SELECT GROUP BY ORDER BY ( ) LIMIT , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0}
# count:  4
# SQL:  SELECT COUNT ( ) ( ) GROUP BY , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  4
# SQL:  SELECT WHERE ( SELECT ( ) WHERE ) , count: 2
# SQL:  SELECT WHERE > ( SELECT ( ) WHERE ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN1} ORDER BY {COLUMN2}
# count:  4
# SQL:  SELECT ( ) WHERE > GROUP BY ORDER BY , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN2} ORDER BY {AGG} ( {COLUMN1} ) {DASC} LIMIT {VALUE}
# count:  4
# SQL:  SELECT ( ) GROUP BY ORDER BY ( ) DESC LIMIT , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  4
# SQL:  SELECT ( ) GROUP BY HAVING COUNT ( ) , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ORDER BY {COLUMN3}
# count:  4
# SQL:  SELECT WHERE ORDER BY , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  4
# SQL:  SELECT WHERE , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN2} ) {OP} {VALUE}
# count:  4
# SQL:  SELECT GROUP BY HAVING ( ) > , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  4
# SQL:  SELECT COUNT ( ) GROUP BY HAVING COUNT ( ) , count: 2
# SQL:  SELECT COUNT ( ) GROUP BY HAVING COUNT ( ) > , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  4
# SQL:  SELECT WHERE GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {VALUE}
# count:  4
# SQL:  SELECT WHERE , count: 2
# SQL:  SELECT WHERE LIKE , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} , {COLUMN1} HAVING COUNT ( {COLUMN2} ) {OP} {VALUE}
# count:  4
# SQL:  SELECT GROUP BY HAVING COUNT ( ) , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) , {COLUMN2} {FROM} GROUP BY {COLUMN2} ORDER BY {COLUMN2}
# count:  4
# SQL:  SELECT ( ) ( ) GROUP BY ORDER BY , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ORDER BY {COLUMN4}
# count:  4
# SQL:  SELECT WHERE ORDER BY , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} BETWEEN {VALUE} AND {VALUE}
# count:  4
# SQL:  SELECT ( ) WHERE , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) BETWEEN {VALUE} AND {VALUE}
# count:  4
# SQL:  SELECT GROUP BY HAVING COUNT ( ) , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} NOT IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  4
# SQL:  SELECT COUNT ( ) WHERE NOT IN ( SELECT WHERE ) , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN0} {DASC}
# count:  4
# SQL:  SELECT WHERE ORDER BY DESC , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE} )
# count:  4
# SQL:  SELECT WHERE IN ( SELECT GROUP BY ORDER BY COUNT ( ) DESC LIMIT ) , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN0} {FROM}
# count:  4
# SQL:  SELECT WHERE IN ( SELECT WHERE IN ( SELECT , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  4
# SQL:  SELECT ( ) GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 2
# SQL:  SELECT ( ) GROUP BY ORDER BY COUNT ( ) LIMIT , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} UNION SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  4
# SQL:  SELECT WHERE UNION SELECT WHERE , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {COLUMN1} {FROM}
# count:  4
# SQL:  SELECT WHERE ( SELECT , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  4
# SQL:  SELECT ( ) WHERE > ( SELECT ( ) , count: 2
# SQL:  SELECT ( ) WHERE ( SELECT ( ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  4
# SQL:  SELECT ( ) WHERE NOT IN ( SELECT WHERE ) , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  4
# SQL:  SELECT COUNT ( ) WHERE > ( SELECT ( ) , count: 2
# SQL:  SELECT COUNT ( ) WHERE ( SELECT ( ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE} )
# count:  4
# SQL:  SELECT WHERE ( SELECT ( ) WHERE ) , count: 2
# SQL:  SELECT WHERE > ( SELECT ( ) WHERE ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) , {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM} GROUP BY {COLUMN1}
# count:  4
# SQL:  SELECT COUNT ( ) ( ) GROUP BY , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {OP} {VALUE}
# count:  4
# SQL:  SELECT ( ) ( ) WHERE , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ORDER BY {COLUMN2}
# count:  4
# SQL:  SELECT WHERE > ORDER BY , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} , {COLUMN1}
# count:  4
# SQL:  SELECT COUNT ( ) GROUP BY , count: 4
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  3
# SQL:  SELECT COUNT ( ) GROUP BY HAVING COUNT ( ) > , count: 1
# SQL:  SELECT COUNT ( ) GROUP BY HAVING COUNT ( ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE}
# count:  3
# SQL:  SELECT COUNT ( ) GROUP BY HAVING COUNT ( ) > , count: 1
# SQL:  SELECT COUNT ( ) GROUP BY HAVING COUNT ( ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN1} {FROM}
# count:  3
# SQL:  SELECT ( ) WHERE NOT IN ( SELECT , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN1} {FROM}
# count:  3
# SQL:  SELECT ( ) WHERE IN ( SELECT , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN2} {DASC}
# count:  3
# SQL:  SELECT ORDER BY , count: 1
# SQL:  SELECT ORDER BY DESC , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN0} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE}
# count:  3
# SQL:  SELECT WHERE > , count: 1
# SQL:  SELECT WHERE , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {VALUE}
# count:  3
# SQL:  SELECT WHERE , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN0} {DASC}
# count:  3
# SQL:  SELECT ORDER BY , count: 1
# SQL:  SELECT ORDER BY DESC , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} ORDER BY {AGG} ( {COLUMN2} ) LIMIT {VALUE}
# count:  3
# SQL:  SELECT GROUP BY ORDER BY ( ) LIMIT , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {VALUE}
# count:  3
# SQL:  SELECT ( ) WHERE , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN0} {DASC} LIMIT {VALUE}
# count:  3
# SQL:  SELECT ORDER BY DESC LIMIT , count: 1
# SQL:  SELECT ORDER BY LIMIT , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {FROM} WHERE {OP} {VALUE}
# count:  3
# SQL:  SELECT WHERE , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT * {FROM} ORDER BY {COLUMN0} {DASC}
# count:  3
# SQL:  SELECT ORDER BY , count: 1
# SQL:  SELECT ORDER BY DESC , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  3
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  3
# SQL:  SELECT WHERE GROUP BY HAVING COUNT ( ) , count: 1
# SQL:  SELECT WHERE > GROUP BY HAVING COUNT ( ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC}
# count:  3
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) DESC , count: 1
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  3
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} {FROM} ORDER BY {COLUMN1}
# count:  3
# SQL:  SELECT ORDER BY , count: 3
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} WHERE {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN0}
# count:  2
# ...
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} - {COLUMN3} {OP} ( SELECT {COLUMN2} - {COLUMN3} {FROM} ORDER BY ( {COLUMN2} - {COLUMN3} ) {DASC} LIMIT {VALUE} )
# count:  2
# SQL:  SELECT WHERE ( SELECT ORDER BY ( ) DESC LIMIT ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN1} ORDER BY {AGG} ( {COLUMN2} ) LIMIT {VALUE}
# count:  2
# SQL:  SELECT GROUP BY ORDER BY ( ) LIMIT , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} ORDER BY {COLUMN1} , {COLUMN2}
# count:  2
# SQL:  SELECT ORDER BY , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {COLUMN2} OR {COLUMN1} {OP} {COLUMN3}
# count:  2
# SQL:  SELECT WHERE OR > , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {COLUMN2} INTERSECT SELECT {COLUMN0} {FROM}
# count:  2
# SQL:  SELECT WHERE INTERSECT SELECT , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {COLUMN2} EXCEPT SELECT {COLUMN0} {FROM}
# count:  2
# SQL:  SELECT WHERE EXCEPT SELECT , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {COLUMN2} UNION SELECT {COLUMN0} {FROM}
# count:  2
# SQL:  SELECT WHERE > UNION SELECT , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count:  2
# SQL:  SELECT WHERE OR , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  2
# SQL:  SELECT ( ) WHERE LIKE , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN0} , {COLUMN0}
# count:  2
# SQL:  SELECT ORDER BY , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN1} ) {FROM}
# count:  2
# SQL:  SELECT WHERE ( SELECT ( ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING {COLUMN2} {OP} {VALUE} ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  2
# SQL:  SELECT GROUP BY HAVING ORDER BY COUNT ( ) DESC LIMIT , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} OR {COLUMN4} {OP} {VALUE}
# count:  2
# SQL:  SELECT WHERE OR , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , COUNT ( * ) , {COLUMN2} {FROM} GROUP BY {COLUMN2}
# count:  2
# SQL:  SELECT COUNT ( ) GROUP BY , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {COLUMN2} {OP} {VALUE} OR {COLUMN2} {OP} {VALUE}
# count:  2
# SQL:  SELECT WHERE EXCEPT SELECT WHERE OR , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  2
# SQL:  SELECT WHERE , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} GROUP BY {COLUMN0} ORDER BY COUNT ( * ) {DASC}
# count:  2
# SQL:  SELECT COUNT ( ) WHERE GROUP BY ORDER BY COUNT ( ) DESC , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} )
# count:  2
# SQL:  SELECT COUNT ( ) GROUP BY HAVING COUNT ( ) > ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} ORDER BY COUNT ( * )
# count:  2
# SQL:  SELECT GROUP BY HAVING COUNT ( ) > ORDER BY COUNT ( ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ) AND {COLUMN3} IN ( SELECT {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} )
# count:  2
# SQL:  SELECT COUNT ( ) WHERE IN ( SELECT WHERE ) IN ( SELECT WHERE ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ) AND {COLUMN4} IN ( SELECT {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} )
# count:  2
# SQL:  SELECT WHERE IN ( SELECT WHERE ) IN ( SELECT WHERE ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} GROUP BY {COLUMN3} HAVING COUNT ( * ) {OP} {VALUE}
# count:  2
# SQL:  SELECT WHERE GROUP BY HAVING COUNT ( ) , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ORDER BY {COLUMN3} {DASC} LIMIT {VALUE}
# count:  2
# SQL:  SELECT WHERE ORDER BY DESC LIMIT , count: 2
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} BETWEEN {VALUE} AND {VALUE}
# count:  1
# SQL:  SELECT ( ) WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} GROUP BY {VALUE}
# count:  1
# SQL:  SELECT COUNT ( ) GROUP BY , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} ( SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} )
# count:  1
# SQL:  SELECT GROUP BY HAVING COUNT ( ) > ( SELECT COUNT ( ) WHERE ) , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} ORDER BY {COLUMN0}
# count:  1
# SQL:  SELECT ORDER BY , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} NOT IN ( SELECT {COLUMN2} {FROM}
# count:  1
# SQL:  SELECT ( ) WHERE NOT IN ( SELECT , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} ( SELECT {AGG} ( {COLUMN2} ) {FROM}
# count:  1
# SQL:  SELECT WHERE ( SELECT ( ) , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE}
# count:  1
# SQL:  SELECT WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN2} {OP} {VALUE}
# count:  1
# SQL:  SELECT WHERE INTERSECT SELECT WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} NOT IN ( SELECT {COLUMN4} {FROM}
# count:  1
# SQL:  SELECT WHERE NOT IN ( SELECT , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} GROUP BY {COLUMN2} HAVING {AGG} ( {COLUMN3} ) {OP} {VALUE}
# count:  1
# SQL:  SELECT WHERE > INTERSECT SELECT GROUP BY HAVING ( ) > , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0} ORDER BY {AGG} ( {COLUMN1} ) {DASC}
# count:  1
# SQL:  SELECT ( ) GROUP BY ORDER BY ( ) DESC , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {COLUMN1}
# count:  1
# SQL:  SELECT COUNT ( ) WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN1} ) {OP} {VALUE} OR {AGG} ( {COLUMN2} ) {OP} {VALUE}
# count:  1
# SQL:  SELECT GROUP BY HAVING ( ) > OR ( ) > , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {COLUMN0} {OP} {VALUE} GROUP BY {COLUMN1} HAVING COUNT ( * ) {OP} {VALUE} )
# count:  1
# SQL:  SELECT COUNT ( ) WHERE > GROUP BY HAVING COUNT ( ) > ) , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} OR {COLUMN4} {OP} {VALUE} ORDER BY {COLUMN5} , {COLUMN6}
# count:  1
# SQL:  SELECT WHERE > OR ORDER BY , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ORDER BY {COLUMN1}
# count:  1
# SQL:  SELECT WHERE ORDER BY , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING {AGG} ( {COLUMN1} ) {OP} {VALUE} ORDER BY {AGG} ( {COLUMN1} ) {DASC}
# count:  1
# SQL:  SELECT GROUP BY HAVING ( ) ORDER BY ( ) DESC , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT , COUNT ( ) {FROM} GROUP BY HAVING COUNT ( ) {OP} {VALUE}
# count:  1
# SQL:  SELECT COUNT ( ) GROUP BY HAVING COUNT ( ) > , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {OP} {VALUE}
# count:  1
# SQL:  SELECT COUNT ( ) WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT , COUNT ( ) {FROM} GROUP BY ORDER BY COUNT ( ) {DASC} LIMIT {VALUE}
# count:  1
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  1
# SQL:  SELECT WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {OP} {VALUE}
# count:  1
# SQL:  SELECT WHERE EXCEPT SELECT WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {OP} {VALUE}
# count:  1
# SQL:  SELECT WHERE INTERSECT SELECT WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( {COLUMN1} ) {DASC} LIMIT {VALUE}
# count:  1
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT , COUNT ( * ) {FROM} GROUP BY , , ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  1
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} HAVING COUNT ( {COLUMN0} ) BETWEEN {VALUE} AND {VALUE}
# count:  1
# SQL:  SELECT COUNT ( ) GROUP BY HAVING COUNT ( ) , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {VALUE} AND {COLUMN4} {OP} {VALUE}
# count:  1
# SQL:  SELECT WHERE > , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} GROUP BY HAVING {OP} {VALUE}
# count:  1
# SQL:  SELECT COUNT ( ) GROUP BY HAVING , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {OP} {VALUE} AND {OP} {VALUE}
# count:  1
# SQL:  SELECT ( ) WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {OP} {VALUE} AND {OP} {VALUE} AND {OP} {VALUE}
# count:  1
# SQL:  SELECT COUNT ( ) WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {OP} {VALUE} AND {OP} {VALUE} AND {OP} {VALUE}
# count:  1
# SQL:  SELECT WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT , {AGG} ( ) {FROM} GROUP BY ORDER BY {AGG} ( ) {DASC} LIMIT {VALUE}
# count:  1
# SQL:  SELECT ( ) GROUP BY ORDER BY ( ) LIMIT , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT , {FROM} GROUP BY ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  1
# SQL:  SELECT GROUP BY ORDER BY COUNT ( ) DESC LIMIT , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  1
# SQL:  SELECT GROUP BY HAVING COUNT ( ) INTERSECT SELECT GROUP BY HAVING COUNT ( ) , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} UNION SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  1
# SQL:  SELECT GROUP BY HAVING COUNT ( ) UNION SELECT GROUP BY HAVING COUNT ( ) , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2}
# count:  1
# SQL:  SELECT COUNT ( ) GROUP BY , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2} HAVING {AGG} ( {COLUMN3} ) {OP} {VALUE}
# count:  1
# SQL:  SELECT GROUP BY HAVING ( ) > , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} ORDER BY {COLUMN0} {DASC} LIMIT {VALUE}
# count:  1
# SQL:  SELECT ( ) ORDER BY DESC LIMIT , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * )
# count:  1
# SQL:  SELECT COUNT ( ) GROUP BY ORDER BY COUNT ( ) , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN1} , {COLUMN2} {DASC}
# count:  1
# SQL:  SELECT WHERE > ORDER BY DESC , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} ORDER BY {COLUMN0}
# count:  1
# SQL:  SELECT GROUP BY HAVING COUNT ( ) ORDER BY , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {VALUE}
# count:  1
# SQL:  SELECT WHERE INTERSECT SELECT WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) BETWEEN {VALUE} AND {VALUE}
# count:  1
# SQL:  SELECT GROUP BY HAVING COUNT ( ) , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE}
# count:  1
# SQL:  SELECT WHERE > INTERSECT SELECT WHERE , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM} ORDER BY {COLUMN3}
# count:  1
# SQL:  SELECT ORDER BY , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count:  1
# SQL:  SELECT ( ) ( ) WHERE OR , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) , {AGG} ( {COLUMN2} ) {FROM} GROUP BY {COLUMN0}
# count:  1
# SQL:  SELECT ( ) ( ) GROUP BY , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ORDER BY {COLUMN1} {DASC}
# count:  1
# SQL:  SELECT WHERE ORDER BY DESC , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2} , {COLUMN3}
# count:  1
# SQL:  SELECT ORDER BY , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ORDER BY {COLUMN0}
# count:  1
# SQL:  SELECT WHERE ORDER BY , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM}
# count:  1
# SQL:  SELECT ( ) , count: 1
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} UNION SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  1
# SQL:  SELECT GROUP BY HAVING COUNT ( ) UNION SELECT GROUP BY HAVING COUNT ( ) , count: 1

# %%
for sql_template, qts in pattern_question_dict:
    print("\n--------------------------------------")
    print("SQL Pattern: {}".format(sql_template))
    print("count: ", len(qts))
    for qt in qts:
        q, q_template, sql, sql_more = qt.split("|||")
        print("question: ", q)
        print("SQL: {} \n".format(sql_more))
# Out:
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE}
# count:  794
# question:  What are the distinct creation years of the departments managed by a secretary born in state 'Alabama ' ?
# SQL:  SELECT DISTINCT T1.creation FROM department AS T1 JOIN management AS T2 ON T1.department_id  =  T2.department_id JOIN head AS T3 ON T2.head_id  =  T3.head_id WHERE T3.born_state  =  'Alabama'
#
# question:  What are the distinct ages of the heads who are acting ?
# SQL:  SELECT DISTINCT T1.age FROM management AS T2 JOIN head AS T1 ON T1.head_id  =  T2.head_id WHERE T2.temporary_acting  =  'Yes'
#
# question:  Please show the themes of competitions with host cities having populations larger than 1000 .
# SQL:  SELECT T2.Theme FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID WHERE T1.Population  >  1000
#
# question:  What are the themes of competitions that have corresponding host cities with more than 1000 residents ?
# SQL:  SELECT T2.Theme FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID WHERE T1.Population  >  1000
#
# question:  Find id of the candidate whose email is stanley.monahan @ example.org ?
# SQL:  SELECT T2.candidate_id FROM people AS T1 JOIN candidates AS T2 ON T1.person_id = T2.candidate_id WHERE T1.email_address = "stanley.monahan@example.org"
#
# question:  What is the id of the candidate whose email is stanley.monahan @ example.org ?
# SQL:  SELECT T2.candidate_id FROM people AS T1 JOIN candidates AS T2 ON T1.person_id = T2.candidate_id WHERE T1.email_address = "stanley.monahan@example.org"
#
# question:  Find id of candidates whose assessment code is `` Pass '' ?
# SQL:  SELECT candidate_id FROM candidate_assessments WHERE asessment_outcome_code = "Pass"
#
# question:  What are the ids of the candidates that have an outcome code of Pass ?
# SQL:  SELECT candidate_id FROM candidate_assessments WHERE asessment_outcome_code = "Pass"
#
# question:  Find the cell mobile number of the candidates whose assessment code is `` Fail '' ?
# SQL:  SELECT T3.cell_mobile_number FROM candidates AS T1 JOIN candidate_assessments AS T2 ON T1.candidate_id = T2.candidate_id JOIN people AS T3 ON T1.candidate_id = T3.person_id WHERE T2.asessment_outcome_code = "Fail"
#
# question:  What are the cell phone numbers of the candidates that received an assessment code of `` Fail '' ?
# SQL:  SELECT T3.cell_mobile_number FROM candidates AS T1 JOIN candidate_assessments AS T2 ON T1.candidate_id = T2.candidate_id JOIN people AS T3 ON T1.candidate_id = T3.person_id WHERE T2.asessment_outcome_code = "Fail"
#
# question:  What are the id of students who registered course 301 ?
# SQL:  SELECT student_id FROM student_course_attendance WHERE course_id  =  301
#
# question:  What are the ids of the students who registered for course 301 ?
# SQL:  SELECT student_id FROM student_course_attendance WHERE course_id  =  301
#
# question:  Give me the dates when the max temperature was higher than 85 .
# SQL:  SELECT date FROM weather WHERE max_temperature_f  >  85
#
# question:  What are the dates with a maximum temperature higher than 85 ?
# SQL:  SELECT date FROM weather WHERE max_temperature_f  >  85
#
# question:  What are the names of stations that have latitude lower than 37.5 ?
# SQL:  SELECT name FROM station WHERE lat  <  37.5
#
# question:  What are the names of all stations with a latitude smaller than 37.5 ?
# SQL:  SELECT name FROM station WHERE lat  <  37.5
#
# question:  Return the unique name for stations that have ever had 7 bikes available .
# SQL:  SELECT DISTINCT T1.name FROM station AS T1 JOIN status AS T2 ON T1.id  =  T2.station_id WHERE T2.bikes_available  =  7
#
# question:  What are the different names for each station that has ever had 7 bikes available ?
# SQL:  SELECT DISTINCT T1.name FROM station AS T1 JOIN status AS T2 ON T1.id  =  T2.station_id WHERE T2.bikes_available  =  7
#
# question:  List all the distinct stations from which a trip of duration below 100 started .
# SQL:  SELECT DISTINCT start_station_name FROM trip WHERE duration  <  100
#
# question:  What are all the different start station names for a trip that lasted less than 100 ?
# SQL:  SELECT DISTINCT start_station_name FROM trip WHERE duration  <  100
#
# question:  Find all the zip codes in which the max dew point have never reached 70 .
# SQL:  SELECT DISTINCT zip_code FROM weather EXCEPT SELECT DISTINCT zip_code FROM weather WHERE max_dew_point_f  >=  70
#
# question:  What are all the different zip codes that have a maximum dew point that was always below 70 ?
# SQL:  SELECT DISTINCT zip_code FROM weather EXCEPT SELECT DISTINCT zip_code FROM weather WHERE max_dew_point_f  >=  70
#
# question:  What are the distinct publishers of publications with price higher than 5000000 ?
# SQL:  SELECT DISTINCT Publisher FROM publication WHERE Price  >  5000000
#
# question:  Show writers who have published a book with price more than 4000000 .
# SQL:  SELECT T1.Writer FROM book AS T1 JOIN publication AS T2 ON T1.Book_ID  =  T2.Book_ID WHERE T2.Price  >  4000000
#
# question:  What are the names of musicals with nominee `` Bob Fosse '' ?
# SQL:  SELECT Name FROM musical WHERE Nominee  =  "Bob Fosse"
#
# question:  Return the names of musicals who have the nominee Bob Fosse .
# SQL:  SELECT Name FROM musical WHERE Nominee  =  "Bob Fosse"
#
# question:  Find the emails of the user named `` Mary '' .
# SQL:  SELECT email FROM user_profiles WHERE name  =  'Mary'
#
# question:  What is the partition id of the user named `` Iron Man '' .
# SQL:  SELECT partitionid FROM user_profiles WHERE name  =  'Iron Man'
#
# question:  What is the attribute data type of the attribute with name `` Green '' ?
# SQL:  SELECT attribute_data_type FROM Attribute_Definitions WHERE attribute_name  =  "Green"
#
# question:  Find the attribute data type for the attribute named `` Green '' .
# SQL:  SELECT attribute_data_type FROM Attribute_Definitions WHERE attribute_name  =  "Green"
#
# question:  Find the names of all the products whose stock number starts with `` 2 '' .
# SQL:  SELECT catalog_entry_name FROM catalog_contents WHERE product_stock_number LIKE "2%"
#
# question:  Which catalog contents have a product stock number that starts from `` 2 '' ? Show the catalog entry names .
# SQL:  SELECT catalog_entry_name FROM catalog_contents WHERE product_stock_number LIKE "2%"
#
# question:  Find the names of catalog entries with level number 8 .
# SQL:  SELECT t1.catalog_entry_name FROM Catalog_Contents AS t1 JOIN Catalog_Contents_Additional_Attributes AS t2 ON t1.catalog_entry_id  =  t2.catalog_entry_id WHERE t2.catalog_level_number  =  "8"
#
# question:  What are the names of catalog entries with level number 8 ?
# SQL:  SELECT t1.catalog_entry_name FROM Catalog_Contents AS t1 JOIN Catalog_Contents_Additional_Attributes AS t2 ON t1.catalog_entry_id  =  t2.catalog_entry_id WHERE t2.catalog_level_number  =  "8"
#
# question:  Name all the products with next entry ID greater than 8 .
# SQL:  SELECT catalog_entry_name FROM catalog_contents WHERE next_entry_id  >  8
#
# question:  What are the catalog entry names of the products with next entry ID above 8 ?
# SQL:  SELECT catalog_entry_name FROM catalog_contents WHERE next_entry_id  >  8
#
# question:  Show ids for all aircrafts with more than 1000 distance .
# SQL:  SELECT aid FROM Aircraft WHERE distance  >  1000
#
# question:  What are the ids of all aircrafts that can cover a distance of more than 1000 ?
# SQL:  SELECT aid FROM Aircraft WHERE distance  >  1000
#
# question:  Show ids for all employees with at least 100000 salary .
# SQL:  SELECT eid FROM Employee WHERE salary  >  100000
#
# question:  What is the id of every employee who has at least a salary of 100000 ?
# SQL:  SELECT eid FROM Employee WHERE salary  >  100000
#
# question:  Show all flight number from Los Angeles .
# SQL:  SELECT flno FROM Flight WHERE origin  =  "Los Angeles"
#
# question:  What are the numbers of all flights coming from Los Angeles ?
# SQL:  SELECT flno FROM Flight WHERE origin  =  "Los Angeles"
#
# question:  Show origins of all flights with destination Honolulu .
# SQL:  SELECT origin FROM Flight WHERE destination  =  "Honolulu"
#
# question:  What are the origins of all flights that are headed to Honolulu ?
# SQL:  SELECT origin FROM Flight WHERE destination  =  "Honolulu"
#
# question:  Show flight number for all flights with more than 2000 distance .
# SQL:  SELECT flno FROM Flight WHERE distance  >  2000
#
# question:  What are the numbers of all flights that can cover a distance of more than 2000 ?
# SQL:  SELECT flno FROM Flight WHERE distance  >  2000
#
# question:  What is the aircraft name for the flight with number 99
# SQL:  SELECT T2.name FROM Flight AS T1 JOIN Aircraft AS T2 ON T1.aid  =  T2.aid WHERE T1.flno  =  99
#
# question:  What is the name of the aircraft that was on flight number 99 ?
# SQL:  SELECT T2.name FROM Flight AS T1 JOIN Aircraft AS T2 ON T1.aid  =  T2.aid WHERE T1.flno  =  99
#
# question:  Show all flight numbers with aircraft Airbus A340-300 .
# SQL:  SELECT T1.flno FROM Flight AS T1 JOIN Aircraft AS T2 ON T1.aid  =  T2.aid WHERE T2.name  =  "Airbus A340-300"
#
# question:  What are the flight numbers for the aircraft Airbus A340-300 ?
# SQL:  SELECT T1.flno FROM Flight AS T1 JOIN Aircraft AS T2 ON T1.aid  =  T2.aid WHERE T2.name  =  "Airbus A340-300"
#
# question:  Show all allergies with type food .
# SQL:  SELECT DISTINCT allergy FROM Allergy_type WHERE allergytype  =  "food"
#
# question:  What are all the different food allergies ?
# SQL:  SELECT DISTINCT allergy FROM Allergy_type WHERE allergytype  =  "food"
#
# question:  What is the type of allergy Cat ?
# SQL:  SELECT allergytype FROM Allergy_type WHERE allergy  =  "Cat"
#
# question:  What is allergy type of a cat allergy ?
# SQL:  SELECT allergytype FROM Allergy_type WHERE allergy  =  "Cat"
#
# question:  Show student ids for all male students .
# SQL:  SELECT StuID FROM Student WHERE Sex  =  'M'
#
# question:  What are the student ids for all male students ?
# SQL:  SELECT StuID FROM Student WHERE Sex  =  'M'
#
# question:  Show all student ids who are older than 20 .
# SQL:  SELECT StuID FROM Student WHERE age  >  20
#
# question:  What are the student ids for students over 20 years old ?
# SQL:  SELECT StuID FROM Student WHERE age  >  20
#
# question:  Which city does the student whose last name is `` Kim '' live in ?
# SQL:  SELECT city_code FROM Student WHERE LName  =  "Kim"
#
# question:  Give the city that the student whose family name is Kim lives in .
# SQL:  SELECT city_code FROM Student WHERE LName  =  "Kim"
#
# question:  Who is the advisor of student with ID 1004 ?
# SQL:  SELECT Advisor FROM Student WHERE StuID  =  1004
#
# question:  Who advises student 1004 ?
# SQL:  SELECT Advisor FROM Student WHERE StuID  =  1004
#
# question:  List Aerosmith 's albums .
# SQL:  SELECT T1.title FROM albums AS T1 JOIN artists AS T2 ON  T1.artist_id = T2.id WHERE T2.name = "Aerosmith";
#
# question:  What are the titles of all the Aerosmith albums ?
# SQL:  SELECT T1.title FROM albums AS T1 JOIN artists AS T2 ON  T1.artist_id = T2.id WHERE T2.name = "Aerosmith";
#
# question:  List the name of albums that are released by aritist whose name has 'Led '
# SQL:  SELECT T2.title FROM artists AS T1 JOIN albums AS T2 ON T1.id  =  T2.artist_id WHERE T1.name LIKE '%Led%'
#
# question:  What is the title of the album that was released by the artist whose name has the phrase 'Led ' ?
# SQL:  SELECT T2.title FROM artists AS T1 JOIN albums AS T2 ON T1.id  =  T2.artist_id WHERE T1.name LIKE '%Led%'
#
# question:  Who is the composer of track Fast As a Shark ?
# SQL:  SELECT composer FROM tracks WHERE name = "Fast As a Shark";
#
# question:  What is the composer who created the track `` Fast As a Shark '' ?
# SQL:  SELECT composer FROM tracks WHERE name = "Fast As a Shark";
#
# question:  How long does track Fast As a Shark has ?
# SQL:  SELECT milliseconds FROM tracks WHERE name = "Fast As a Shark";
#
# question:  How many milliseconds long is Fast As a Shark ?
# SQL:  SELECT milliseconds FROM tracks WHERE name = "Fast As a Shark";
#
# question:  What is title of album which track Balls to the Wall belongs to ?
# SQL:  SELECT T1.title FROM albums AS T1 JOIN tracks AS T2 ON T1.id = T2.genre_id WHERE T2.name = "Balls to the Wall";
#
# question:  What is the name of the album that has the track Ball to the Wall ?
# SQL:  SELECT T1.title FROM albums AS T1 JOIN tracks AS T2 ON T1.id = T2.genre_id WHERE T2.name = "Balls to the Wall";
#
# question:  List name of all tracks in Balls to the Wall .
# SQL:  SELECT T2.name FROM albums AS T1 JOIN tracks AS T2 ON T1.id = T2.genre_id WHERE T1.title = "Balls to the Wall";
#
# question:  What is the name of all tracks in the album named Balls to the Wall ?
# SQL:  SELECT T2.name FROM albums AS T1 JOIN tracks AS T2 ON T1.id = T2.genre_id WHERE T1.title = "Balls to the Wall";
#
# question:  How much is the track Fast As a Shark ?
# SQL:  SELECT unit_price FROM tracks WHERE name = "Fast As a Shark";
#
# question:  What is the unit price of the tune `` Fast As a Shark '' ?
# SQL:  SELECT unit_price FROM tracks WHERE name = "Fast As a Shark";
#
# question:  List the names of editors who are older than 25 .
# SQL:  SELECT Name FROM editor WHERE Age  >  25
#
# question:  Show the names of editors that are on the committee of journals with sales bigger than 3000 .
# SQL:  SELECT T2.Name FROM journal_committee AS T1 JOIN editor AS T2 ON T1.Editor_ID  =  T2.Editor_ID JOIN journal AS T3 ON T1.Journal_ID  =  T3.Journal_ID WHERE T3.Sales  >  3000
#
# question:  Show other account details for account with name 338 .
# SQL:  SELECT other_account_details FROM Accounts WHERE account_name  =  "338"
#
# question:  What are the other account details for the account with the name 338 ?
# SQL:  SELECT other_account_details FROM Accounts WHERE account_name  =  "338"
#
# question:  What are the names for tracks without a race in class 'GT ' .
# SQL:  SELECT name FROM track EXCEPT SELECT T2.name FROM race AS T1 JOIN track AS T2 ON T1.track_id  =  T2.track_id WHERE T1.class  =  'GT'
#
# question:  Give the names of tracks that do not have a race in the class 'GT ' .
# SQL:  SELECT name FROM track EXCEPT SELECT T2.name FROM race AS T1 JOIN track AS T2 ON T1.track_id  =  T2.track_id WHERE T1.class  =  'GT'
#
# question:  Which address do not have any member with the black membership card ?
# SQL:  SELECT address FROM member EXCEPT SELECT address FROM member WHERE Membership_card  =  'Black'
#
# question:  Find the title of all the albums of the artist `` AC/DC '' .
# SQL:  SELECT Title FROM ALBUM AS T1 JOIN ARTIST AS T2 ON T1.ArtistId  =  T2.ArtistId WHERE T2.Name  =  "AC/DC"
#
# question:  What are the titles of albums by the artist `` AC/DC '' ?
# SQL:  SELECT Title FROM ALBUM AS T1 JOIN ARTIST AS T2 ON T1.ArtistId  =  T2.ArtistId WHERE T2.Name  =  "AC/DC"
#
# question:  Which artist does the album `` Balls to the Wall '' belong to ?
# SQL:  SELECT T2.Name FROM ALBUM AS T1 JOIN ARTIST AS T2 ON T1.ArtistId  =  T2.ArtistId WHERE T1.Title  =  "Balls to the Wall"
#
# question:  Find the name of the artist who made the album `` Balls to the Wall '' .
# SQL:  SELECT T2.Name FROM ALBUM AS T1 JOIN ARTIST AS T2 ON T1.ArtistId  =  T2.ArtistId WHERE T1.Title  =  "Balls to the Wall"
#
# question:  What city does the employee who helps the customer with postal code 70174 live in ?
# SQL:  SELECT T2.City FROM CUSTOMER AS T1 JOIN EMPLOYEE AS T2 ON T1.SupportRepId  =  T2.EmployeeId WHERE T1.PostalCode  =  "70174"
#
# question:  Find the cities corresponding to employees who help customers with the postal code 70174 .
# SQL:  SELECT T2.City FROM CUSTOMER AS T1 JOIN EMPLOYEE AS T2 ON T1.SupportRepId  =  T2.EmployeeId WHERE T1.PostalCode  =  "70174"
#
# question:  Find all the customer last names that do not have invoice totals larger than 20 .
# SQL:  SELECT LastName FROM CUSTOMER EXCEPT SELECT T1.LastName FROM CUSTOMER AS T1 JOIN Invoice AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T2.total  >  20
#
# question:  What are the last names of customers without invoice totals exceeding 20 ?
# SQL:  SELECT LastName FROM CUSTOMER EXCEPT SELECT T1.LastName FROM CUSTOMER AS T1 JOIN Invoice AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T2.total  >  20
#
# question:  Find the first names of all customers that live in Brazil and have an invoice .
# SQL:  SELECT DISTINCT T1.FirstName FROM CUSTOMER AS T1 JOIN INVOICE AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T1.country  =  "Brazil"
#
# question:  What are the different first names for customers from Brazil who have also had an invoice ?
# SQL:  SELECT DISTINCT T1.FirstName FROM CUSTOMER AS T1 JOIN INVOICE AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T1.country  =  "Brazil"
#
# question:  Find the address of all customers that live in Germany and have invoice .
# SQL:  SELECT DISTINCT T1.Address FROM CUSTOMER AS T1 JOIN INVOICE AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T1.country  =  "Germany"
#
# question:  What are the addresses of customers living in Germany who have had an invoice ?
# SQL:  SELECT DISTINCT T1.Address FROM CUSTOMER AS T1 JOIN INVOICE AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T1.country  =  "Germany"
#
# question:  What are the birth dates of employees living in Edmonton ?
# SQL:  SELECT BirthDate FROM EMPLOYEE WHERE City  =  "Edmonton"
#
# question:  Find the birth dates corresponding to employees who live in the city of Edmonton .
# SQL:  SELECT BirthDate FROM EMPLOYEE WHERE City  =  "Edmonton"
#
# question:  What are the customer phone numbers under the policy `` Life Insurance '' ?
# SQL:  SELECT customer_phone FROM available_policies WHERE policy_type_code  =  "Life Insurance"
#
# question:  What are the phone numbers of customers using the policy with the code `` Life Insurance '' ?
# SQL:  SELECT customer_phone FROM available_policies WHERE policy_type_code  =  "Life Insurance"
#
# question:  What are all the policy types of the customer named `` Dayana Robel '' ?
# SQL:  SELECT DISTINCT t3.policy_type_code FROM customers AS t1 JOIN customers_policies AS t2 ON t1.customer_id  =  t2.customer_id JOIN available_policies AS t3 ON t2.policy_id  =  t3.policy_id WHERE t1.customer_name  =  "Dayana Robel"
#
# question:  Tell me the types of the policy used by the customer named `` Dayana Robel '' .
# SQL:  SELECT DISTINCT t3.policy_type_code FROM customers AS t1 JOIN customers_policies AS t2 ON t1.customer_id  =  t2.customer_id JOIN available_policies AS t3 ON t2.policy_id  =  t3.policy_id WHERE t1.customer_name  =  "Dayana Robel"
#
# question:  Find the IDs of customers whose name contains `` Diana '' .
# SQL:  SELECT customer_id FROM customers WHERE customer_name LIKE "%Diana%"
#
# question:  What are the IDs of customers who have `` Diana '' in part of their names ?
# SQL:  SELECT customer_id FROM customers WHERE customer_name LIKE "%Diana%"
#
# question:  Find the names of the chip models that are not used by any phone with full accreditation type .
# SQL:  SELECT model_name FROM chip_model EXCEPT SELECT chip_model FROM phone WHERE Accreditation_type  =  'Full'
#
# question:  Show the players from college UCLA .
# SQL:  SELECT Player FROM match_season WHERE College  =  "UCLA"
#
# question:  Who are the players from UCLA ?
# SQL:  SELECT Player FROM match_season WHERE College  =  "UCLA"
#
# question:  Which players are from Indonesia ?
# SQL:  SELECT T2.Player FROM country AS T1 JOIN match_season AS T2 ON T1.Country_id  =  T2.Country WHERE T1.Country_name  =  "Indonesia"
#
# question:  Who are the players from Indonesia ?
# SQL:  SELECT T2.Player FROM country AS T1 JOIN match_season AS T2 ON T1.Country_id  =  T2.Country WHERE T1.Country_name  =  "Indonesia"
#
# question:  What are the distinct positions of the players from a country whose capital is Dublin ?
# SQL:  SELECT DISTINCT T2.Position FROM country AS T1 JOIN match_season AS T2 ON T1.Country_id  =  T2.Country WHERE T1.Capital  =  "Dublin"
#
# question:  Give the different positions of players who play for the country with the capital Dublin .
# SQL:  SELECT DISTINCT T2.Position FROM country AS T1 JOIN match_season AS T2 ON T1.Country_id  =  T2.Country WHERE T1.Capital  =  "Dublin"
#
# question:  Show the positions of the players from the team with name `` Ryley Goldner '' .
# SQL:  SELECT T1.Position FROM match_season AS T1 JOIN team AS T2 ON T1.Team  =  T2.Team_id WHERE T2.Name  =  "Ryley Goldner"
#
# question:  Return the positions of players on the team Ryley Goldner .
# SQL:  SELECT T1.Position FROM match_season AS T1 JOIN team AS T2 ON T1.Team  =  T2.Team_id WHERE T2.Name  =  "Ryley Goldner"
#
# question:  What are the countries of mountains with height bigger than 5000 ?
# SQL:  SELECT Country FROM mountain WHERE Height  >  5000
#
# question:  Return the countries of the mountains that have a height larger than 5000 .
# SQL:  SELECT Country FROM mountain WHERE Height  >  5000
#
# question:  Show the distinct names of mountains climbed by climbers from country `` West Germany '' .
# SQL:  SELECT DISTINCT T2.Name FROM climber AS T1 JOIN mountain AS T2 ON T1.Mountain_ID  =  T2.Mountain_ID WHERE T1.Country  =  "West Germany"
#
# question:  What are the different names of mountains ascended by climbers from the country of West Germany ?
# SQL:  SELECT DISTINCT T2.Name FROM climber AS T1 JOIN mountain AS T2 ON T1.Mountain_ID  =  T2.Mountain_ID WHERE T1.Country  =  "West Germany"
#
# question:  Show the times used by climbers to climb mountains in Country Uganda .
# SQL:  SELECT T1.Time FROM climber AS T1 JOIN mountain AS T2 ON T1.Mountain_ID  =  T2.Mountain_ID WHERE T2.Country  =  "Uganda"
#
# question:  What are the times used by climbers who climbed mountains in the country of Uganda ?
# SQL:  SELECT T1.Time FROM climber AS T1 JOIN mountain AS T2 ON T1.Mountain_ID  =  T2.Mountain_ID WHERE T2.Country  =  "Uganda"
#
# question:  What are the names of body builders whose total score is higher than 300 ?
# SQL:  SELECT T2.Name FROM body_builder AS T1 JOIN people AS T2 ON T1.People_ID  =  T2.People_ID WHERE T1.Total  >  300
#
# question:  What are the heights of body builders with total score smaller than 315 ?
# SQL:  SELECT T2.Height FROM body_builder AS T1 JOIN people AS T2 ON T1.People_ID  =  T2.People_ID WHERE T1.Total  <  315
#
# question:  What are the total scores of the body builders whose birthday contains the string `` January '' ?
# SQL:  SELECT T1.total FROM body_builder AS T1 JOIN people AS T2 ON T1.people_id  =  T2.people_id WHERE T2.Birth_Date LIKE "%January%";
#
# question:  What are the names of representatives with more than 10000 votes in election ?
# SQL:  SELECT T2.Name FROM election AS T1 JOIN representative AS T2 ON T1.Representative_ID  =  T2.Representative_ID WHERE Votes  >  10000
#
# question:  Show the short names of the buildings managed by `` Emma '' .
# SQL:  SELECT building_short_name FROM Apartment_Buildings WHERE building_manager	 =  "Emma"
#
# question:  Which buildings does `` Emma '' manage ? Give me the short names of the buildings .
# SQL:  SELECT building_short_name FROM Apartment_Buildings WHERE building_manager	 =  "Emma"
#
# question:  Return the apartment numbers of the apartments with type code `` Flat '' .
# SQL:  SELECT apt_number FROM Apartments WHERE apt_type_code  =  "Flat"
#
# question:  Which apartments have type code `` Flat '' ? Give me their apartment numbers .
# SQL:  SELECT apt_number FROM Apartments WHERE apt_type_code  =  "Flat"
#
# question:  Return the date of birth for all the guests with gender code `` Male '' .
# SQL:  SELECT date_of_birth FROM Guests WHERE gender_code  =  "Male"
#
# question:  What are dates of birth of all the guests whose gender is `` Male '' ?
# SQL:  SELECT date_of_birth FROM Guests WHERE gender_code  =  "Male"
#
# question:  What is the booking status code of the apartment with apartment number `` Suite 634 '' ?
# SQL:  SELECT T1.booking_status_code FROM Apartment_Bookings AS T1 JOIN Apartments AS T2 ON T1.apt_id  =  T2.apt_id WHERE T2.apt_number  =  "Suite 634"
#
# question:  Tell me the booking status code for the apartment with number `` Suite 634 '' .
# SQL:  SELECT T1.booking_status_code FROM Apartment_Bookings AS T1 JOIN Apartments AS T2 ON T1.apt_id  =  T2.apt_id WHERE T2.apt_number  =  "Suite 634"
#
# question:  Show the distinct apartment numbers of the apartments that have bookings with status code `` Confirmed '' .
# SQL:  SELECT DISTINCT T2.apt_number FROM Apartment_Bookings AS T1 JOIN Apartments AS T2 ON T1.apt_id  =  T2.apt_id WHERE T1.booking_status_code  =  "Confirmed"
#
# question:  Which apartments have bookings with status code `` Confirmed '' ? Return their apartment numbers .
# SQL:  SELECT DISTINCT T2.apt_number FROM Apartment_Bookings AS T1 JOIN Apartments AS T2 ON T1.apt_id  =  T2.apt_id WHERE T1.booking_status_code  =  "Confirmed"
#
# question:  Show the facility codes of apartments with more than 4 bedrooms .
# SQL:  SELECT T1.facility_code FROM Apartment_Facilities AS T1 JOIN Apartments AS T2 ON T1.apt_id  =  T2.apt_id WHERE T2.bedroom_count  >  4
#
# question:  What are the facility codes of the apartments with more than four bedrooms ?
# SQL:  SELECT T1.facility_code FROM Apartment_Facilities AS T1 JOIN Apartments AS T2 ON T1.apt_id  =  T2.apt_id WHERE T2.bedroom_count  >  4
#
# question:  Show the addresses of the buildings that have apartments with more than 2 bathrooms .
# SQL:  SELECT T1.building_address FROM Apartment_Buildings AS T1 JOIN Apartments AS T2 ON T1.building_id  =  T2.building_id WHERE T2.bathroom_count  >  2
#
# question:  Which buildings have apartments that have more than two bathrooms ? Give me the addresses of the buildings .
# SQL:  SELECT T1.building_address FROM Apartment_Buildings AS T1 JOIN Apartments AS T2 ON T1.building_id  =  T2.building_id WHERE T2.bathroom_count  >  2
#
# question:  What is the average attendance of stadiums with capacity percentage higher than 100 % ?
# SQL:  SELECT average_attendance FROM stadium WHERE capacity_percentage  >  100
#
# question:  What is the season of the game which causes the player 'Walter Samuel ' to get injured ?
# SQL:  SELECT T1.season FROM game AS T1 JOIN injury_accident AS T2 ON T1.id  =  T2.game_id WHERE T2.player  =  'Walter Samuel'
#
# question:  Show the dates of performances with attending members whose roles are `` Violin '' .
# SQL:  SELECT T3.Date FROM member_attendance AS T1 JOIN member AS T2 ON T1.Member_ID  =  T2.Member_ID JOIN performance AS T3 ON T1.Performance_ID  =  T3.Performance_ID WHERE T2.Role  =  "Violin"
#
# question:  Find the buildings which have rooms with capacity more than 50 .
# SQL:  SELECT DISTINCT building FROM classroom WHERE capacity  >  50
#
# question:  What are the distinct buildings with capacities of greater than 50 ?
# SQL:  SELECT DISTINCT building FROM classroom WHERE capacity  >  50
#
# question:  Find the department name of the instructor whose name contains 'Soisalon ' .
# SQL:  SELECT dept_name FROM instructor WHERE name LIKE '%Soisalon%'
#
# question:  What is the name of the department with an instructure who has a name like 'Soisalon ' ?
# SQL:  SELECT dept_name FROM instructor WHERE name LIKE '%Soisalon%'
#
# question:  What is the id of the instructor who advises of all students from History department ?
# SQL:  SELECT i_id FROM advisor AS T1 JOIN student AS T2 ON T1.s_id  =  T2.id WHERE T2.dept_name  =  'History'
#
# question:  Give id of the instructor who advises students in the History department .
# SQL:  SELECT i_id FROM advisor AS T1 JOIN student AS T2 ON T1.s_id  =  T2.id WHERE T2.dept_name  =  'History'
#
# question:  Find the name of the instructors who taught C Programming course before .
# SQL:  SELECT T1.name FROM instructor AS T1 JOIN teaches AS T2 ON T1.id  =  T2.id JOIN course AS T3 ON T2.course_id  =  T3.course_id WHERE T3.title  =  'C Programming'
#
# question:  What are the names of instructors who have taught C Programming courses ?
# SQL:  SELECT T1.name FROM instructor AS T1 JOIN teaches AS T2 ON T1.id  =  T2.id JOIN course AS T3 ON T2.course_id  =  T3.course_id WHERE T3.title  =  'C Programming'
#
# question:  Find the name of students who took some course offered by Statistics department .
# SQL:  SELECT T3.name FROM course AS T1 JOIN takes AS T2 ON T1.course_id  =  T2.course_id JOIN student AS T3 ON T2.id  =  T3.id WHERE T1.dept_name  =  'Statistics'
#
# question:  What are the names of students who have taken Statistics courses ?
# SQL:  SELECT T3.name FROM course AS T1 JOIN takes AS T2 ON T1.course_id  =  T2.course_id JOIN student AS T3 ON T2.id  =  T3.id WHERE T1.dept_name  =  'Statistics'
#
# question:  Find the names of all instructors in computer science department
# SQL:  SELECT name FROM instructor WHERE dept_name  =  'Comp. Sci.'
#
# question:  What are the names of all instructors in the Comp . Sci . department ?
# SQL:  SELECT name FROM instructor WHERE dept_name  =  'Comp. Sci.'
#
# question:  List the dates of debates with number of audience bigger than 150
# SQL:  SELECT Date FROM debate WHERE Num_of_Audience  >  150
#
# question:  Show the names of people that are on affirmative side of debates with number of audience bigger than 200 .
# SQL:  SELECT T3.Name FROM debate_people AS T1 JOIN debate AS T2 ON T1.Debate_ID  =  T2.Debate_ID JOIN people AS T3 ON T1.Affirmative  =  T3.People_ID WHERE T2.Num_of_Audience  >  200
#
# question:  Find all the policy type codes associated with the customer `` Dayana Robel ''
# SQL:  SELECT policy_type_code FROM policies AS t1 JOIN customers AS t2 ON t1.customer_id  =  t2.customer_id WHERE t2.customer_details  =  "Dayana Robel"
#
# question:  What are the type codes of the policies used by the customer `` Dayana Robel '' ?
# SQL:  SELECT policy_type_code FROM policies AS t1 JOIN customers AS t2 ON t1.customer_id  =  t2.customer_id WHERE t2.customer_details  =  "Dayana Robel"
#
# question:  Find the names of the customers who have an deputy policy .
# SQL:  SELECT DISTINCT t2.customer_details FROM policies AS t1 JOIN customers AS t2 ON t1.customer_id  =  t2.customer_id WHERE t1.policy_type_code  =  "Deputy"
#
# question:  Which customers have an insurance policy with the type code `` Deputy '' ? Give me the customer details .
# SQL:  SELECT DISTINCT t2.customer_details FROM policies AS t1 JOIN customers AS t2 ON t1.customer_id  =  t2.customer_id WHERE t1.policy_type_code  =  "Deputy"
#
# question:  What is the description of the claim status `` Open '' ?
# SQL:  SELECT claim_status_description FROM claims_processing_stages WHERE claim_status_name  =  "Open"
#
# question:  Find the description of the claim status `` Open '' .
# SQL:  SELECT claim_status_description FROM claims_processing_stages WHERE claim_status_name  =  "Open"
#
# question:  Show all church names except for those that had a wedding in year 2015 .
# SQL:  SELECT name FROM church EXCEPT SELECT T1.name FROM church AS T1 JOIN wedding AS T2 ON T1.church_id  =  T2.church_id WHERE T2.year  =  2015
#
# question:  Show all artist names who did n't have an exhibition in 2004 .
# SQL:  SELECT name FROM artist EXCEPT SELECT T2.name FROM exhibition AS T1 JOIN artist AS T2 ON T1.artist_id  =  T2.artist_id WHERE T1.year  =  2004
#
# question:  What are the names of artists who did not have an exhibition in 2004 ?
# SQL:  SELECT name FROM artist EXCEPT SELECT T2.name FROM exhibition AS T1 JOIN artist AS T2 ON T1.artist_id  =  T2.artist_id WHERE T1.year  =  2004
#
# question:  Find the id of the item whose title is `` orange '' .
# SQL:  SELECT i_id FROM item WHERE title  =  "orange"
#
# question:  Find the names of goods that receive a rating of 10 .
# SQL:  SELECT T1.title FROM item AS T1 JOIN review AS T2 ON T1.i_id  =  T2.i_id WHERE T2.rating  =  10
#
# question:  Find the titles of items that received any rating below 5 .
# SQL:  SELECT T1.title FROM item AS T1 JOIN review AS T2 ON T1.i_id  =  T2.i_id WHERE T2.rating  <  5
#
# question:  Show the names of players coached by the rank 1 coach .
# SQL:  SELECT T3.Player_name FROM player_coach AS T1 JOIN coach AS T2 ON T1.Coach_ID  =  T2.Coach_ID JOIN player AS T3 ON T1.Player_ID  =  T3.Player_ID WHERE T2.Rank  =  1
#
# question:  What are the distinct hometowns of gymnasts with total points more than 57.5 ?
# SQL:  SELECT DISTINCT T2.Hometown FROM gymnast AS T1 JOIN people AS T2 ON T1.Gymnast_ID  =  T2.People_ID WHERE T1.Total_Points  >  57.5
#
# question:  Give the different hometowns of gymnasts that have a total point score of above 57.5 .
# SQL:  SELECT DISTINCT T2.Hometown FROM gymnast AS T1 JOIN people AS T2 ON T1.Gymnast_ID  =  T2.People_ID WHERE T1.Total_Points  >  57.5
#
# question:  What is the checking balance of the account whose owner’s name contains the substring ‘ee’ ?
# SQL:  SELECT T2.balance FROM accounts AS T1 JOIN checking AS T2 ON T1.custid  =  T2.custid WHERE T1.name LIKE '%ee%'
#
# question:  Find the balance of the checking account belonging to an owner whose name contains 'ee ' .
# SQL:  SELECT T2.balance FROM accounts AS T1 JOIN checking AS T2 ON T1.custid  =  T2.custid WHERE T1.name LIKE '%ee%'
#
# question:  What distinct accelerator names are compatible with the browswers that have market share higher than 15 ?
# SQL:  SELECT DISTINCT T1.name FROM web_client_accelerator AS T1 JOIN accelerator_compatible_browser AS T2 ON T2.accelerator_id  =  T1.id JOIN browser AS T3 ON T2.browser_id  =  T3.id WHERE T3.market_share  >  15;
#
# question:  What are the elimination moves of wrestlers whose team is `` Team Orton '' ?
# SQL:  SELECT Elimination_Move FROM Elimination WHERE Team  =  "Team Orton"
#
# question:  Return the elimination movies of wrestlers on Team Orton .
# SQL:  SELECT Elimination_Move FROM Elimination WHERE Team  =  "Team Orton"
#
# question:  Show times of elimination of wrestlers with days held more than 50 .
# SQL:  SELECT T1.Time FROM elimination AS T1 JOIN wrestler AS T2 ON T1.Wrestler_ID  =  T2.Wrestler_ID WHERE T2.Days_held  >  50
#
# question:  What are the times of elimination for wrestlers with over 50 days held ?
# SQL:  SELECT T1.Time FROM elimination AS T1 JOIN wrestler AS T2 ON T1.Wrestler_ID  =  T2.Wrestler_ID WHERE T2.Days_held  >  50
#
# question:  What are the names of wrestlers days held less than 100 ?
# SQL:  SELECT Name FROM wrestler WHERE Days_held  <  100
#
# question:  Return the names of wrestlers with fewer than 100 days held .
# SQL:  SELECT Name FROM wrestler WHERE Days_held  <  100
#
# question:  Show the names of all the donors except those whose donation amount less than 9 .
# SQL:  SELECT donator_name FROM endowment EXCEPT SELECT donator_name FROM endowment WHERE amount  <  9
#
# question:  Show the names of buildings except for those having an institution founded in 2003 .
# SQL:  SELECT name FROM building EXCEPT SELECT T1.name FROM building AS T1 JOIN institution AS T2 ON T1.building_id  =  T2.building_id WHERE T2.founded  =  2003
#
# question:  Show all the locations where no cinema has capacity over 800 .
# SQL:  SELECT LOCATION FROM cinema EXCEPT SELECT LOCATION FROM cinema WHERE capacity  >  800
#
# question:  Are the customers holding coupons with amount 500 bad or good ?
# SQL:  SELECT T1.good_or_bad_customer FROM customers AS T1 JOIN discount_coupons AS T2 ON T1.coupon_id  =  T2.coupon_id WHERE T2.coupon_amount  =  500
#
# question:  What is the product description of the product booked with an amount of 102.76 ?
# SQL:  SELECT T2.product_description FROM products_booked AS T1 JOIN products_for_hire AS T2 ON T1.product_id  =  T2.product_id WHERE T1.booked_amount  =  102.76
#
# question:  What are the names of products whose availability equals to 1 ?
# SQL:  SELECT T2.product_name FROM view_product_availability AS T1 JOIN products_for_hire AS T2 ON T1.product_id  =  T2.product_id WHERE T1.available_yn  =  1
#
# question:  What are the daily hire costs for the products with substring 'Book ' in its name ?
# SQL:  SELECT daily_hire_cost FROM Products_for_hire WHERE product_name LIKE '%Book%'
#
# question:  List the distinct carriers of phones with memories bigger than 32 .
# SQL:  SELECT DISTINCT Carrier FROM phone WHERE Memory_in_G  >  32
#
# question:  Show the names of phones that are on market with number of shops greater than 50 .
# SQL:  SELECT T3.Name FROM phone_market AS T1 JOIN market AS T2 ON T1.Market_ID  =  T2.Market_ID JOIN phone AS T3 ON T1.Phone_ID  =  T3.Phone_ID WHERE T2.Num_of_shops  >  50
#
# question:  Show all headquarters without a company in banking industry .
# SQL:  SELECT headquarters FROM company EXCEPT SELECT headquarters FROM company WHERE main_industry  =  'Banking'
#
# question:  What are the headquarters without companies that are in the banking industry ?
# SQL:  SELECT headquarters FROM company EXCEPT SELECT headquarters FROM company WHERE main_industry  =  'Banking'
#
# question:  Show the manager name for gas stations belonging to the ExxonMobil company .
# SQL:  SELECT T3.manager_name FROM station_company AS T1 JOIN company AS T2 ON T1.company_id  =  T2.company_id JOIN gas_station AS T3 ON T1.station_id  =  T3.station_id WHERE T2.company  =  'ExxonMobil'
#
# question:  What are the names of the managers for gas stations that are operated by the ExxonMobil company ?
# SQL:  SELECT T3.manager_name FROM station_company AS T1 JOIN company AS T2 ON T1.company_id  =  T2.company_id JOIN gas_station AS T3 ON T1.station_id  =  T3.station_id WHERE T2.company  =  'ExxonMobil'
#
# question:  Show all locations where a gas station for company with market value greater than 100 is located .
# SQL:  SELECT T3.location FROM station_company AS T1 JOIN company AS T2 ON T1.company_id  =  T2.company_id JOIN gas_station AS T3 ON T1.station_id  =  T3.station_id WHERE T2.market_value  >  100
#
# question:  What are the locations that have gas stations owned by a company with a market value greater than 100 ?
# SQL:  SELECT T3.location FROM station_company AS T1 JOIN company AS T2 ON T1.company_id  =  T2.company_id JOIN gas_station AS T3 ON T1.station_id  =  T3.station_id WHERE T2.market_value  >  100
#
# question:  List the distinct positions of pilots older than 30 .
# SQL:  SELECT DISTINCT POSITION FROM pilot WHERE Age  >  30
#
# question:  Show the fleet series of the aircrafts flied by pilots younger than 34
# SQL:  SELECT T2.Fleet_Series FROM pilot_record AS T1 JOIN aircraft AS T2 ON T1.Aircraft_ID  =  T2.Aircraft_ID JOIN pilot AS T3 ON T1.Pilot_ID  =  T3.Pilot_ID WHERE T3.Age  <  34
#
# question:  What is the description of document status code 'working ' ?
# SQL:  SELECT document_status_description FROM Ref_Document_Status WHERE document_status_code = "working";
#
# question:  What is the description of document type 'Paper ' ?
# SQL:  SELECT document_type_description FROM Ref_Document_Types WHERE document_type_code = "Paper";
#
# question:  What is the shipping agent code of shipping agent UPS ?
# SQL:  SELECT shipping_agent_code FROM Ref_Shipping_Agents WHERE shipping_agent_name = "UPS";
#
# question:  What is the description of role code ED ?
# SQL:  SELECT role_description FROM ROLES WHERE role_code = "ED";
#
# question:  What is the role of the employee named Koby ?
# SQL:  SELECT T1.role_description FROM ROLES AS T1 JOIN Employees AS T2 ON T1.role_code = T2.role_code WHERE T2.employee_name = "Koby";
#
# question:  List the document type code for the document with the id 2 .
# SQL:  SELECT document_type_code FROM Documents WHERE document_id = 2;
#
# question:  What is the receipt date of the document with id 3 ?
# SQL:  SELECT receipt_date FROM Documents WHERE document_id = 3;
#
# question:  What is the mail date of the document with id 7 ?
# SQL:  SELECT mailing_date FROM Documents_Mailed WHERE document_id = 7;
#
# question:  What is draft detail of the document with id 7 ?
# SQL:  SELECT draft_details FROM Document_Drafts WHERE document_id = 7;
#
# question:  find all dependent names who have a spouse relation with some employee .
# SQL:  SELECT Dependent_name FROM dependent WHERE relationship  =  'Spouse'
#
# question:  Find the names of departments that are located in Houston .
# SQL:  SELECT t1.dname FROM department AS t1 JOIN dept_locations AS t2 ON t1.dnumber  =  t2.dnumber WHERE t2.dlocation  =  'Houston'
#
# question:  what are the event details of the services that have the type code 'Marriage ' ?
# SQL:  SELECT T1.event_details FROM EVENTS AS T1 JOIN Services AS T2 ON T1.Service_ID  =  T2.Service_ID WHERE T2.Service_Type_Code  =  'Marriage'
#
# question:  Which events id does not have any participant with detail 'Kenyatta Kuhn ' ?
# SQL:  SELECT event_id FROM EVENTS EXCEPT SELECT T1.event_id FROM Participants_in_Events AS T1 JOIN Participants AS T2 ON T1.Participant_ID  =  T2.Participant_ID WHERE Participant_Details  =  'Kenyatta Kuhn'
#
# question:  Find the names of all races held in 2017 .
# SQL:  SELECT name FROM races WHERE YEAR = 2017
#
# question:  What are the names of all the races that occurred in the year 2017 ?
# SQL:  SELECT name FROM races WHERE YEAR = 2017
#
# question:  Show names of technicians who are assigned to repair machines with value point more than 70 .
# SQL:  SELECT T3.Name FROM repair_assignment AS T1 JOIN machine AS T2 ON T1.machine_id  =  T2.machine_id JOIN technician AS T3 ON T1.technician_ID  =  T3.technician_ID WHERE T2.value_points  >  70
#
# question:  What are the names of the technicians that are assigned to repair machines with more point values than 70 ?
# SQL:  SELECT T3.Name FROM repair_assignment AS T1 JOIN machine AS T2 ON T1.machine_id  =  T2.machine_id JOIN technician AS T3 ON T1.technician_ID  =  T3.technician_ID WHERE T2.value_points  >  70
#
# question:  Report the name of all campuses in Los Angeles county .
# SQL:  SELECT campus FROM campuses WHERE county  =  "Los Angeles"
#
# question:  What campuses are located in the county of Los Angeles ?
# SQL:  SELECT campus FROM campuses WHERE county  =  "Los Angeles"
#
# question:  What are the names of all campuses located at Chico ?
# SQL:  SELECT campus FROM campuses WHERE LOCATION  =  "Chico"
#
# question:  What campuses are located in Chico ?
# SQL:  SELECT campus FROM campuses WHERE LOCATION  =  "Chico"
#
# question:  Find all the campuses opened in 1958 .
# SQL:  SELECT campus FROM campuses WHERE YEAR  =  1958
#
# question:  What are the campuses that opened in 1958 ?
# SQL:  SELECT campus FROM campuses WHERE YEAR  =  1958
#
# question:  Find the name of the campuses opened before 1800 .
# SQL:  SELECT campus FROM campuses WHERE YEAR  <  1800
#
# question:  What campuses opened before 1800 ?
# SQL:  SELECT campus FROM campuses WHERE YEAR  <  1800
#
# question:  List the campuses in Los Angeles county .
# SQL:  SELECT campus FROM campuses WHERE county  =  "Los Angeles"
#
# question:  What campuses are in Los Angeles county ?
# SQL:  SELECT campus FROM campuses WHERE county  =  "Los Angeles"
#
# question:  Find the titles of all movies directed by steven spielberg .
# SQL:  SELECT title FROM Movie WHERE director = 'Steven Spielberg'
#
# question:  What are the names of all movies directed by Steven Spielberg ?
# SQL:  SELECT title FROM Movie WHERE director = 'Steven Spielberg'
#
# question:  Who is the director of movie Avatar ?
# SQL:  SELECT director FROM Movie WHERE title  = 'Avatar'
#
# question:  Who directed Avatar ?
# SQL:  SELECT director FROM Movie WHERE title  = 'Avatar'
#
# question:  What is the id of the reviewer whose name has substring “Mike” ?
# SQL:  SELECT rID FROM Reviewer WHERE name LIKE "%Mike%"
#
# question:  What is the id of the reviewer whose name includes the word `` Mike '' ?
# SQL:  SELECT rID FROM Reviewer WHERE name LIKE "%Mike%"
#
# question:  What is the reviewer id of Daniel Lewis ?
# SQL:  SELECT rID FROM Reviewer WHERE name  =  "Daniel Lewis"
#
# question:  What is the id of the reviewer named Daniel Lewis ?
# SQL:  SELECT rID FROM Reviewer WHERE name  =  "Daniel Lewis"
#
# question:  Find the names of all reviewers who have ratings with a NULL value for the date .
# SQL:  SELECT DISTINCT name FROM Reviewer AS T1 JOIN Rating AS T2 ON T1.rID  =  T2.rID WHERE ratingDate  =  "null"
#
# question:  What are the different names of all reviewers whose ratings do not have a date field ?
# SQL:  SELECT DISTINCT name FROM Reviewer AS T1 JOIN Rating AS T2 ON T1.rID  =  T2.rID WHERE ratingDate  =  "null"
#
# question:  Find the names of all reviewers who rated Gone with the Wind .
# SQL:  SELECT DISTINCT T3.name FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID JOIN Reviewer AS T3 ON T1.rID  =  T3.rID WHERE T2.title  =  'Gone with the Wind'
#
# question:  What are the names of all the different reviewers who rates Gone with the Wind ?
# SQL:  SELECT DISTINCT T3.name FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID JOIN Reviewer AS T3 ON T1.rID  =  T3.rID WHERE T2.title  =  'Gone with the Wind'
#
# question:  Find the names of all directors whose movies are rated by Sarah Martinez .
# SQL:  SELECT DISTINCT T2.director FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID JOIN Reviewer AS T3 ON T1.rID  =  T3.rID WHERE T3.name  =  'Sarah Martinez'
#
# question:  What are the names of all directors whose movies have been reviewed by Sarah Martinez ?
# SQL:  SELECT DISTINCT T2.director FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID JOIN Reviewer AS T3 ON T1.rID  =  T3.rID WHERE T3.name  =  'Sarah Martinez'
#
# question:  Find the titles of all movies not reviewed by Chris Jackson .
# SQL:  SELECT DISTINCT title FROM Movie EXCEPT SELECT T2.title FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID JOIN Reviewer AS T3 ON T1.rID  =  T3.rID WHERE T3.name  =  'Chris Jackson'
#
# question:  What are the titles of all movies that were not reviewed by Chris Jackson ?
# SQL:  SELECT DISTINCT title FROM Movie EXCEPT SELECT T2.title FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID JOIN Reviewer AS T3 ON T1.rID  =  T3.rID WHERE T3.name  =  'Chris Jackson'
#
# question:  Find the names of reviewers who had given higher than 3 star ratings .
# SQL:  SELECT T2.name FROM Rating AS T1 JOIN Reviewer AS T2 ON T1.rID  =  T2.rID WHERE T1.stars  >  3
#
# question:  What are the names of the reviewers who have rated a movie more than 3 stars before ?
# SQL:  SELECT T2.name FROM Rating AS T1 JOIN Reviewer AS T2 ON T1.rID  =  T2.rID WHERE T1.stars  >  3
#
# question:  What are the ids of the movies that are not reviewed by Brittany Harris .
# SQL:  SELECT mID FROM Rating EXCEPT SELECT T1.mID FROM Rating AS T1 JOIN Reviewer AS T2 ON T1.rID  =  T2.rID WHERE T2.name  =  "Brittany Harris"
#
# question:  What are the ids of all moviest hat have not been reviewed by Britanny Harris ?
# SQL:  SELECT mID FROM Rating EXCEPT SELECT T1.mID FROM Rating AS T1 JOIN Reviewer AS T2 ON T1.rID  =  T2.rID WHERE T2.name  =  "Brittany Harris"
#
# question:  find the ids of reviewers who did not give 4 star .
# SQL:  SELECT rID FROM Rating EXCEPT SELECT rID FROM Rating WHERE stars  =  4
#
# question:  What are the ids of all reviewers who did not give 4 stars ?
# SQL:  SELECT rID FROM Rating EXCEPT SELECT rID FROM Rating WHERE stars  =  4
#
# question:  What are the percentage of hispanics in cities with the black percentage higher than 10 ?
# SQL:  SELECT Hispanic FROM city WHERE Black  >  10
#
# question:  Return the hispanic percentage for cities in which the black percentage is greater than 10 .
# SQL:  SELECT Hispanic FROM city WHERE Black  >  10
#
# question:  Show the crime rate of counties with a city having white percentage more than 90 .
# SQL:  SELECT T2.Crime_rate FROM city AS T1 JOIN county_public_safety AS T2 ON T1.County_ID  =  T2.County_ID WHERE T1.White  >  90
#
# question:  What are the crime rates of counties that contain cities that have white percentages of over 90 ?
# SQL:  SELECT T2.Crime_rate FROM city AS T1 JOIN county_public_safety AS T2 ON T1.County_ID  =  T2.County_ID WHERE T1.White  >  90
#
# question:  What is the decor of room Recluse and defiance ?
# SQL:  SELECT decor FROM Rooms WHERE roomName  =  "Recluse and defiance";
#
# question:  Return the decor of the room named `` Recluse and defiance '' .
# SQL:  SELECT decor FROM Rooms WHERE roomName  =  "Recluse and defiance";
#
# question:  Find the name of rooms booked by some customers whose first name contains ROY .
# SQL:  SELECT T2.roomName FROM Reservations AS T1 JOIN Rooms AS T2 ON T1.Room  =  T2.RoomId WHERE firstname LIKE '%ROY%'
#
# question:  What are the name of rooms booked by customers whose first name has `` ROY '' in part ?
# ...
# SQL:  SELECT Roles.role_description , count(Employees.employee_id) FROM ROLES JOIN Employees ON Employees.role_code = Roles.role_code GROUP BY Employees.role_code HAVING count(Employees.employee_id)  >  1;
#
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {OP} {VALUE}
# count:  1
# question:  How many documents were shipped by USPS ?
# SQL:  SELECT count(*) FROM Ref_Shipping_Agents JOIN Documents ON Documents.shipping_agent_code = Ref_Shipping_Agents.shipping_agent_code WHERE Ref_Shipping_Agents.shipping_agent_name = "USPS";
#
#
# --------------------------------------
# SQL Pattern: SELECT , COUNT ( ) {FROM} GROUP BY ORDER BY COUNT ( ) {DASC} LIMIT {VALUE}
# count:  1
# question:  Which shipping agent shipped the most documents ? List the shipping agent name and the number of documents .
# SQL:  SELECT Ref_Shipping_Agents.shipping_agent_name , count(Documents.document_id) FROM Ref_Shipping_Agents JOIN Documents ON Documents.shipping_agent_code = Ref_Shipping_Agents.shipping_agent_code GROUP BY Ref_Shipping_Agents.shipping_agent_code ORDER BY count(Documents.document_id) DESC LIMIT 1;
#
#
# --------------------------------------
# SQL Pattern: SELECT {FROM} WHERE {COLUMN0} {OP} {VALUE}
# count:  1
# question:  What address was the document with id 4 mailed to ?
# SQL:  SELECT Addresses.address_details FROM Addresses JOIN Documents_Mailed ON Documents_Mailed.mailed_to_address_id = Addresses.address_id WHERE document_id = 4;
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} EXCEPT SELECT {COLUMN0} {FROM} WHERE {OP} {VALUE}
# count:  1
# question:  List the document ids of documents with the status done and type Paper , which not shipped by the shipping agent named USPS .
# SQL:  SELECT document_id FROM Documents WHERE document_status_code  =  "done" AND document_type_code = "Paper" EXCEPT SELECT document_id FROM Documents JOIN Ref_Shipping_Agents ON Documents.shipping_agent_code = Ref_Shipping_Agents.shipping_agent_code WHERE Ref_Shipping_Agents.shipping_agent_name = "USPS";
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} AND {COLUMN2} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {OP} {VALUE}
# count:  1
# question:  List document id of documents status is done and document type is Paper and the document is shipped by shipping agent named USPS .
# SQL:  SELECT document_id FROM Documents WHERE document_status_code  =  "done" AND document_type_code = "Paper" INTERSECT SELECT document_id FROM Documents JOIN Ref_Shipping_Agents ON Documents.shipping_agent_code = Ref_Shipping_Agents.shipping_agent_code WHERE Ref_Shipping_Agents.shipping_agent_name = "USPS";
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( {COLUMN1} ) {FROM} GROUP BY {COLUMN0} ORDER BY COUNT ( {COLUMN1} ) {DASC} LIMIT {VALUE}
# count:  1
# question:  Which document has the most draft copies ? List its document id and number of draft copies .
# SQL:  SELECT document_id , count(copy_number) FROM Draft_Copies GROUP BY document_id ORDER BY count(copy_number) DESC LIMIT 1;
#
#
# --------------------------------------
# SQL Pattern: SELECT , COUNT ( * ) {FROM} GROUP BY , , ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  1
# question:  Which employee has showed up in most circulation history documents . List the employee 's name and the number of drafts and copies .
# SQL:  SELECT Employees.employee_name , count(*) FROM Employees JOIN Circulation_History ON Circulation_History.employee_id = Employees.employee_id GROUP BY Circulation_History.document_id , Circulation_History.draft_number , Circulation_History.copy_number ORDER BY count(*) DESC LIMIT 1;
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN0} HAVING COUNT ( {COLUMN0} ) BETWEEN {VALUE} AND {VALUE}
# count:  1
# question:  Which major has between 2 and 30 number of students ? List major and the number of students .
# SQL:  SELECT Major ,  count(*) FROM Student GROUP BY Major HAVING count(Major) BETWEEN 2 AND 30;
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} AND {COLUMN3} {VALUE} AND {COLUMN4} {OP} {VALUE}
# count:  1
# question:  List all female students age is older than 18 who is not majoring in 600 . List students ' first name and last name .
# SQL:  SELECT Fname , Lname FROM Student WHERE Age  >  18 AND Major != 600 AND Sex = 'F';
#
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} GROUP BY HAVING {OP} {VALUE}
# count:  1
# question:  How many restaurant is the Sandwich type restaurant ?
# SQL:  SELECT count(*) FROM Restaurant JOIN Type_Of_Restaurant ON Restaurant.ResID =  Type_Of_Restaurant.ResID JOIN Restaurant_Type ON Type_Of_Restaurant.ResTypeID = Restaurant_Type.ResTypeID GROUP BY Type_Of_Restaurant.ResTypeID HAVING Restaurant_Type.ResTypeName = 'Sandwich'
#
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} WHERE {OP} {VALUE} AND {OP} {VALUE}
# count:  1
# question:  How long does student Linda Smith spend on the restaurant in total ?
# SQL:  SELECT sum(Spent) FROM Student JOIN Visits_Restaurant ON Student.StuID = Visits_Restaurant.StuID WHERE Student.Fname = "Linda" AND Student.Lname = "Smith";
#
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) {FROM} WHERE {OP} {VALUE} AND {OP} {VALUE} AND {OP} {VALUE}
# count:  1
# question:  How many times has the student Linda Smith visited Subway ?
# SQL:  SELECT count(*) FROM Student JOIN Visits_Restaurant ON Student.StuID = Visits_Restaurant.StuID JOIN Restaurant ON Visits_Restaurant.ResID = Restaurant.ResID WHERE Student.Fname = "Linda" AND Student.Lname = "Smith" AND Restaurant.ResName = "Subway";
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {OP} {VALUE} AND {OP} {VALUE} AND {OP} {VALUE}
# count:  1
# question:  When did Linda Smith visit Subway ?
# SQL:  SELECT TIME FROM Student JOIN Visits_Restaurant ON Student.StuID = Visits_Restaurant.StuID JOIN Restaurant ON Visits_Restaurant.ResID = Restaurant.ResID WHERE Student.Fname = "Linda" AND Student.Lname = "Smith" AND Restaurant.ResName = "Subway";
#
#
# --------------------------------------
# SQL Pattern: SELECT , {AGG} ( ) {FROM} GROUP BY ORDER BY {AGG} ( ) {DASC} LIMIT {VALUE}
# count:  1
# question:  At which restaurant did the students spend the least amount of time ? List restaurant and the time students spent on in total .
# SQL:  SELECT Restaurant.ResName ,  sum(Visits_Restaurant.Spent) FROM Visits_Restaurant JOIN Restaurant ON Visits_Restaurant.ResID = Restaurant.ResID GROUP BY Restaurant.ResID ORDER BY sum(Visits_Restaurant.Spent) ASC LIMIT 1;
#
#
# --------------------------------------
# SQL Pattern: SELECT , {FROM} GROUP BY ORDER BY COUNT ( * ) {DASC} LIMIT {VALUE}
# count:  1
# question:  Which student visited restaurant most often ? List student 's first name and last name .
# SQL:  SELECT Student.Fname , Student.Lname FROM Student JOIN Visits_Restaurant ON Student.StuID = Visits_Restaurant.StuID GROUP BY Student.StuID ORDER BY count(*) DESC LIMIT 1;
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  1
# question:  Which assets have 2 parts and have less than 2 fault logs ? List the asset id and detail .
# SQL:  SELECT T1.asset_id ,  T1.asset_details FROM Assets AS T1 JOIN Asset_Parts AS T2 ON T1.asset_id  =  T2.asset_id GROUP BY T1.asset_id HAVING count(*)  =  2 INTERSECT SELECT T1.asset_id ,  T1.asset_details FROM Assets AS T1 JOIN Fault_Log AS T2 ON T1.asset_id  =  T2.asset_id GROUP BY T1.asset_id HAVING count(*)  <  2
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} UNION SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  1
# question:  Which third party companies have at least 2 maintenance engineers or have at least 2 maintenance contracts ? List the company id and name .
# SQL:  SELECT T1.company_id ,  T1.company_name FROM Third_Party_Companies AS T1 JOIN Maintenance_Engineers AS T2 ON T1.company_id  =  T2.company_id GROUP BY T1.company_id HAVING count(*)  >=  2 UNION SELECT T3.company_id ,  T3.company_name FROM Third_Party_Companies AS T3 JOIN Maintenance_Contracts AS T4 ON T3.company_id  =  T4.maintenance_contract_company_id GROUP BY T3.company_id HAVING count(*)  >=  2
#
#
# --------------------------------------
# SQL Pattern: SELECT COUNT ( * ) , {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2}
# count:  1
# question:  Find the number of trains for each station , as well as the station network name and services .
# SQL:  SELECT count(*) ,  t1.network_name ,  t1.services FROM station AS t1 JOIN route AS t2 ON t1.id  =  t2.station_id GROUP BY t2.station_id
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN2} HAVING {AGG} ( {COLUMN3} ) {OP} {VALUE}
# count:  1
# question:  Find the id and local authority of the station whose maximum precipitation is higher than 50 .
# SQL:  SELECT t2.id ,  t2.local_authority FROM weekly_weather AS t1 JOIN station AS t2 ON t1.station_id  =  t2.id GROUP BY t1.station_id HAVING max(t1.precipitation)  >  50
#
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) {FROM} ORDER BY {COLUMN0} {DASC} LIMIT {VALUE}
# count:  1
# question:  find the total market rate of the furnitures that have the top 2 market shares .
# SQL:  SELECT sum(market_rate) FROM furniture ORDER BY market_rate DESC LIMIT 2
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , COUNT ( * ) {FROM} GROUP BY {COLUMN1} ORDER BY COUNT ( * )
# count:  1
# question:  What is the name of each camera lens and the number of photos taken by it ? Order the result by the count of photos .
# SQL:  SELECT T1.name ,  count(*) FROM camera_lens AS T1 JOIN photos AS T2 ON T1.id  =  T2.camera_lens_id GROUP BY T1.id ORDER BY count(*)
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} ORDER BY {COLUMN1} , {COLUMN2} {DASC}
# count:  1
# question:  list the names of the companies with more than 200 sales in the descending order of sales and profits .
# SQL:  SELECT name FROM company WHERE Sales_in_Billion  >  200 ORDER BY Sales_in_Billion ,  Profits_in_Billion DESC
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} ORDER BY {COLUMN0}
# count:  1
# question:  Show the names of products that are in at least two events in ascending alphabetical order of product name .
# SQL:  SELECT T1.Product_Name FROM Products AS T1 JOIN Products_in_Events AS T2 ON T1.Product_ID  =  T2.Product_ID GROUP BY T1.Product_Name HAVING COUNT(*)  >=  2 ORDER BY T1.Product_Name
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {OP} {VALUE} INTERSECT SELECT {COLUMN0} {FROM} WHERE {COLUMN1} {VALUE}
# count:  1
# question:  In which year are there festivals both inside the 'United States ' and outside the 'United States ' ?
# SQL:  SELECT YEAR FROM festival_detail WHERE LOCATION  =  'United States' INTERSECT SELECT YEAR FROM festival_detail WHERE LOCATION != 'United States'
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) BETWEEN {VALUE} AND {VALUE}
# count:  1
# question:  Which events have the number of notes between one and three ? List the event id and the property id .
# SQL:  SELECT T1.Customer_Event_ID  ,  T1.property_id FROM Customer_Events AS T1 JOIN Customer_Event_Notes AS T2 ON T1.Customer_Event_ID  =  T2.Customer_Event_ID GROUP BY T1.customer_event_id HAVING count(*) BETWEEN 1 AND 3
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} INTERSECT SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE}
# count:  1
# question:  What are the country names , area and population which has both roller coasters with speed higher
# SQL:  SELECT T1.name ,  T1.area ,  T1.population FROM country AS T1 JOIN roller_coaster AS T2 ON T1.Country_ID  =  T2.Country_ID WHERE T2.speed  >  60 INTERSECT SELECT T1.name ,  T1.area ,  T1.population FROM country AS T1 JOIN roller_coaster AS T2 ON T1.Country_ID  =  T2.Country_ID WHERE T2.speed  <  55
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} , {COLUMN3} {FROM} ORDER BY {COLUMN3}
# count:  1
# question:  List the id , country , city and name of the airports ordered alphabetically by the name .
# SQL:  SELECT id ,  country ,  city ,  name FROM airport ORDER BY name
#
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {AGG} ( {COLUMN0} ) {FROM} WHERE {COLUMN1} {OP} {VALUE} OR {COLUMN1} {OP} {VALUE}
# count:  1
# question:  What is the average and maximum number of total passengers for train stations in London or Glasgow ?
# SQL:  SELECT avg(total_passengers) ,  max(total_passengers) FROM station WHERE LOCATION  =  'London' OR LOCATION  =  'Glasgow'
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {AGG} ( {COLUMN1} ) , {AGG} ( {COLUMN2} ) {FROM} GROUP BY {COLUMN0}
# count:  1
# question:  Show all locations and the total number of platforms and passengers for all train stations in each location .
# SQL:  SELECT LOCATION ,  sum(number_of_platforms) ,  sum(total_passengers) FROM station GROUP BY LOCATION
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} WHERE {COLUMN2} {OP} {VALUE} ORDER BY {COLUMN1} {DASC}
# count:  1
# question:  Show all train names and times in stations in London in descending order by train time .
# SQL:  SELECT T3.name ,  T3.time FROM train_station AS T1 JOIN station AS T2 ON T1.station_id  =  T2.station_id JOIN train AS T3 ON T3.train_id  =  T1.train_id WHERE T2.location  =  'London' ORDER BY T3.time DESC
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} {FROM} ORDER BY {COLUMN2} , {COLUMN3}
# count:  1
# question:  List the names and locations of all stations ordered by their yearly entry exit and interchange amounts .
# SQL:  SELECT name ,  LOCATION FROM station ORDER BY Annual_entry_exit ,  Annual_interchanges
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} WHERE {COLUMN3} {OP} {VALUE} ORDER BY {COLUMN0}
# count:  1
# question:  List the name , nationality and id of all male architects ordered by their names lexicographically .
# SQL:  SELECT name ,  nationality ,  id FROM architect WHERE gender  =  'male' ORDER BY name
#
#
# --------------------------------------
# SQL Pattern: SELECT {AGG} ( {COLUMN0} ) , {COLUMN1} {FROM}
# count:  1
# question:  What is the maximum length in meters for the bridges and what are the architects ' names ?
# SQL:  SELECT max(T1.length_meters) ,  T2.name FROM bridge AS T1 JOIN architect AS T2 ON T1.architect_id  =  T2.id
#
#
# --------------------------------------
# SQL Pattern: SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE} UNION SELECT {COLUMN0} , {COLUMN1} , {COLUMN2} {FROM} GROUP BY {COLUMN0} HAVING COUNT ( * ) {OP} {VALUE}
# count:  1
# question:  What are the ids , names and genders of the architects who built two bridges or one mill ?
# SQL:  SELECT T1.id ,  T1.name ,  T1.gender FROM architect AS T1 JOIN bridge AS T2 ON T1.id  =  T2.architect_id GROUP BY T1.id HAVING count(*)  =  2 UNION SELECT T1.id ,  T1.name ,  T1.gender FROM architect AS T1 JOIN mill AS T2 ON T1.id  =  T2.architect_id GROUP BY T1.id HAVING count(*)  =  1
